# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/cerv1-air/Downloads/Retro Funding 4 early data.csv", low_memory=False)
df.head()
# Out:
#                                           Project id Project name  \
# 0  0x4b987d79912367ada6c3fa1bf6ad1daa6d164078f8c5...       Sturdy
# 1  0x4b987d79912367ada6c3fa1bf6ad1daa6d164078f8c5...       Sturdy
# 2  0x4b987d79912367ada6c3fa1bf6ad1daa6d164078f8c5...       Sturdy
# 3  0x79159d9bd4981ce68651fb4d585fd5827215309e503f...        Slice
# 4  0x79159d9bd4981ce68651fb4d585fd5827215309e503f...        Slice
#
#    Farcaster ID    Name    Username                 Email  \
# 0        559551     Sam      pgpsam  samaforman@gmail.com
# 1        559551     Sam      pgpsam  samaforman@gmail.com
# 2        559551     Sam      pgpsam  samaforman@gmail.com
# 3          2007  jacopo  jacopo.eth       jacopo@slice.so
# 4          2007  jacopo  jacopo.eth       jacopo@slice.so
#
#                                      ID  \
# 0  7067688f-e128-451f-8dba-bf542640bccb
# 1  7067688f-e128-451f-8dba-bf542640bccb
# 2  7067688f-e128-451f-8dba-bf542640bccb
# 3  35bbf4a9-9193-44af-a693-76890667aedb
# ...

# %%
sorted(df['Project name'].unique())
# Out:
# ['Alien Base',
#  'Ambire',
#  'Amet Finance',
#  'Another World',
#  'Aragon ',
#  'Artgene',
#  'Atlendis',
#  'Aura Finance',
#  'Avantis ',
#  'BSX',
#  'Balancer',
#  'Base on Rarible',
#  'Based Onchain Cubes',
#  'Based Onchain Dinos',
#  'Basepaint',
#  'Basic Dog Meme',
#  'Bebop',
#  'Beefy',
#  'Blob Farm',
#  'Boost',
#  'Bored Town',
#  'Borja Moskv',
#  'Bright Moments',
#  'Building Blocks',
#  'CanineReverie',
#  'CashmereLabs',
#  'Catalog Radio',
#  'Circle.tech',
#  'Clearpool Finance',
#  'Coordinape',
#  'Copin.io',
#  'Crypto: The Game S2',
#  'DackieNFT',
#  'DackieSwap',
#  'DappRadar',
#  'Dappgate',
#  'DappyKit Smart Accounts for Farcaster',
#  'DefiLlama',
#  'Degenfers',
#  'Dot',
#  'Drakula.app',
#  'DropFrame',
#  'EFIHUB',
#  'El Niño Estrella',
#  'Equalizer',
#  'EthXY',
#  'Ethos Reserve',
#  'Exactly Protocol',
#  'Extra Finance',
#  'Farcaster-Frames-Marketsense',
#  'Fluidkey',
#  'Fractal Visions',
#  'Gamma',
#  'Gangster Arena',
# ...

# %%
df[df['Project name'] == 'Zora']['Contract address'].unique()
# Out:
# array([], dtype=object)

# %%
df.iloc[0].T
# Out:
# Project id                   0x4b987d79912367ada6c3fa1bf6ad1daa6d164078f8c5...
# Project name                                                            Sturdy
# Farcaster ID                                                            559551
# Name                                                                       Sam
# Username                                                                pgpsam
# Email                                                     samaforman@gmail.com
# ID                                        7067688f-e128-451f-8dba-bf542640bccb
# Description                  Sturdy enables anyone to create liquid money m...
# Category                                                                 De Fi
# Thumbnail URL                https://storage.googleapis.com/op-atlas/3948f7...
# Banner URL                   https://storage.googleapis.com/op-atlas/c234d4...
# Twitter                                              twitter.com/sturdyfinance
# ...

# %%
[x.lower() for x in ['0xc2b78104907F722DABAc4C69f826a522B2754De4',
'0xF9D643f5645C6140b8EEb7eF42878b71eBfEe40b',
'0x4AdcA7cB84497c9c4c308063D2f219C7b6041183',
'0x594bc666500fAeD35DC741F45a35C571399560d8',
'0xf0fc94DCDC04b2400E5EEac6Aba35cC87d1954D0',
'0xA728b16CbA81772Fa881dC569Ad4c7F1dE360869',
'0x209603886a4520195FBC6221e2d8c8A609eE6c16',
'0x24aA17a5A5D14Bd3f5144a4a963ee8CDfAe6B511']]
# Out:
# ['0xc2b78104907f722dabac4c69f826a522b2754de4',
#  '0xf9d643f5645c6140b8eeb7ef42878b71ebfee40b',
#  '0x4adca7cb84497c9c4c308063d2f219c7b6041183',
#  '0x594bc666500faed35dc741f45a35c571399560d8',
#  '0xf0fc94dcdc04b2400e5eeac6aba35cc87d1954d0',
#  '0xa728b16cba81772fa881dc569ad4c7f1de360869',
#  '0x209603886a4520195fbc6221e2d8c8a609ee6c16',
#  '0x24aa17a5a5d14bd3f5144a4a963ee8cdfae6b511']
