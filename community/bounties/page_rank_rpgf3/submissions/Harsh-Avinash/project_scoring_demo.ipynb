# %%
import pandas as pd
from scoring_tools.project_scores import calculate_engagement_index, calculate_activity_level, calculate_collaboration_index, calculate_impact_factor, calculate_user_diversity_score
from scoring_tools.centrality_functions import calculate_importance_centrality, calculate_structural_centrality
from datetime import datetime

df = pd.read_csv("../../github_graph.csv")

# %%
project_engagement_scores = calculate_engagement_index(df, level='project')
repo_engagement_scores = calculate_engagement_index(df, level='repo')

print(project_engagement_scores)
print(repo_engagement_scores)
# Out:
#                          Unique Contributors  Total Contributions  \
# project
# protocol-guild                          5572              82117.0
# defi-llama                              2721              69091.0
# ipfs                                    1279              29494.0
# foundry                                 1500              13125.0
# snapshot-labs                           1179              20740.0
# ...                                      ...                  ...
# slugs-protocol-bernatfp                    1                  4.0
# valioxyz                                   1                  3.0
# seamless-protocol                          1                  3.0
# nacion-bankless                            1                  1.0
# jobstash                                   1                  1.0
#
#                          Normalized Unique Contributors  \
# project
# protocol-guild                                 1.000000
# defi-llama                                     0.488335
# ipfs                                           0.229541
# foundry                                        0.269203
# snapshot-labs                                  0.211594
# ...                                                 ...
# slugs-protocol-bernatfp                        0.000179
# valioxyz                                       0.000179
# seamless-protocol                              0.000179
# nacion-bankless                                0.000179
# jobstash                                       0.000179
#
#                          Normalized Total Contributions  Engagement Index
# project
# protocol-guild                                 1.000000          1.000000
# defi-llama                                     0.841373          0.594246
# ipfs                                           0.359170          0.268430
# foundry                                        0.159833          0.236392
# snapshot-labs                                  0.252566          0.223886
# ...                                                 ...               ...
# slugs-protocol-bernatfp                        0.000049          0.000140
# valioxyz                                       0.000037          0.000137
# seamless-protocol                              0.000037          0.000137
# nacion-bankless                                0.000012          0.000129
# jobstash                                       0.000012          0.000129
#
# [306 rows x 5 columns]
#                                    Unique Contributors  Total Contributions  \
# repo
# defillama/defillama-adapters                      2342              25306.0
# ethereum/ethereum-org-website                     1669              24769.0
# ethereum/go-ethereum                              1478               9124.0
# foundry-rs/foundry                                1229               8513.0
# blockscout/blockscout                             1086               7387.0
# ...                                                ...                  ...
# galxe/bab-sbt-subgraph                               1                  1.0
# galxe/alpaca-vault-subgraph                          1                  1.0
# rainbow-me/make-color-more-chill                     1                  1.0
# giveth/givethdirectory                               1                  1.0
# ethereumphone/androiddesignsystem                    1                  1.0
#
#                                    Normalized Unique Contributors  \
# repo
# defillama/defillama-adapters                             1.000000
# ethereum/ethereum-org-website                            0.712639
# ethereum/go-ethereum                                     0.631085
# foundry-rs/foundry                                       0.524765
# blockscout/blockscout                                    0.463706
# ...                                                           ...
# galxe/bab-sbt-subgraph                                   0.000427
# galxe/alpaca-vault-subgraph                              0.000427
# rainbow-me/make-color-more-chill                         0.000427
# giveth/givethdirectory                                   0.000427
# ethereumphone/androiddesignsystem                        0.000427
#
#                                    Normalized Total Contributions  \
# repo
# defillama/defillama-adapters                             0.546778
# ethereum/ethereum-org-website                            0.535176
# ethereum/go-ethereum                                     0.197139
# foundry-rs/foundry                                       0.183938
# blockscout/blockscout                                    0.159608
# ...                                                           ...
# galxe/bab-sbt-subgraph                                   0.000022
# galxe/alpaca-vault-subgraph                              0.000022
# rainbow-me/make-color-more-chill                         0.000022
# giveth/givethdirectory                                   0.000022
# ethereumphone/androiddesignsystem                        0.000022
#
#                                    Engagement Index
# repo
# defillama/defillama-adapters               0.864034
# ethereum/ethereum-org-website              0.659400
# ethereum/go-ethereum                       0.500901
# foundry-rs/foundry                         0.422517
# blockscout/blockscout                      0.372477
# ...                                             ...
# galxe/bab-sbt-subgraph                     0.000305
# galxe/alpaca-vault-subgraph                0.000305
# rainbow-me/make-color-more-chill           0.000305
# giveth/givethdirectory                     0.000305
# ethereumphone/androiddesignsystem          0.000305
#
# [4258 rows x 5 columns]

# %%
project_activity_scores = calculate_activity_level(df, level='project')
repo_activity_scores = calculate_activity_level(df, level='repo')

print(project_activity_scores)
print(repo_activity_scores)
# Out:
#                                  Contribution Frequency  Recency Score  \
# project
# protocol-guild                                  82117.0   57589.500000
# defi-llama                                      69091.0   50316.500000
# dappradar                                       47954.0   26237.666667
# ipfs                                            29494.0   21670.666667
# giveth                                          25965.0   17541.000000
# ...                                                 ...            ...
# valioxyz                                            3.0       3.000000
# seamless-protocol                                   3.0       3.000000
# go-ethereum-hdwallet-miguelmota                     3.0       2.500000
# nacion-bankless                                     1.0       1.000000
# jobstash                                            1.0       1.000000
#
#                                  Normalized Frequency  Normalized Recency  \
# project
# protocol-guild                               1.000000            1.000000
# defi-llama                                   0.841373            0.873710
# dappradar                                    0.583972            0.455598
# ipfs                                         0.359170            0.376295
# giveth                                       0.316195            0.304587
# ...                                               ...                 ...
# valioxyz                                     0.000037            0.000052
# seamless-protocol                            0.000037            0.000052
# go-ethereum-hdwallet-miguelmota              0.000037            0.000043
# nacion-bankless                              0.000012            0.000017
# jobstash                                     0.000012            0.000017
#
#                                  Activity Level
# project
# protocol-guild                         1.000000
# defi-llama                             0.857541
# dappradar                              0.519785
# ipfs                                   0.367733
# giveth                                 0.310391
# ...                                         ...
# valioxyz                               0.000044
# seamless-protocol                      0.000044
# go-ethereum-hdwallet-miguelmota        0.000040
# nacion-bankless                        0.000015
# jobstash                               0.000015
#
# [306 rows x 5 columns]
#                                Contribution Frequency  Recency Score  \
# repo
# dappradar/tokens                              46282.0   25093.000000
# defillama/defillama-adapters                  25306.0   16893.166667
# ethereum/ethereum-org-website                 24769.0   16403.833333
# defillama/defillama-server                    19058.0   14851.833333
# ethereum/remix-project                        18818.0   12784.333333
# ...                                               ...            ...
# ethereansos/interfaces-ui                         1.0       0.333333
# snapshot-labs/drop                                1.0       0.333333
# crustio/crust-action                              1.0       0.333333
# dexkit/coinleagues-graph                          1.0       0.333333
# blocknative/o2-wallets                            1.0       0.333333
#
#                                Normalized Frequency  Normalized Recency  \
# repo
# dappradar/tokens                           1.000000            1.000000
# defillama/defillama-adapters               0.546778            0.673222
# ethereum/ethereum-org-website              0.535176            0.653721
# defillama/defillama-server                 0.411780            0.591872
# ethereum/remix-project                     0.406594            0.509478
# ...                                             ...                 ...
# ethereansos/interfaces-ui                  0.000022            0.000013
# snapshot-labs/drop                         0.000022            0.000013
# crustio/crust-action                       0.000022            0.000013
# dexkit/coinleagues-graph                   0.000022            0.000013
# blocknative/o2-wallets                     0.000022            0.000013
#
#                                Activity Level
# repo
# dappradar/tokens                     1.000000
# defillama/defillama-adapters         0.610000
# ethereum/ethereum-org-website        0.594449
# defillama/defillama-server           0.501826
# ethereum/remix-project               0.458036
# ...                                       ...
# ethereansos/interfaces-ui            0.000017
# snapshot-labs/drop                   0.000017
# crustio/crust-action                 0.000017
# dexkit/coinleagues-graph             0.000017
# blocknative/o2-wallets               0.000017
#
# [4258 rows x 5 columns]

# %%
project_collaboration_scores = calculate_collaboration_index(df, level='project')
repo_collaboration_scores = calculate_collaboration_index(df, level='repo')

print(project_collaboration_scores)
print(repo_collaboration_scores)
# Out:
#                               Collaboration Pairs  Unique Users  \
# project
# protocol-guild                         15526378.0          5572
# defi-llama                              3703281.0          2721
# foundry                                 1125750.0          1500
# go-ethereum                             1092981.0          1478
# ipfs                                     818560.0          1279
# ...                                           ...           ...
# ponder-surveys                                0.0             1
# seamless-protocol                             0.0             1
# slugs-protocol-bernatfp                       0.0             1
# solidity-analyzer-parmanuxyz                  0.0             1
# jobstash                                      0.0             1
#
#                               Normalized Pairs  Normalized Users  \
# project
# protocol-guild                        1.000000          1.000000
# defi-llama                            0.238515          0.488335
# foundry                               0.072506          0.269203
# go-ethereum                           0.070395          0.265255
# ipfs                                  0.052721          0.229541
# ...                                        ...               ...
# ponder-surveys                        0.000000          0.000179
# seamless-protocol                     0.000000          0.000179
# slugs-protocol-bernatfp               0.000000          0.000179
# solidity-analyzer-parmanuxyz          0.000000          0.000179
# jobstash                              0.000000          0.000179
#
#                               Collaboration Index
# project
# protocol-guild                           1.000000
# defi-llama                               0.363425
# foundry                                  0.170854
# go-ethereum                              0.167825
# ipfs                                     0.141131
# ...                                           ...
# ponder-surveys                           0.000090
# seamless-protocol                        0.000090
# slugs-protocol-bernatfp                  0.000090
# solidity-analyzer-parmanuxyz             0.000090
# jobstash                                 0.000090
#
# [306 rows x 5 columns]
#                                            Collaboration Pairs  Unique Users  \
# repo
# defillama/defillama-adapters                         2743653.0          2342
# ethereum/ethereum-org-website                        1393615.0          1669
# ethereum/go-ethereum                                 1092981.0          1478
# foundry-rs/foundry                                    755835.0          1229
# blockscout/blockscout                                 590241.0          1086
# ...                                                        ...           ...
# givepraise/op-attestation-explorer                         0.0             1
# openocean-finance/cbridge_im_crossandswap                  0.0             1
# dexkit/coinleagues-champions-contract                      0.0             1
# dexkit/coinleagues-graph                                   0.0             1
# nftearth/reservoir-nftearth                                0.0             1
#
#                                            Normalized Pairs  Normalized Users  \
# repo
# defillama/defillama-adapters                       1.000000          1.000000
# ethereum/ethereum-org-website                      0.507941          0.712639
# ethereum/go-ethereum                               0.398367          0.631085
# foundry-rs/foundry                                 0.275485          0.524765
# blockscout/blockscout                              0.215130          0.463706
# ...                                                     ...               ...
# givepraise/op-attestation-explorer                 0.000000          0.000427
# openocean-finance/cbridge_im_crossandswap          0.000000          0.000427
# dexkit/coinleagues-champions-contract              0.000000          0.000427
# dexkit/coinleagues-graph                           0.000000          0.000427
# nftearth/reservoir-nftearth                        0.000000          0.000427
#
#                                            Collaboration Index
# repo
# defillama/defillama-adapters                          1.000000
# ethereum/ethereum-org-website                         0.610290
# ethereum/go-ethereum                                  0.514726
# foundry-rs/foundry                                    0.400125
# blockscout/blockscout                                 0.339418
# ...                                                        ...
# givepraise/op-attestation-explorer                    0.000213
# openocean-finance/cbridge_im_crossandswap             0.000213
# dexkit/coinleagues-champions-contract                 0.000213
# dexkit/coinleagues-graph                              0.000213
# nftearth/reservoir-nftearth                           0.000213
#
# [4258 rows x 5 columns]

# %%
project_impact_scores = calculate_impact_factor(df, level='project')
repo_impact_scores = calculate_impact_factor(df, level='repo')

print(project_impact_scores)
print(repo_impact_scores)
# Out:
#                          Total Contributions  Unique Contributors  \
# project
# protocol-guild                       82117.0                 5572
# defi-llama                           69091.0                 2721
# dappradar                            47954.0                  167
# ipfs                                 29494.0                 1279
# nethermindeth                        23729.0                  630
# ...                                      ...                  ...
# slugs-protocol-bernatfp                  4.0                    1
# valioxyz                                 3.0                    1
# seamless-protocol                        3.0                    1
# nacion-bankless                          1.0                    1
# jobstash                                 1.0                    1
#
#                          Contribution Frequency  Recency Score  \
# project
# protocol-guild                          82117.0   57589.500000
# defi-llama                              69091.0   50316.500000
# dappradar                               47954.0   26237.666667
# ipfs                                    29494.0   21670.666667
# nethermindeth                           23729.0   16703.000000
# ...                                         ...            ...
# slugs-protocol-bernatfp                     4.0       4.000000
# valioxyz                                    3.0       3.000000
# seamless-protocol                           3.0       3.000000
# nacion-bankless                             1.0       1.000000
# jobstash                                    1.0       1.000000
#
#                          Normalized Total Contributions  \
# project
# protocol-guild                                 1.000000
# defi-llama                                     0.841373
# dappradar                                      0.583972
# ipfs                                           0.359170
# nethermindeth                                  0.288966
# ...                                                 ...
# slugs-protocol-bernatfp                        0.000049
# valioxyz                                       0.000037
# seamless-protocol                              0.000037
# nacion-bankless                                0.000012
# jobstash                                       0.000012
#
#                          Normalized Unique Contributors  Normalized Frequency  \
# project
# protocol-guild                                 1.000000              1.000000
# defi-llama                                     0.488335              0.841373
# dappradar                                      0.029971              0.583972
# ipfs                                           0.229541              0.359170
# nethermindeth                                  0.113065              0.288966
# ...                                                 ...                   ...
# slugs-protocol-bernatfp                        0.000179              0.000049
# valioxyz                                       0.000179              0.000037
# seamless-protocol                              0.000179              0.000037
# nacion-bankless                                0.000179              0.000012
# jobstash                                       0.000179              0.000012
#
#                          Normalized Recency  Impact Factor
# project
# protocol-guild                     1.000000       1.000000
# defi-llama                         0.873710       0.761197
# dappradar                          0.455598       0.413378
# ipfs                               0.376295       0.331044
# nethermindeth                      0.290036       0.245258
# ...                                     ...            ...
# slugs-protocol-bernatfp            0.000069       0.000087
# valioxyz                           0.000052       0.000076
# seamless-protocol                  0.000052       0.000076
# nacion-bankless                    0.000017       0.000055
# jobstash                           0.000017       0.000055
#
# [306 rows x 9 columns]
#                                      Total Contributions  Unique Contributors  \
# repo
# dappradar/tokens                                 46282.0                   11
# defillama/defillama-adapters                     25306.0                 2342
# ethereum/ethereum-org-website                    24769.0                 1669
# defillama/defillama-server                       19058.0                  278
# ethereum/remix-project                           18818.0                  342
# ...                                                  ...                  ...
# banklessdao/solidity-study-material                  1.0                    1
# learnweb3dao/dapp                                    1.0                    1
# lexdao/arbitration                                   1.0                    1
# blocknative/o2-wallets                               1.0                    1
# agoraxyz/agora-contracts                             1.0                    1
#
#                                      Contribution Frequency  Recency Score  \
# repo
# dappradar/tokens                                    46282.0   25093.000000
# defillama/defillama-adapters                        25306.0   16893.166667
# ethereum/ethereum-org-website                       24769.0   16403.833333
# defillama/defillama-server                          19058.0   14851.833333
# ethereum/remix-project                              18818.0   12784.333333
# ...                                                     ...            ...
# banklessdao/solidity-study-material                     1.0       0.333333
# learnweb3dao/dapp                                       1.0       0.333333
# lexdao/arbitration                                      1.0       0.333333
# blocknative/o2-wallets                                  1.0       0.333333
# agoraxyz/agora-contracts                                1.0       0.333333
#
#                                      Normalized Total Contributions  \
# repo
# dappradar/tokens                                           1.000000
# defillama/defillama-adapters                               0.546778
# ethereum/ethereum-org-website                              0.535176
# defillama/defillama-server                                 0.411780
# ethereum/remix-project                                     0.406594
# ...                                                             ...
# banklessdao/solidity-study-material                        0.000022
# learnweb3dao/dapp                                          0.000022
# lexdao/arbitration                                         0.000022
# blocknative/o2-wallets                                     0.000022
# agoraxyz/agora-contracts                                   0.000022
#
#                                      Normalized Unique Contributors  \
# repo
# dappradar/tokens                                           0.004697
# defillama/defillama-adapters                               1.000000
# ethereum/ethereum-org-website                              0.712639
# defillama/defillama-server                                 0.118702
# ethereum/remix-project                                     0.146029
# ...                                                             ...
# banklessdao/solidity-study-material                        0.000427
# learnweb3dao/dapp                                          0.000427
# lexdao/arbitration                                         0.000427
# blocknative/o2-wallets                                     0.000427
# agoraxyz/agora-contracts                                   0.000427
#
#                                      Normalized Frequency  Normalized Recency  \
# repo
# dappradar/tokens                                 1.000000            1.000000
# defillama/defillama-adapters                     0.546778            0.673222
# ethereum/ethereum-org-website                    0.535176            0.653721
# defillama/defillama-server                       0.411780            0.591872
# ethereum/remix-project                           0.406594            0.509478
# ...                                                   ...                 ...
# banklessdao/solidity-study-material              0.000022            0.000013
# learnweb3dao/dapp                                0.000022            0.000013
# lexdao/arbitration                               0.000022            0.000013
# blocknative/o2-wallets                           0.000022            0.000013
# agoraxyz/agora-contracts                         0.000022            0.000013
#
#                                      Impact Factor
# repo
# dappradar/tokens                          0.751174
# defillama/defillama-adapters              0.691695
# ethereum/ethereum-org-website             0.609178
# defillama/defillama-server                0.383533
# ethereum/remix-project                    0.367174
# ...                                            ...
# banklessdao/solidity-study-material       0.000121
# learnweb3dao/dapp                         0.000121
# lexdao/arbitration                        0.000121
# blocknative/o2-wallets                    0.000121
# agoraxyz/agora-contracts                  0.000121
#
# [4258 rows x 9 columns]

# %%
project_diversity_scores = calculate_user_diversity_score(df, level='project')
repo_diversity_scores = calculate_user_diversity_score(df, level='repo')

print(project_diversity_scores)
print(repo_diversity_scores)
# Out:
#                                  Unique Users  Total Contributions  \
# project
# jobstash                                    1                  1.0
# go-ethereum-hdwallet-miguelmota             3                  3.0
# nacion-bankless                             1                  1.0
# ethhub-io                                  30                 36.0
# cryptozombieshq                           165                337.0
# ...                                       ...                  ...
# defientco                                  13               4014.0
# sphinx-chugsplash                          10               3115.0
# charmverse                                 19               6640.0
# blockhead-darryl-yeo                        4               1679.0
# ethereansos                                 8              12137.0
#
#                                  Diversity Score
# project
# jobstash                                1.000000
# go-ethereum-hdwallet-miguelmota         1.000000
# nacion-bankless                         1.000000
# ethhub-io                               0.833333
# cryptozombieshq                         0.489614
# ...                                          ...
# defientco                               0.003239
# sphinx-chugsplash                       0.003210
# charmverse                              0.002861
# blockhead-darryl-yeo                    0.002382
# ethereansos                             0.000659
#
# [306 rows x 3 columns]
#                                               Unique Users  \
# repo
# dappnode/certificates-server                             2
# giveth/testgivethdirectory                               1
# nethermindeth/terraform-nethermind                       1
# giveth/website                                           1
# ethereansos/interfaces-ui                                1
# ...                                                    ...
# darrylyeo/blockhead                                      4
# nethermindeth/warp-ts-benchmark                          2
# hop-protocol/goerli-test-merkle-rewards-data             1
# dappradar/tokens                                        11
# ethereansos/items-swap                                   2
#
#                                               Total Contributions  \
# repo
# dappnode/certificates-server                                  1.0
# giveth/testgivethdirectory                                    1.0
# nethermindeth/terraform-nethermind                            1.0
# giveth/website                                                1.0
# ethereansos/interfaces-ui                                     1.0
# ...                                                           ...
# darrylyeo/blockhead                                        1679.0
# nethermindeth/warp-ts-benchmark                             987.0
# hop-protocol/goerli-test-merkle-rewards-data                939.0
# dappradar/tokens                                          46282.0
# ethereansos/items-swap                                    11533.0
#
#                                               Diversity Score
# repo
# dappnode/certificates-server                         2.000000
# giveth/testgivethdirectory                           1.000000
# nethermindeth/terraform-nethermind                   1.000000
# giveth/website                                       1.000000
# ethereansos/interfaces-ui                            1.000000
# ...                                                       ...
# darrylyeo/blockhead                                  0.002382
# nethermindeth/warp-ts-benchmark                      0.002026
# hop-protocol/goerli-test-merkle-rewards-data         0.001065
# dappradar/tokens                                     0.000238
# ethereansos/items-swap                               0.000173
#
# [4258 rows x 3 columns]

# %%
importance_centrality_project = calculate_importance_centrality(df, level='project')
importance_centrality_repo = calculate_importance_centrality(df, level='repo')

print("Importance Centrality for Projects:")
print(importance_centrality_project)

print("Importance Centrality for Repos:")
print(importance_centrality_repo)
# Out:
# Importance Centrality for Projects:
#                            page_rank  eigenvector_centrality
# defi-llama                  0.020322            1.701116e-01
# pokt-foundation             0.019160            3.583306e-02
# gitcoin                     0.018887            1.314564e-01
# protocol-guild              0.016502            2.243250e-01
# foundry                     0.016501            2.203739e-01
# ...                              ...                     ...
# keyring-so                  0.000572            2.758948e-14
# retropgf-hub-fwb-creators   0.000572            2.758948e-14
# openocean-finance           0.000572            2.758948e-14
# justcause-smeee23           0.000572            2.758948e-14
# validatoxyz                 0.000572            2.758948e-14
#
# [306 rows x 2 columns]
# Importance Centrality for Repos:
#                                         page_rank  eigenvector_centrality
# ethereum/eips                            0.005358            1.869556e-01
# ethereum/ethereum-org-website            0.004667            2.140691e-01
# foundry-rs/foundry                       0.003861            2.179559e-01
# wagmi-dev/viem                           0.003553            1.641777e-01
# defillama/defillama-adapters             0.003504            1.490428e-01
# ...                                           ...                     ...
# openocean-finance/openoceanexchangev2    0.000042            6.248283e-16
# crustio/crust-grant-milestone-delivery   0.000042            6.248283e-16
# 1w3io/porfolioui                         0.000042            6.248283e-16
# ethhub-io/ethhub-zh                      0.000042            6.248283e-16
# agoraxyz/gold-glue                       0.000042            6.248283e-16
#
# [4258 rows x 2 columns]

# %%
structural_centrality_project = calculate_structural_centrality(df, level='project')
structural_centrality_repo = calculate_structural_centrality(df, level='repo')

print("Structural Centrality for Projects:")
print(structural_centrality_project)

print("Structural Centrality for Repos:")
print(structural_centrality_repo)
# Out:
# Structural Centrality for Projects:
#                                  betweenness_centrality  closeness_centrality
# protocol-guild                                 0.120348              0.631896
# foundry                                        0.088893              0.624114
# wagmi-dev                                      0.063995              0.589279
# defi-llama                                     0.047375              0.556901
# gitcoin                                        0.042912              0.525706
# ...                                                 ...                   ...
# polynomial-protocol                            0.000000              0.314770
# weekinethnews                                  0.000000              0.361470
# xkcp                                           0.000000              0.000000
# project-squallet-refractor-labs                0.000000              0.350470
# validatoxyz                                    0.000000              0.373732
#
# [306 rows x 2 columns]
# Structural Centrality for Repos:
#                                        betweenness_centrality  \
# foundry-rs/foundry                                   0.125984
# ethereum/ethereum-org-website                        0.097298
# ethereum/eips                                        0.058409
# nomicfoundation/hardhat                              0.057406
# ethers-io/ethers.js                                  0.055878
# ...                                                       ...
# nftearth/raffle-app                                  0.000000
# lexdao/lexdao-articles                               0.000000
# acryptos/data-x                                      0.000000
# openzeppelin/safe-contracts-context                  0.000000
# yokifinance/yoki-dca-protocol-foundry                0.000000
#
#                                        closeness_centrality
# foundry-rs/foundry                                 0.361340
# ethereum/ethereum-org-website                      0.358108
# ethereum/eips                                      0.346563
# nomicfoundation/hardhat                            0.347392
# ethers-io/ethers.js                                0.347977
# ...                                                     ...
# nftearth/raffle-app                                0.173473
# lexdao/lexdao-articles                             0.158729
# acryptos/data-x                                    0.210019
# openzeppelin/safe-contracts-context                0.209291
# yokifinance/yoki-dca-protocol-foundry              0.000235
#
# [4258 rows x 2 columns]
