# %%
from google.cloud import bigquery
import os
import pandas as pd
import re

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../oso_gcp_credentials.json'
GCP_PROJECT = 'opensource-observer'
client = bigquery.Client(GCP_PROJECT)

# %%
# Helpers

def stringify_array(arr):
    return "'" + "','".join(arr) + "'"

def parse_github(pkg_url):
    if isinstance(pkg_url, str):
        match = re.search(r'github\.com/([^/]+)/([^/.#]+)', pkg_url)
        if match:
            owner = match.group(1).lower()
            repo = match.group(2).lower()
            return '/'.join([owner, repo])    
    return None

def extract_namespace(npm_package_name):
    if npm_package_name.startswith('@'):
        return npm_package_name.split('/')[0][1:]
    return None

# %% [markdown]
# # Get SBOMs for repos we care about

# %%
CONSENSUS = [
    'prysmaticlabs/prysm',
    'sigp/lighthouse',
    'consensys/teku',
    'status-im/nimbus-eth2',
    'chainsafe/lodestar',
    'grandinetech/grandine'
]
EXECUTION = [
    'ethereum/go-ethereum',
    'nethermindeth/nethermind',
    'hyperledger/besu',
    'erigontech/erigon',
    'paradigmxyz/reth'
]
OTHER = [
    'ethereum/solidity',
    'ethereum/remix-project',
    'vyperlang/vyper',
    'ethereum/web3.py',
    'ethereum/py-evm',
    'eth-infinitism/account-abstraction',
    'safe-global/safe-smart-account',
    'a16z/helios',
    'web3/web3.js', # prev. 'ethereum/web3.js',
    'ethereumjs/ethereumjs-monorepo'    
]
SEED_REPOS = CONSENSUS + EXECUTION + OTHER
PACKAGE_SERVERS = ['NPM', 'RUST', 'GO', 'PIP']

# %%
print(SEED_REPOS)
# Out:
# ['prysmaticlabs/prysm', 'sigp/lighthouse', 'consensys/teku', 'status-im/nimbus-eth2', 'chainsafe/lodestar', 'grandinetech/grandine', 'ethereum/go-ethereum', 'nethermindeth/nethermind', 'hyperledger/besu', 'erigontech/erigon', 'paradigmxyz/reth', 'ethereum/solidity', 'ethereum/remix-project', 'vyperlang/vyper', 'ethereum/web3.py', 'ethereum/py-evm', 'eth-infinitism/account-abstraction', 'safe-global/safe-smart-account', 'a16z/helios', 'web3/web3.js', 'ethereumjs/ethereumjs-monorepo']

# %%
sbom_results = client.query(f"""
    WITH sboms AS (
      SELECT DISTINCT
        artifact_namespace AS repo_owner,
        CONCAT(artifact_namespace, '/', artifact_name) AS repo_name,
        package_artifact_name,
        package_artifact_source
      FROM `oso.int_sbom_artifacts`
      WHERE package_artifact_source IN ({stringify_array(PACKAGE_SERVERS)})
    )
    SELECT * FROM sboms
    WHERE repo_name IN ({stringify_array(SEED_REPOS)})
""")
df_sbom = sbom_results.to_dataframe()
df_sbom.to_csv('data/sbom.csv')
df_sbom.tail()
# Out:
#       repo_owner             repo_name  \
# 13801   ethereum  ethereum/go-ethereum
# 13802   ethereum  ethereum/go-ethereum
# 13803   ethereum  ethereum/go-ethereum
# 13804   ethereum  ethereum/go-ethereum
# 13805   ethereum  ethereum/go-ethereum
#
#                                 package_artifact_name package_artifact_source
# 13801                           github.com/cespare/cp                      GO
# 13802                     github.com/protolambda/ztyp                      GO
# 13803  github.com/azure/azure-sdk-for-go/sdk/internal                      GO
# 13804                        go.uber.org/automaxprocs                      GO
# 13805       github.com/aws/aws-sdk-go-v2/internal/ini                      GO

# %%
df_sbom.groupby('package_artifact_source')['package_artifact_name'].nunique()
# Out:
# package_artifact_source
# GO       416
# NPM     4750
# PIP      137
# RUST    1076
# Name: package_artifact_name, dtype: int64

# %%
df_sbom.groupby('package_artifact_source')['package_artifact_name'].nunique().sum()
# Out:
# 6379

# %% [markdown]
# ## Lookup Go packages

# %%
df_go = df_sbom[df_sbom['package_artifact_source'] == 'GO'].copy()
df_go['package_repo_name'] = df_go['package_artifact_name'].apply(parse_github)
df_go['likely_package_repo_owner'] = df_go['package_repo_name'].apply(
    lambda x: x.split('/')[0] if isinstance(x, str) else None
)
df_go.tail()
# Out:
#       repo_owner             repo_name  \
# 13801   ethereum  ethereum/go-ethereum
# 13802   ethereum  ethereum/go-ethereum
# 13803   ethereum  ethereum/go-ethereum
# 13804   ethereum  ethereum/go-ethereum
# 13805   ethereum  ethereum/go-ethereum
#
#                                 package_artifact_name package_artifact_source  \
# 13801                           github.com/cespare/cp                      GO
# 13802                     github.com/protolambda/ztyp                      GO
# 13803  github.com/azure/azure-sdk-for-go/sdk/internal                      GO
# 13804                        go.uber.org/automaxprocs                      GO
# 13805       github.com/aws/aws-sdk-go-v2/internal/ini                      GO
#
#             package_repo_name likely_package_repo_owner
# 13801              cespare/cp                   cespare
# 13802        protolambda/ztyp               protolambda
# 13803  azure/azure-sdk-for-go                     azure
# 13804                    None                      None
# 13805       aws/aws-sdk-go-v2                       aws

# %% [markdown]
# ## Lookup Python packages

# %%
df_py = df_sbom[df_sbom['package_artifact_source'] == 'PIP'].copy()
py_pkgs_all = df_py['package_artifact_name'].dropna().unique()

# %%
py_pkg_lookup = client.query(f"""
    WITH github_data AS (
      SELECT DISTINCT
        LOWER(name) AS package_name,
        LOWER(REGEXP_EXTRACT(url, r'github\.com/([^/]+)/')) AS github_owner,
        LOWER(REGEXP_EXTRACT(url, r'github\.com/[^/]+/([^/.]+)')) AS github_repo
      FROM `bigquery-public-data.pypi.distribution_metadata`,
      UNNEST(project_urls) AS url
      WHERE url LIKE '%github.com/%'

      UNION ALL

      SELECT DISTINCT
        LOWER(name) AS package_name,
        LOWER(REGEXP_EXTRACT(home_page, r'github\.com/([^/]+)/')) AS github_owner,
        LOWER(REGEXP_EXTRACT(home_page, r'github\.com/[^/]+/([^/.]+)')) AS github_repo
      FROM `bigquery-public-data.pypi.distribution_metadata`
      WHERE home_page LIKE '%github.com/%'
    )
    
    SELECT DISTINCT
      package_name,
      github_owner,
      github_repo
    FROM github_data
    WHERE package_name IN ({stringify_array(py_pkgs_all)})
""")
df_py_pkg = py_pkg_lookup.to_dataframe()

# %%
df_py_pkg['package_repo_name'] = df_py_pkg.apply(
    lambda x: f"{x['github_owner']}/{x['github_repo']}".strip("'")
              if x['github_owner'] and x['github_repo']
              else None,
    axis=1
)
py_mapper = (
    df_py_pkg[['package_name', 'package_repo_name']]
    .dropna()
    .drop_duplicates()
    .set_index('package_name')['package_repo_name']
    .to_dict()
)
df_py['package_repo_name'] = df_py['package_artifact_name'].map(py_mapper)
df_py['likely_package_repo_owner'] = df_py['package_repo_name'].apply(
    lambda x: x.split('/')[0] if isinstance(x, str) else None
)

df_py.tail()
# Out:
#         repo_owner                       repo_name package_artifact_name  \
# 13280     ethereum                ethereum/web3.py        types-requests
# 13421    status-im           status-im/nimbus-eth2                pep517
# 13422    status-im           status-im/nimbus-eth2             pip-tools
# 13423    status-im           status-im/nimbus-eth2               debugpy
# 13432  safe-global  safe-global/safe-smart-account           certora-cli
#
#       package_artifact_source   package_repo_name likely_package_repo_owner
# 13280                     PIP     python/typeshed                    python
# 13421                     PIP         pypa/pep517                      pypa
# 13422                     PIP      nvie/pip-tools                      nvie
# 13423                     PIP   microsoft/debugpy                 microsoft
# 13432                     PIP  certora/certoracli                   certora

# %% [markdown]
# ## Lookup Rust

# %%
df_rust = df_sbom[df_sbom['package_artifact_source'] == 'RUST'].copy()
rust_pkgs_all = df_rust['package_artifact_name'].dropna().unique()

# %%
rust_pkg_lookup = client.query(f"""
    select distinct
      name,
      lower(repository) as repository
    from `crates.crates`
    where
        name in ({stringify_array(rust_pkgs_all)})
        and repository is not null
""")
rust_py_pkg = rust_pkg_lookup.to_dataframe()
rust_py_pkg['package_repo_name'] = rust_py_pkg['repository'].apply(parse_github)
rust_py_pkg.tail(5)
# Out:
#                     name                                 repository  \
# 1045     crossbeam-deque  https://github.com/crossbeam-rs/crossbeam
# 1046     crossbeam-epoch  https://github.com/crossbeam-rs/crossbeam
# 1047     crossbeam-utils  https://github.com/crossbeam-rs/crossbeam
# 1048   crossbeam-channel  https://github.com/crossbeam-rs/crossbeam
# 1049  crossbeam-skiplist  https://github.com/crossbeam-rs/crossbeam
#
#            package_repo_name
# 1045  crossbeam-rs/crossbeam
# 1046  crossbeam-rs/crossbeam
# 1047  crossbeam-rs/crossbeam
# 1048  crossbeam-rs/crossbeam
# 1049  crossbeam-rs/crossbeam

# %%
df_rust = df_sbom[df_sbom['package_artifact_source'] == 'RUST'].copy()

crates_mapper = (
    rust_py_pkg[['name', 'package_repo_name']]
    .dropna()
    .drop_duplicates()
    .set_index('name')['package_repo_name']
    .to_dict()
)
df_rust['package_repo_name'] = df_rust['package_artifact_name'].map(crates_mapper)
df_rust['likely_package_repo_owner'] = df_rust['package_repo_name'].apply(
    lambda x: x.split('/')[0] if isinstance(x, str) else None
)

df_rust.tail()
# Out:
#         repo_owner         repo_name package_artifact_name  \
# 13504  paradigmxyz  paradigmxyz/reth              httparse
# 13505  paradigmxyz  paradigmxyz/reth           simple_asn1
# 13506  paradigmxyz  paradigmxyz/reth        ws_stream_wasm
# 13507  paradigmxyz  paradigmxyz/reth                   rlp
# 13508  paradigmxyz  paradigmxyz/reth                 c-kzg
#
#       package_artifact_source         package_repo_name  \
# 13504                    RUST      seanmonstar/httparse
# 13505                    RUST           acw/simple_asn1
# 13506                    RUST  najamelan/ws_stream_wasm
# 13507                    RUST  paritytech/parity-common
# 13508                    RUST                       NaN
#
#       likely_package_repo_owner
# 13504               seanmonstar
# 13505                       acw
# 13506                 najamelan
# 13507                paritytech
# 13508                      None

# %% [markdown]
# ## Lookup NPM

# %%
df_npm = df_sbom[df_sbom['package_artifact_source'] == 'NPM'].copy()
npm_pkgs_all = sorted(df_npm['package_artifact_name'].unique())
len(npm_pkgs_all)
# Out:
# 4750

# %%
# create a registry from deps.dev

q = """
SELECT
  Name as package_name,
  (SELECT lower(URL) 
   FROM UNNEST(Links) 
   WHERE REGEXP_CONTAINS(URL, r'github\.com')
   LIMIT 1) AS package_github_url
FROM `bigquery-public-data.deps_dev_v1.PackageVersionsLatest`
WHERE
  System = 'NPM'
  AND SnapshotAt >= '2024-11-01'
  AND ARRAY_LENGTH(Links) > 0
"""

# save it to static_data_sources.npm_registry

# %%
npm_pkg_lookup = client.query(f"""
    SELECT DISTINCT
      package_name,
      package_github_url
    FROM `static_data_sources.npm_registry`
    WHERE package_name in ({stringify_array(npm_pkgs_all)})
""")
df_npm_pkg = npm_pkg_lookup.to_dataframe()

# %%
df_npm_pkg['package_repo_name'] = df_npm_pkg['package_github_url'].apply(parse_github)
npm_mapper = (
    df_npm_pkg[['package_name', 'package_repo_name']]
    .dropna()
    .drop_duplicates()
    .set_index('package_name')['package_repo_name']
    .to_dict()
)
df_npm['package_repo_name'] = df_npm['package_artifact_name'].map(npm_mapper)

df_npm['namespace'] = df_npm['package_artifact_name'].apply(extract_namespace)
namespace_to_owner = {}
for package_name, repo_name in npm_mapper.items():
    namespace = extract_namespace(package_name)
    if namespace and repo_name:
        github_owner = repo_name.split('/')[0]
        namespace_to_owner.update({namespace:github_owner})

df_npm['likely_package_repo_owner'] = df_npm['namespace'].map(namespace_to_owner)
df_npm.loc[df_npm['package_repo_name'].notna(), 'likely_package_repo_owner'] = df_npm['package_repo_name'].str.split('/').str[0]
df_npm.drop(columns='namespace', inplace=True)
df_npm.tail()
# Out:
#       repo_owner     repo_name   package_artifact_name  \
# 13792       web3  web3/web3.js             use-sidecar
# 13793       web3  web3/web3.js        @nodelib/fs.walk
# 13794       web3  web3/web3.js  available-typed-arrays
# 13795       web3  web3/web3.js           which-pm-runs
# 13796       web3  web3/web3.js                     not
#
#       package_artifact_source                  package_repo_name  \
# 13792                     NPM              thekashey/use-sidecar
# 13793                     NPM                    nodelib/nodelib
# 13794                     NPM  inspect-js/available-typed-arrays
# 13795                     NPM              zkochan/which-pm-runs
# 13796                     NPM                         raynos/not
#
#       likely_package_repo_owner
# 13792                 thekashey
# 13793                   nodelib
# 13794                inspect-js
# 13795                   zkochan
# 13796                    raynos

# %% [markdown]
# # Consolidate back into a single graph

# %%
df = pd.concat([df_npm,df_go,df_rust,df_py], axis=0, ignore_index=True)
df.fillna('', inplace=True)
df.rename(columns={
    'repo_name': 'seed_repo_name',
    'repo_owner': 'seed_repo_owner',
    'package_artifact_name': 'package_name',
    'package_artifact_source': 'package_source',
    'likely_package_repo_owner': 'package_repo_owner'
}, inplace=True)
df = df[[
    'seed_repo_name', 'seed_repo_owner', 'package_name', 
    'package_repo_owner', 'package_repo_name', 'package_source'
]]
df
# Out:
#                            seed_repo_name seed_repo_owner  \
# 0      eth-infinitism/account-abstraction  eth-infinitism
# 1      eth-infinitism/account-abstraction  eth-infinitism
# 2      eth-infinitism/account-abstraction  eth-infinitism
# 3      eth-infinitism/account-abstraction  eth-infinitism
# 4      eth-infinitism/account-abstraction  eth-infinitism
# ...                                   ...             ...
# 13801                    ethereum/web3.py        ethereum
# 13802               status-im/nimbus-eth2       status-im
# 13803               status-im/nimbus-eth2       status-im
# 13804               status-im/nimbus-eth2       status-im
# 13805      safe-global/safe-smart-account     safe-global
#
#                       package_name package_repo_owner  \
# 0                 @eslint/eslintrc             eslint
# 1      @types/http-cache-semantics    definitelytyped
# 2                        esrecurse            estools
# 3          typed-array-byte-length         inspect-js
# 4                   fetch-ponyfill             qubyte
# ...                            ...                ...
# 13801               types-requests             python
# 13802                       pep517               pypa
# 13803                    pip-tools               nvie
# 13804                      debugpy          microsoft
# 13805                  certora-cli            certora
#
#                         package_repo_name package_source
# 0                         eslint/eslintrc            NPM
# 1         definitelytyped/definitelytyped            NPM
# 2                       estools/esrecurse            NPM
# 3      inspect-js/typed-array-byte-length            NPM
# 4                   qubyte/fetch-ponyfill            NPM
# ...                                   ...            ...
# 13801                     python/typeshed            PIP
# 13802                         pypa/pep517            PIP
# 13803                      nvie/pip-tools            PIP
# 13804                   microsoft/debugpy            PIP
# 13805                  certora/certoracli            PIP
#
# [13806 rows x 6 columns]

# %%
for pkg in PACKAGE_SERVERS:
    print(f"\n### Most Popular {pkg} Packages ###")
    pkg_lst = df[(df['package_source']==pkg) & (df['package_repo_owner'] != '')]['package_repo_name'].value_counts()
    nth = int(len(pkg_lst) * (0.025 if pkg == 'NPM' else 0.1))
    pkg_lst_top = list(pkg_lst.head(nth).index)
    print(pkg_lst_top)
# Out:
# ### Most Popular NPM Packages ###
# ['babel/babel', 'definitelytyped/definitelytyped', 'ethers-io/ethers', 'lerna/lerna', 'lodash/lodash', 'evanw/esbuild', 'ethereumjs/ethereumjs-monorepo', 'micromark/micromark', 'facebook/jest', 'streetsidesoftware/cspell-dicts', 'chainsafe/web3', 'facebook/docusaurus', 'radix-ui/primitives', 'typescript-eslint/typescript-eslint', 'ben-eb/cssnano', 'jestjs/jest', '', 'xtuc/webassemblyjs', 'cssnano/cssnano', 'ethereum/web3', 'nrwl/nx', 'nomicfoundation/solidity-analyzer', 'rollup/rollup', 'napi-rs/node-rs', 'smooth-code/svgr', 'ardatan/graphql-tools', 'swc-project/swc', 'algolia/algoliasearch-client-javascript', 'tsconfig/bases', 'getsentry/sentry-javascript', 'blakeembrey/change-case', 'nodelib/nodelib', 'stablelib/stablelib', 'vitest-dev/vitest', 'achingbrain/it', 'tootallnate/proxy-agents', 'streetsidesoftware/cspell', 'webdriverio/webdriverio', 'walletconnect/walletconnect-utils', 'gregberge/svgr', 'ethereumjs/ethereumjs-vm', 'chainsafe/lodestar', 'brooooooklyn/snappy', 'parcel-bundler/watcher', 'algolia/autocomplete', 'es-shims/object', 'nodejs/undici', 'eslint/js', 'babel/babel-polyfills', 'nomicfoundation/hardhat', 'web3modal/web3modal', 'sigstore/sigstore-js', 'sboudrias/inquirer', 'zloirock/core-js', 'es-shims/array', 'es-shims/string', 'dcodeio/protobuf', 'dotansimha/graphql-code-generator', 'nodeca/js-yaml', 'rollup/plugins', 'feross/ieee754', 'xtuc/js-webassembly-interpreter', 'coolaj86/nodejs-libs-4-browser', 'ethereum/remix-plugin', 'facebook/react', 'npm/security-holder', 'biomejs/biome', 'facebook/regenerator', 'chainsafe/swap-or-not-shuffle', 'conventional-changelog/conventional-changelog', 'getsentry/raven-js', 'import-js/eslint-plugin-import', 'algolia/algoliasearch-client-js', 'chainsafe/blst-ts', 'formatjs/formatjs', 'webpack/webpack-cli', 'libp2p/js-libp2p', 'inikulin/parse5', 'azure/azure-sdk-for-js', 'npm/wrappy']
#
# ### Most Popular RUST Packages ###
# ['libp2p/rust-libp2p', 'microsoft/windows-rs', 'unicode-org/icu4x', 'alloy-rs/alloy', 'rust-lang/futures-rs', 'rustcrypto/traits', 'rustcrypto/formats', 'rustwasm/wasm-bindgen', 'rustcrypto/utils', 'tokio-rs/tracing', 'rust-cli/anstyle', 'paritytech/parity-common', 'rustcrypto/hashes', 'crossbeam-rs/crossbeam', 'servo/rust-url', 'paritytech/libsecp256k1', 'tokio-rs/tokio', 'clap-rs/clap', 'toml-rs/toml', 'dalek-cryptography/curve25519-dalek', 'alloy-rs/core', 'rustcrypto/elliptic-curves', 'paritytech/jsonrpsee', 'plotters-rs/plotters', 'quinn-rs/quinn', 'rust-lang/regex', 'time-rs/time', 'rust-random/rand', 'teddriggs/darling', 'enarx/ciborium', 'tower-rs/tower', 'rustcrypto/signatures', 'tikv/jemallocator', 'amanieu/parking_lot', 'ia0/data-encoding', 'retep998/winapi-rs', 'boa-dev/boa', 'arkworks-rs/algebra', 'dtolnay/thiserror', 'rustcrypto/universal-hashes', 'rust-phf/rust-phf', 'kornelski/rust-security-framework', 'serde-rs/serde', 'strawlab/iana-time-zone', 'diesel-rs/diesel', 'hyperium/http-body', 'rusticata/asn1-rs', 'rayon-rs/rayon', 'taiki-e/pin-project', 'xdg-rs/dirs', 'google/zerocopy', 'bheisler/criterion', 'paritytech/parity-scale-codec', 'ferrilab/ferrilab', 'gyscos/zstd-rs', 'jonasbb/serde_with', 'peternator7/strum', 'servo/core-foundation-rs', 'alloy-rs/op-alloy', 'vorner/signal-hook', 'jeltef/derive_more', 'gakonst/ethers-rs', 'rustcrypto/aeads', 'tokio-rs/axum', 'rustcrypto/password-hashes', 'sfackler/foreign-types', 'alloy-rs/rlp', 'rust-random/rngs']
#
# ### Most Popular GO Packages ###
# ['aws/aws-sdk-go-v2', 'cespare/xxhash', 'deckarep/golang-set', 'hashicorp/golang-lru', 'supranational/blst', 'gofrs/flock', 'jackpal/go-nat-pmp', 'tklauser/go-sysconf', 'davecgh/go-spew', 'minio/sha256-simd', 'holiman/bloomfilter', 'mattn/go-isatty', 'google/gofuzz', 'klauspost/compress', 'gogo/protobuf', 'google/pprof', 'rivo/uniseg', 'pion/transport', 'tklauser/numcpus', 'holiman/uint256', 'gorilla/websocket', 'consensys/gnark-crypto', 'go-ole/go-ole', 'mitchellh/mapstructure', 'pkg/errors', 'mattn/go-runewidth', 'russross/blackfriday', 'xrash/smetrics', 'stretchr/testify', 'pmezard/go-difflib', 'golang/snappy', 'prometheus/client_golang']
#
# ### Most Popular PIP Packages ###
# ['sponsors/hynek', 'sphinx-doc/sphinx', 'pypa/wheel', 'python/typing', 'ipython/ipython', 'pypa/packaging', 'python/importlib_metadata', 'gristlabs/asttokens', 'ethereum/eth-hash', 'lepture/mistune', 'dateutil/dateutil', 'hsoft/send2trash']

# %%
owners = list(df['package_repo_owner'].unique())
len(owners)
# Out:
# 1807

# %%
owner_lookup = client.query(f"""
    SELECT
      artifact_namespace as owner,
      COUNT(distinct artifact_id) AS oso_artifacts_owned
    FROM `oso.artifacts_v1`
    WHERE artifact_namespace in ({stringify_array(owners)})
    GROUP BY 1
""")

owners_on_oso = [row['owner'] for row in owner_lookup]
df['package_repo_owner_is_on_oso'] = df['package_repo_owner'].apply(lambda x: x in owners_on_oso)
df['package_repo_owner_is_on_oso'].mean()
# Out:
# 0.6926698536868029

# %%
df.to_csv('data/unweighted_graph.csv')

# %% [markdown]
# # Create a network graph

# %%
import json
import networkx as nx

# %%
dff = df[df['package_repo_owner'] != ''].copy()
len(dff) / len(df)
# Out:
# 0.9811676082862524

# %%
gh = 'https://github.com/'
dff['source'] = dff['seed_repo_name'].apply(lambda x: f'{gh}{x}')
dff['target'] = dff.apply(
    lambda x: f"{gh}{x['package_repo_name']}"
              if x['package_repo_name'] != ''
              else f"{gh}{x['package_repo_owner']}"
    , axis=1)
dff
# Out:
#                            seed_repo_name seed_repo_owner  \
# 0      eth-infinitism/account-abstraction  eth-infinitism
# 1      eth-infinitism/account-abstraction  eth-infinitism
# 2      eth-infinitism/account-abstraction  eth-infinitism
# 3      eth-infinitism/account-abstraction  eth-infinitism
# 4      eth-infinitism/account-abstraction  eth-infinitism
# ...                                   ...             ...
# 13801                    ethereum/web3.py        ethereum
# 13802               status-im/nimbus-eth2       status-im
# 13803               status-im/nimbus-eth2       status-im
# 13804               status-im/nimbus-eth2       status-im
# 13805      safe-global/safe-smart-account     safe-global
#
#                       package_name package_repo_owner  \
# 0                 @eslint/eslintrc             eslint
# 1      @types/http-cache-semantics    definitelytyped
# 2                        esrecurse            estools
# 3          typed-array-byte-length         inspect-js
# 4                   fetch-ponyfill             qubyte
# ...                            ...                ...
# 13801               types-requests             python
# 13802                       pep517               pypa
# 13803                    pip-tools               nvie
# 13804                      debugpy          microsoft
# 13805                  certora-cli            certora
#
#                         package_repo_name package_source  \
# 0                         eslint/eslintrc            NPM
# 1         definitelytyped/definitelytyped            NPM
# 2                       estools/esrecurse            NPM
# 3      inspect-js/typed-array-byte-length            NPM
# 4                   qubyte/fetch-ponyfill            NPM
# ...                                   ...            ...
# 13801                     python/typeshed            PIP
# 13802                         pypa/pep517            PIP
# 13803                      nvie/pip-tools            PIP
# 13804                   microsoft/debugpy            PIP
# 13805                  certora/certoracli            PIP
#
#        package_repo_owner_is_on_oso  \
# 0                              True
# 1                              True
# 2                             False
# 3                             False
# 4                              True
# ...                             ...
# 13801                          True
# 13802                         False
# 13803                          True
# 13804                          True
# 13805                          True
#
#                                                   source  \
# 0      https://github.com/eth-infinitism/account-abst...
# 1      https://github.com/eth-infinitism/account-abst...
# 2      https://github.com/eth-infinitism/account-abst...
# 3      https://github.com/eth-infinitism/account-abst...
# 4      https://github.com/eth-infinitism/account-abst...
# ...                                                  ...
# 13801                https://github.com/ethereum/web3.py
# 13802           https://github.com/status-im/nimbus-eth2
# 13803           https://github.com/status-im/nimbus-eth2
# 13804           https://github.com/status-im/nimbus-eth2
# 13805  https://github.com/safe-global/safe-smart-account
#
#                                                   target
# 0                     https://github.com/eslint/eslintrc
# 1      https://github.com/definitelytyped/definitelyt...
# 2                   https://github.com/estools/esrecurse
# 3      https://github.com/inspect-js/typed-array-byte...
# 4               https://github.com/qubyte/fetch-ponyfill
# ...                                                  ...
# 13801                 https://github.com/python/typeshed
# 13802                     https://github.com/pypa/pep517
# 13803                  https://github.com/nvie/pip-tools
# 13804               https://github.com/microsoft/debugpy
# 13805              https://github.com/certora/certoracli
#
# [13546 rows x 9 columns]

# %%
G = nx.DiGraph()

for repo in dff['seed_repo_name'].unique():
    repo_url = f"{gh}{repo}"
    G.add_node(repo_url, level=1)
    
for repo in dff['package_repo_name'].unique():
    repo_url = f"{gh}{repo}"
    if repo_url not in G.nodes:
        G.add_node(repo_url, level=2)
        
for _, row in dff.iterrows():
    G.add_edge(row['source'], row['target'], relation=row['package_source'])
    
total_edges = G.number_of_edges()
global_weight = 1.0 / total_edges
for u, v in G.edges:
    G[u][v]['weight'] = global_weight
    
total_weight = sum(data['weight'] for _, _, data in G.edges(data=True))
print(f"Total Weight of All Edges: {total_weight:.5f}")    
    
graph_json = nx.node_link_data(G)
output_path = "data/unweighted_graph.json"
with open(output_path, "w") as f:
    json.dump(graph_json, f, indent=2)
# Out:
# Total Weight of All Edges: 1.00000
