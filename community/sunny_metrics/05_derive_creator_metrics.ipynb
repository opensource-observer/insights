# %% [markdown]
# # Creator Metrics
#
# This script processes a CSV from [this Dune Query](https://dune.com/queries/4087193) and derives metrics the following NFT creator metrics:
#
# - num drops
# - num unique minters
# - num txns
# - USD value of txns

# %%
from dotenv import load_dotenv
from dune_client.types import QueryParameter
from dune_client.client import DuneClient
from dune_client.query import QueryBase
from google.cloud import bigquery
import json
import os
import pandas as pd
# Out:
# 2025-02-05 23:07:42,032 INFO numexpr.utils NumExpr defaulting to 8 threads.

# %%
load_dotenv()

PROJECT = 'opensource-observer'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "../../oso_gcp_credentials.json"
client = bigquery.Client()


DUNE_API_KEY = os.getenv('DUNE_API_KEY')
dune = DuneClient(DUNE_API_KEY)

# %% [markdown]
# ## Part 1. Parse the creator data

# %%
apps = pd.read_csv('data/apps/creator_apps.csv', index_col=0)
apps = apps.drop(columns=['chain']).drop_duplicates()
uuid_to_address_mapper = apps.set_index('uuid')['address'].to_dict()
uuid_list = list(apps['uuid'].unique())
address_list = list(apps['address'].unique())
apps.tail(1)
# Out:
#                                       uuid  \
# 1572  568706f3-8127-448f-b0b1-56c28e4f3ed1
#
#                                        recipient project_type  category  \
# 1572  0xf56E55e35d2CCa5A34F5Ba568454974424aEA0F4      Creator  Art NFTs
#
#                                          address
# 1572  0xf56e55e35d2cca5a34f5ba568454974424aea0f4

# %%
all_apps = pd.read_csv('data/apps/applications_reviewed.csv')
all_apps = all_apps[all_apps['uuid'].isin(uuid_list)]
uuid_to_profile_mapper = all_apps.set_index('uuid')['profile_name'].to_dict()
uuid_to_name_mapper = all_apps.set_index('uuid')['name'].to_dict()
uuid_to_id_mapper = all_apps.set_index('uuid')['id'].to_dict()
all_apps.tail(1)
# Out:
#                                       uuid  \
# 1722  568706f3-8127-448f-b0b1-56c28e4f3ed1
#
#                               charmverseId  \
# 1722  568706f3-8127-448f-b0b1-56c28e4f3ed1
#
#                                      agoraProjectRefUID  \
# 1722  0x2b24be9c82b7cbd266af7a2a27fbd3213c98bd93c01d...
#
#                                                      id  \
# 1722  0xb07fdf1ede14ea0abf845c015d4ad73f336e50acb273...
#
#                                        recipient        time   name   status  \
# 1722  0xf56E55e35d2CCa5A34F5Ba568454974424aEA0F4  1725398873  面白い事実  pending
#
#        profile_name                         profile_url  ... chain_id  \
# 1722  music-guy.eth  https://warpcast.com/music-guy.eth  ...      NaN
#
#                chain flag_multiple_projects_same_profile  \
# 1722  All Superchain                               False
#
#      flag_creator_no_address flag_app_missing_contract  \
# 1722                   False                     False
#
#      flag_channel_no_channel  flag_charmverse_in_name  \
# 1722                   False                    False
#
#      flag_creator_address_conflict  count_flags  has_flag
# 1722                         False            0         0
#
# [1 rows x 26 columns]

# %%
#all_apps[all_apps['name'].str.contains('Kismet')].T
len(all_apps)
# Out:
# 525

# %%
app_dict = {}
for _,app in apps.iterrows():
    recipient = app['recipient'].lower()
    uuid = app['uuid']
    minting_address = app['address'].lower()
    if recipient not in app_dict:
        app_dict.update({
            recipient: {
                'mintingAddressList': [minting_address],
                'uuidList': [uuid]
            }
        })
    else:
        app_dict[recipient]['mintingAddressList'].append(minting_address)
        app_dict[recipient]['uuidList'].append(uuid)

app_json = []        
for recipient, record in app_dict.items():
    app_json.append({
        'recipientAddress': recipient,
        'mintingAddressList': list(set(record['mintingAddressList'])),
        'uuidList': list(set(record['uuidList'])),
    })
        
with open("data/apps/creator_address_to_uuid.json", "w") as f:
    json.dump(app_json, f, indent=2)

# %%
farcaster_df = pd.read_parquet('data/raw_metric_data/farcaster.parquet')
fids = farcaster_df.set_index('address')['fid'].to_dict()

# %% [markdown]
# ## Part 2. Look for NFT deployments from factories

# %%
factories_path = 'data/raw_metric_data/oso_raw_creator_factories.csv'
oso_creator_addresses_str = "'" +  "','".join(address_list) + "'"

query = f"""
    select distinct
        originating_address as creator_address,
        contract_address as nft_contract_address,
        lower(network) as blockchain
    from `{PROJECT}.oso.int_factories`
    where originating_address in ({oso_creator_addresses_str})    
"""

result = client.query(query)
print("Query completed.")
factories_df = result.to_dataframe()

print("Dataframe loaded.")
factories_df.set_index('nft_contract_address', drop=True).to_csv(factories_path)

# with open(factories_path) as file:
#     data = file.read()

# table = dune.upload_csv(
#     data=str(data),
#     description="Creator-deployed NFT contracts",
#     table_name="sunny_creator_contracts",
#     is_private=False
# )

factories_df = pd.read_csv(factories_path, index_col=0)
factories_df.tail(1)
# Out:
# Query completed.
# Dataframe loaded.
#                                                                        creator_address  \
# nft_contract_address
# 0xb9295dd14923649b8c606f3c07f65fe27623404d  0xfe952def1c0e295048374ccd0b8ebe7001f1123e
#
#                                            blockchain
# nft_contract_address
# 0xb9295dd14923649b8c606f3c07f65fe27623404d   optimism

# %% [markdown]
# ## Part 3. Grab NFT mint data from Dune

# %%
creator_addresses_str = ',\n\t\t'.join(address_list)
query_sql = f"""

with nft_creators as (
    select
        nft_contract_address,
        blockchain,
        min_by(tx_from, block_number) as creator_address
    from nft.mints
    where
        block_date between date('2024-01-01') and date('2024-09-01')
        and blockchain in ('base', 'optimism', 'zora')
    group by 1,2
    
    union all
    
    select
        nft_contract_address,
        blockchain,
        creator_address
    from dune.gitcoin_dao.dataset_sunny_creator_contracts
)

select
    nft_creators.creator_address,
    nft_creators.nft_contract_address,
    nft_creators.blockchain,
    count(distinct case when block_date > date('2024-06-01') then m.tx_hash end) as num_txns_90D,
    count(distinct m.tx_hash) as num_txns_180D,
    sum(case when block_date > date('2024-06-01') then coalesce(m.amount_usd,0) else 0 end) as amount_usd_90D,
    sum(coalesce(m.amount_usd,0)) as amount_usd_180D,
    array_agg(distinct case when block_date > date('2024-06-01') then m.buyer end) as buyers_90D,
    array_agg(distinct m.buyer) as buyers_180D
from nft.mints as m
join nft_creators
    on m.nft_contract_address = nft_creators.nft_contract_address
    and m.blockchain = nft_creators.blockchain
where
    m.block_date between date('2024-02-01') and date('2024-09-01')
    and nft_creators.creator_address in (
                {creator_addresses_str}
    )
group by 1,2,3

"""

query_id = dune.create_query(name='sunny_nft_mints', query_sql=query_sql, is_private=False)
print(query_id.base.query_id)
# Out:
# 4674835

# %%
query = QueryBase(name='sunny_nft_mints', query_id=query_id.base.query_id)
results_df = dune.run_query_dataframe(query)
results_df.to_parquet('data/raw_metric_data/dune_raw_nft_mints.parquet')
# Out:
# 2025-02-05 23:07:48,800 INFO dune_client.api.base executing 4674835 on medium cluster
# 2025-02-05 23:07:49,059 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.PENDING (queue position: 3)
# 2025-02-05 23:07:50,216 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:51,352 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:52,478 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:53,607 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:54,737 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:55,859 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:56,985 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:58,114 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:07:59,245 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:00,369 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:01,548 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:02,678 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:03,813 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:04,952 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:06,072 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:07,197 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:08,325 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:09,448 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:10,596 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:11,728 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:12,857 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:14,009 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:15,141 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:16,277 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:17,407 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:18,556 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:19,683 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:20,801 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:21,921 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:23,047 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:24,178 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:25,303 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:26,434 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:27,559 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:28,691 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:29,816 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:30,945 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:32,081 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:33,212 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING
# 2025-02-05 23:08:34,362 INFO dune_client.api.base waiting for query execution 01JKCQ2KDDS1CF65AE2WFB90T9 to complete: ExecutionState.EXECUTING

# %%
nft_creators = pd.read_parquet('data/raw_metric_data/dune_raw_nft_mints.parquet')

nft_creators['blockchain'] = nft_creators['blockchain'].apply(lambda x: x.title())

def clean_lst(lst_str):
    lst_str = lst_str.replace("[","").replace("]","")
    lst = lst_str.split(" ")
    lst = [x for x in lst if x[:2] == '0x']
    return lst

nft_creators['buyers_90D'] = nft_creators['buyers_90D'].apply(clean_lst)
nft_creators['buyers_180D'] = nft_creators['buyers_180D'].apply(clean_lst)

def map_fids(lst_addr):
    return [x for x in set([fids.get(x) for x in lst_addr]) if x is not None]

nft_creators['list_of_fids_90D'] = nft_creators['buyers_90D'].apply(map_fids)
nft_creators['list_of_fids_180D'] = nft_creators['buyers_180D'].apply(map_fids)

nft_creators.tail(1).T
# Out:
#                                                               2756
# creator_address         0xe06383ece7b8bbb6c3f65a95fc2b6450e9077a6c
# nft_contract_address    0x697632065343efb386fade0c241d9af5c87844c7
# blockchain                                                    Base
# num_txns_90D                                                     1
# num_txns_180D                                                    1
# amount_usd_90D                                                 0.0
# amount_usd_180D                                                0.0
# buyers_90D            [0xe06383ece7b8bbb6c3f65a95fc2b6450e9077a6c]
# buyers_180D           [0xe06383ece7b8bbb6c3f65a95fc2b6450e9077a6c]
# list_of_fids_90D                                          [283144]
# list_of_fids_180D                                         [283144]

# %% [markdown]
# ## Part 4. Derive the metrics

# %%
metrics_by_address = pd.concat([
    nft_creators.groupby('creator_address')['nft_contract_address'].nunique().rename('num_drops'),

    nft_creators.groupby('creator_address')['buyers_90D'].agg(lambda x: len(set().union(*x))).rename('num_unique_minters_90D'),
    nft_creators.groupby('creator_address')['buyers_180D'].agg(lambda x: len(set().union(*x))).rename('num_unique_minters_180D'),

    nft_creators.groupby('creator_address')['list_of_fids_90D'].agg(lambda x: len(set().union(*x))).rename('num_farcaster_minters_90D'),
    nft_creators.groupby('creator_address')['list_of_fids_180D'].agg(lambda x: len(set().union(*x))).rename('num_farcaster_minters_180D'),

    nft_creators.groupby('creator_address')['num_txns_90D'].sum().rename('num_transactions_90D'),
    nft_creators.groupby('creator_address')['num_txns_180D'].sum().rename('num_transactions_180D'),
        
    nft_creators.groupby('creator_address')['amount_usd_90D'].sum().rename('usd_value_of_transactions_90D'),
    nft_creators.groupby('creator_address')['amount_usd_180D'].sum().rename('usd_value_of_transactions_180D')
], axis=1)
metrics_by_address
# Out:
#                                             num_drops  num_unique_minters_90D  \
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09          6                       8
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5          2                       1
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf          3                      31
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe          1                       5
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6          4                       2
# ...                                               ...                     ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c          7                    2884
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08          6                  135042
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac          4                      21
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f          1                      19
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e         16                       1
#
#                                             num_unique_minters_180D  \
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09                       59
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5                        1
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf                       98
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe                       38
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6                       10
# ...                                                             ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c                     2884
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08                   141811
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac                       35
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f                       19
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e                       10
#
#                                             num_farcaster_minters_90D  \
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09                          1
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5                          1
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf                         26
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe                          5
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6                          2
# ...                                                               ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c                       1051
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08                      15264
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac                         18
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f                         16
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e                          1
#
#                                             num_farcaster_minters_180D  \
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09                           8
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5                           1
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf                          83
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe                          28
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6                          10
# ...                                                                ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c                        1051
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08                       19146
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac                          29
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f                          16
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e                           2
#
#                                             num_transactions_90D  \
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09                    11
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5                     2
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf                    65
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe                     5
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6                     3
# ...                                                          ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c                  3053
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08                118014
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac                    15
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f                    20
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e                     5
#
#                                             num_transactions_180D  \
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09                     69
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5                      3
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf                    198
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe                     72
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6                     35
# ...                                                           ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c                   3054
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08                 127320
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac                     55
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f                     20
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e                     27
#
#                                             usd_value_of_transactions_90D  \
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09                    3201.237005
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5                       0.371670
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf                       6.110765
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe                       0.000000
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6                       0.000000
# ...                                                                   ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c                    7256.926583
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08                       0.000000
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac                      95.217809
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f                      52.761224
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e                       0.000000
#
#                                             usd_value_of_transactions_180D
# creator_address
# 0x00409fc839a2ec2e6d12305423d37cd011279c09                    46268.158249
# 0x010e0dc4af75b1b5ae4a04601dfab3a7dd27bda5                        0.371670
# 0x0438053b82cb27004bd80d3ca18b8ef6b23f20cf                        6.110765
# 0x05a7eb929209f5c1f2f08dd087b64bb1beba99fe                        4.334526
# 0x05e0ccdee8e642388da4478facc6ac7c496714f6                        0.000000
# ...                                                                    ...
# 0xf8c80ebf80ff0c17bdfbc08a91e64a890aae8e3c                     7256.926583
# 0xf977a728f3aa00885b2de0a106f8ae69d17adb08                   162606.466195
# 0xf981a7a6b3796bf02425fd64fd80093b6fc5b2ac                      777.535558
# 0xfc9307d74c87a48b504e74f92b034b1484561d9f                       52.761224
# 0xfe952def1c0e295048374ccd0b8ebe7001f1123e                       37.356529
#
# [294 rows x 9 columns]

# %%
metrics = []
errors = []
for uuid, app in apps.set_index('uuid').iterrows():
    
    name = uuid_to_name_mapper.get(uuid)
    address = app['address']
    recipient = app['recipient']
    
    if address not in metrics_by_address.index:
        errors.append({
            'uuid': uuid,
            **app,
            'status': 'no_nft_activity_90D'
        })
        continue
    
    creator_metrics = metrics_by_address.loc[address].to_dict()
    
    metrics.append({
        'uuid': uuid,
        **app,
        'status': 'metrics_available',
        **creator_metrics,
    })

# %%
df_metrics = pd.DataFrame(metrics)
df_metrics.to_csv('data/clean_metric_data/metrics_creators.csv')

# %% [markdown]
# ## Part 5. Derive metrics by recipient address

# %%
recipient_mapping = (
    all_apps
    .groupby(['recipient', 'profile_name'])
    ['address']
    .unique()
    .apply(list)
    .to_dict()
)

# %%
recipient_metrics = []
for (recipient,profile_name),address_list in recipient_mapping.items():

    dff = nft_creators[nft_creators.creator_address.isin(address_list)]
    if len(dff) < 1:
        continue

    uuid_list =  all_apps[(all_apps['recipient'] == recipient) & (all_apps['profile_name'] == profile_name)]['uuid'].unique()
    app_id_list = list(set([uuid_to_id_mapper[x] for x in uuid_list]))
    name_list = list(set([uuid_to_name_mapper[x] for x in uuid_list]))
    
    
    nft_creators.groupby('creator_address')['buyers_90D'].agg(lambda x: len(set().union(*x))).rename('num_unique_minters_90D'),
    nft_creators.groupby('creator_address')['buyers_180D'].agg(lambda x: len(set().union(*x))).rename('num_unique_minters_180D'),

    nft_creators.groupby('creator_address')['list_of_fids_90D'].agg(lambda x: len(set().union(*x))).rename('num_farcaster_minters_90D'),
    nft_creators.groupby('creator_address')['list_of_fids_180D'].agg(lambda x: len(set().union(*x))).rename('num_farcaster_minters_180D'),

    nft_creators.groupby('creator_address')['num_txns_90D'].sum().rename('num_transactions_90D'),
    nft_creators.groupby('creator_address')['num_txns_180D'].sum().rename('num_transactions_180D'),
        
    nft_creators.groupby('creator_address')['amount_usd_90D'].sum().rename('usd_value_of_transactions_90D'),
    nft_creators.groupby('creator_address')['amount_usd_180D'].sum().rename('usd_value_of_transactions_180D')

    
    creator_metrics = {
        'recipient': recipient,
        'artist_profile': f'"{profile_name}"',
    
        'num_drops': dff['nft_contract_address'].nunique(),
        
        #'num_unique_minters_90D': len(set(dff['buyers_90D'].sum())),
        'num_unique_minters': len(set(dff['buyers_180D'].sum())),
        
        #'num_farcaster_minters_90D': len(set(dff['list_of_fids_90D'].sum())),
        'num_farcaster_minters': len(set(dff['list_of_fids_180D'].sum())),
        
        #'num_transactions_90D': dff['num_txns_90D'].sum(),
        'num_transactions': dff['num_txns_180D'].sum(),
        
        #'usd_value_of_transactions_90D': dff['amount_usd_90D'].sum(),
        'usd_value_of_transactions': dff['amount_usd_180D'].sum(),
        
        'uuid_list': uuid_list,
        'application_id_list': app_id_list
        #'project_names': name_list
    }
    recipient_metrics.append(creator_metrics)

# %%
df_recipient_metrics = pd.DataFrame(recipient_metrics).set_index(['recipient', 'artist_profile'])
df_recipient_metrics.to_csv('data/clean_metric_data/metrics_creators_by_recipient.csv')
df_recipient_metrics.sort_values(by='num_transactions')
# Out:
#                                                                 num_drops  \
# recipient                                  artist_profile
# 0x435172C1B669839dE487c8A26BeE3124E2f06D78 "hanma"                      1
# 0xF15132421A7Cd4a3528d5b938b53c782Fe7fE57D "mayowalawal.eth"            1
# 0xdc7E36f806012252C7A88E7c8f00802Be46453df "sadye"                      1
# 0x2e63A76A0025BF1D92CECdA73c5Efd342849fd0d "snip3"                      1
# 0xA78a151A0a2a103830D040bC44CF143703C5eD61 "freetown"                   1
# ...                                                                   ...
# 0x07BD4932D08e5956faB224965a58BF1a441134A1 "eneowaith.eth"             46
# 0x2Fb0e475F6D495DFdfd9176aF9113f48F7687565 "nimaleophotos.eth"         23
# 0x829C0F59FF906fd617F84f6790AF18f440D0C108 "mx1000"                    15
# 0xf977A728f3AA00885b2dE0A106f8ae69d17adB08 "primitivesnft"              6
# 0x0B81BfFce9970aca9868120eEE1bcc8De19119F7 "mahnaaz"                   18
#
#                                                                 num_unique_minters  \
# recipient                                  artist_profile
# 0x435172C1B669839dE487c8A26BeE3124E2f06D78 "hanma"                               1
# 0xF15132421A7Cd4a3528d5b938b53c782Fe7fE57D "mayowalawal.eth"                     1
# 0xdc7E36f806012252C7A88E7c8f00802Be46453df "sadye"                               1
# 0x2e63A76A0025BF1D92CECdA73c5Efd342849fd0d "snip3"                               1
# 0xA78a151A0a2a103830D040bC44CF143703C5eD61 "freetown"                            1
# ...                                                                            ...
# 0x07BD4932D08e5956faB224965a58BF1a441134A1 "eneowaith.eth"                   79621
# 0x2Fb0e475F6D495DFdfd9176aF9113f48F7687565 "nimaleophotos.eth"               66493
# 0x829C0F59FF906fd617F84f6790AF18f440D0C108 "mx1000"                          96761
# 0xf977A728f3AA00885b2dE0A106f8ae69d17adB08 "primitivesnft"                  141811
# 0x0B81BfFce9970aca9868120eEE1bcc8De19119F7 "mahnaaz"                        144237
#
#                                                                 num_farcaster_minters  \
# recipient                                  artist_profile
# 0x435172C1B669839dE487c8A26BeE3124E2f06D78 "hanma"                                  1
# 0xF15132421A7Cd4a3528d5b938b53c782Fe7fE57D "mayowalawal.eth"                        1
# 0xdc7E36f806012252C7A88E7c8f00802Be46453df "sadye"                                  1
# 0x2e63A76A0025BF1D92CECdA73c5Efd342849fd0d "snip3"                                  1
# 0xA78a151A0a2a103830D040bC44CF143703C5eD61 "freetown"                               1
# ...                                                                               ...
# 0x07BD4932D08e5956faB224965a58BF1a441134A1 "eneowaith.eth"                      23711
# 0x2Fb0e475F6D495DFdfd9176aF9113f48F7687565 "nimaleophotos.eth"                  10556
# 0x829C0F59FF906fd617F84f6790AF18f440D0C108 "mx1000"                             24445
# 0xf977A728f3AA00885b2dE0A106f8ae69d17adB08 "primitivesnft"                      19146
# 0x0B81BfFce9970aca9868120eEE1bcc8De19119F7 "mahnaaz"                            18692
#
#                                                                 num_transactions  \
# recipient                                  artist_profile
# 0x435172C1B669839dE487c8A26BeE3124E2f06D78 "hanma"                             1
# 0xF15132421A7Cd4a3528d5b938b53c782Fe7fE57D "mayowalawal.eth"                   1
# 0xdc7E36f806012252C7A88E7c8f00802Be46453df "sadye"                             1
# 0x2e63A76A0025BF1D92CECdA73c5Efd342849fd0d "snip3"                             1
# 0xA78a151A0a2a103830D040bC44CF143703C5eD61 "freetown"                          1
# ...                                                                          ...
# 0x07BD4932D08e5956faB224965a58BF1a441134A1 "eneowaith.eth"                 87187
# 0x2Fb0e475F6D495DFdfd9176aF9113f48F7687565 "nimaleophotos.eth"            100614
# 0x829C0F59FF906fd617F84f6790AF18f440D0C108 "mx1000"                       110164
# 0xf977A728f3AA00885b2dE0A106f8ae69d17adB08 "primitivesnft"                127320
# 0x0B81BfFce9970aca9868120eEE1bcc8De19119F7 "mahnaaz"                      148232
#
#                                                                 usd_value_of_transactions  \
# recipient                                  artist_profile
# 0x435172C1B669839dE487c8A26BeE3124E2f06D78 "hanma"                               0.000000
# 0xF15132421A7Cd4a3528d5b938b53c782Fe7fE57D "mayowalawal.eth"                     0.678374
# 0xdc7E36f806012252C7A88E7c8f00802Be46453df "sadye"                              24.443007
# 0x2e63A76A0025BF1D92CECdA73c5Efd342849fd0d "snip3"                               3.581022
# 0xA78a151A0a2a103830D040bC44CF143703C5eD61 "freetown"                            0.000000
# ...                                                                                   ...
# 0x07BD4932D08e5956faB224965a58BF1a441134A1 "eneowaith.eth"                  184352.023688
# 0x2Fb0e475F6D495DFdfd9176aF9113f48F7687565 "nimaleophotos.eth"               57469.219082
# 0x829C0F59FF906fd617F84f6790AF18f440D0C108 "mx1000"                         220935.033483
# 0xf977A728f3AA00885b2dE0A106f8ae69d17adB08 "primitivesnft"                  162606.466195
# 0x0B81BfFce9970aca9868120eEE1bcc8De19119F7 "mahnaaz"                         77851.167452
#
#                                                                                                         uuid_list  \
# recipient                                  artist_profile
# 0x435172C1B669839dE487c8A26BeE3124E2f06D78 "hanma"                         [c50abe5e-ad79-4707-9beb-9e91edef299b]
# 0xF15132421A7Cd4a3528d5b938b53c782Fe7fE57D "mayowalawal.eth"               [2612c31b-b3d0-475a-85dc-650fbbfad308]
# 0xdc7E36f806012252C7A88E7c8f00802Be46453df "sadye"                         [4b0ec866-5b3e-4014-8ddc-a875c4f4d6b5]
# 0x2e63A76A0025BF1D92CECdA73c5Efd342849fd0d "snip3"                         [6e6228be-6e91-4b8f-bdf8-54ab3a9f3625]
# 0xA78a151A0a2a103830D040bC44CF143703C5eD61 "freetown"                      [284cae0c-c330-46d9-a3d6-19699f6bee72]
# ...                                                                                                           ...
# 0x07BD4932D08e5956faB224965a58BF1a441134A1 "eneowaith.eth"      [caf3b198-91f2-495e-96fd-67b9cb622e73, 184736b...
# 0x2Fb0e475F6D495DFdfd9176aF9113f48F7687565 "nimaleophotos.eth"  [b2265281-1d30-4c30-8973-820c81d12641, ad90d93...
# 0x829C0F59FF906fd617F84f6790AF18f440D0C108 "mx1000"             [dbdf5a7b-9635-4703-ad41-7fb29f96f88d, 84c008f...
# 0xf977A728f3AA00885b2dE0A106f8ae69d17adB08 "primitivesnft"                 [2802267f-fbce-4450-88db-7f7b72bbef97]
# 0x0B81BfFce9970aca9868120eEE1bcc8De19119F7 "mahnaaz"                       [89aabf68-45a8-4db6-9d32-2d4cd96cc4ad]
#
#                                                                                               application_id_list
# recipient                                  artist_profile
# 0x435172C1B669839dE487c8A26BeE3124E2f06D78 "hanma"              [0x092a6fc3cce81c8eedd578519e396dae9f7881df31c...
# 0xF15132421A7Cd4a3528d5b938b53c782Fe7fE57D "mayowalawal.eth"    [0x647b118b702796f479900d3ad4275b3fca7d2d8135f...
# 0xdc7E36f806012252C7A88E7c8f00802Be46453df "sadye"              [0xd6eba54679903df9eb6e63ce5d3048726b1aec52896...
# 0x2e63A76A0025BF1D92CECdA73c5Efd342849fd0d "snip3"              [0x3d66e061c487378b5263c244f941a01ca40baf2947c...
# 0xA78a151A0a2a103830D040bC44CF143703C5eD61 "freetown"           [0xa5b39600efb468ba17fe8fb3e1031d5417dceb5a8e7...
# ...                                                                                                           ...
# 0x07BD4932D08e5956faB224965a58BF1a441134A1 "eneowaith.eth"      [0xe58537b88b97567c536e5d1f9966a40884297037cdb...
# 0x2Fb0e475F6D495DFdfd9176aF9113f48F7687565 "nimaleophotos.eth"  [0x31cd86c37aac301c6c929ea84394ea2297652660751...
# 0x829C0F59FF906fd617F84f6790AF18f440D0C108 "mx1000"             [0x5856be128b614c252d90e956dad0d932ca90e957d03...
# 0xf977A728f3AA00885b2dE0A106f8ae69d17adB08 "primitivesnft"      [0x560e862e98c3a55998464d95cad73a43b6fd3f2e43d...
# 0x0B81BfFce9970aca9868120eEE1bcc8De19119F7 "mahnaaz"            [0xf81ae24ef5932f6e3d03a91054252b1986d35001f55...
#
# [267 rows x 7 columns]

# %% [markdown]
# ## Upload application data to Dune

# %%
apps_path = pd.read_csv('data/apps/applications_reviewed.csv')

# with open(apps_path) as file:
#     data = file.read()

# table = dune.upload_csv(
#     data=str(data),
#     description="Sunny Awards applications (cleaned) with reviewer issues.",
#     table_name="sunny_applications",
#     is_private=False
# )
