# %%
from google.cloud import bigquery
import os
import pandas as pd
import plotly.express as px

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../../gcp_credentials.json'
client = bigquery.Client()

# %% [markdown]
# # Unified Superchain transactions summary

# %%
query = """
    select
      txn_date,
      network,
      count(*) as txns
    from `opensource-observer.oso.rf4_transactions_window`
    group by txn_date, network
"""
txns_results = client.query(query)

# %%
df_txns = txns_results.to_dataframe()
df_txns.head(1)
# Out:
#                    txn_date network   txns
# 0 2024-01-27 00:00:00+00:00    ZORA  69188

# %%
df_txns['txns'].sum()
# Out:
# 290464488

# %%
palette = {
    'OPTIMISM': '#FF0420',
    'BASE': '#1750FA',
    'ZORA': 'indigo',
    'MODE': '#D7FF00',
    'METAL': '#C16C3B',
    'FRAX': '#000000'
}
fig = px.area(
    data_frame=df_txns, x='txn_date', y='txns', color='network', 
    color_discrete_map=palette,
    category_orders={'network': ['OPTIMISM', 'ZORA', 'MODE', 'FRAX', 'METAL', 'BASE']}
)
fig.update_layout(
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=False),
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)
fig.update_traces(line=dict(width=.1))
# Out:
# <div>                            <div id="fcec7e05-0792-4ec9-a0a0-4304ad0bec38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcec7e05-0792-4ec9-a0a0-4304ad0bec38")) {                    Plotly.newPlot(                        "fcec7e05-0792-4ec9-a0a0-4304ad0bec38",                        [{"fillpattern":{"shape":""},"hovertemplate":"network=OPTIMISM<br>txn_date=%{x}<br>txns=%{y}<extra></extra>","legendgroup":"OPTIMISM","line":{"color":"#FF0420","width":0.1},"marker":{"symbol":"circle"},"mode":"lines","name":"OPTIMISM","orientation":"v","showlegend":true,"stackgroup":"1","x":["2024-05-22T00:00:00+00:00","2023-12-19T00:00:00+00:00","2024-05-26T00:00:00+00:00","2024-02-02T00:00:00+00:00","2023-10-05T00:00:00+00:00","2023-12-01T00:00:00+00:00","2023-12-21T00:00:00+00:00","2024-03-21T00:00:00+00:00","2024-05-12T00:00:00+00:00","2024-03-25T00:00:00+00:00","2023-10-26T00:00:00+00:00","2023-11-24T00:00:00+00:00","2023-10-08T00:00:00+00:00","2024-02-09T00:00:00+00:00","2023-12-22T00:00:00+00:00","2024-01-05T00:00:00+00:00","2023-10-14T00:00:00+00:00","2023-12-13T00:00:00+00:00","2023-11-13T00:00:00+00:00","2024-03-06T00:00:00+00:00","2024-04-16T00:00:00+00:00","2024-04-01T00:00:00+00:00","2024-02-20T00:00:00+00:00","2024-05-21T00:00:00+00:00","2023-12-26T00:00:00+00:00","2024-01-14T00:00:00+00:00","2024-04-27T00:00:00+00:00","2023-10-17T00:00:00+00:00","2024-02-18T00:00:00+00:00","2024-05-01T00:00:00+00:00","2024-04-13T00:00:00+00:00","2024-01-22T00:00:00+00:00","2023-11-25T00:00:00+00:00","2024-03-10T00:00:00+00:00","2024-02-29T00:00:00+00:00","2023-11-27T00:00:00+00:00","2024-04-25T00:00:00+00:00","2024-03-13T00:00:00+00:00","2023-10-22T00:00:00+00:00","2024-02-28T00:00:00+00:00","2024-01-30T00:00:00+00:00","2024-01-02T00:00:00+00:00","2024-01-17T00:00:00+00:00","2024-03-03T00:00:00+00:00","2024-05-18T00:00:00+00:00","2024-02-24T00:00:00+00:00","2024-05-09T00:00:00+00:00","2023-12-03T00:00:00+00:00","2024-04-17T00:00:00+00:00","2023-12-27T00:00:00+00:00","2023-11-14T00:00:00+00:00","2024-05-30T00:00:00+00:00","2024-01-20T00:00:00+00:00","2024-02-03T00:00:00+00:00","2024-02-15T00:00:00+00:00","2024-01-15T00:00:00+00:00","2024-04-15T00:00:00+00:00","2024-02-25T00:00:00+00:00","2024-02-13T00:00:00+00:00","2023-10-30T00:00:00+00:00","2023-11-23T00:00:00+00:00","2024-02-10T00:00:00+00:00","2023-12-08T00:00:00+00:00","2023-11-09T00:00:00+00:00","2023-10-23T00:00:00+00:00","2024-01-28T00:00:00+00:00","2023-11-05T00:00:00+00:00","2024-01-09T00:00:00+00:00","2024-05-03T00:00:00+00:00","2024-01-06T00:00:00+00:00","2023-12-29T00:00:00+00:00","2023-12-07T00:00:00+00:00","2023-12-06T00:00:00+00:00","2024-02-05T00:00:00+00:00","2023-11-18T00:00:00+00:00","2024-01-04T00:00:00+00:00","2024-05-24T00:00:00+00:00","2024-04-02T00:00:00+00:00","2024-01-31T00:00:00+00:00","2023-11-12T00:00:00+00:00","2023-11-07T00:00:00+00:00","2023-10-15T00:00:00+00:00","2024-02-12T00:00:00+00:00","2024-04-21T00:00:00+00:00","2023-12-24T00:00:00+00:00","2024-02-07T00:00:00+00:00","2024-03-02T00:00:00+00:00","2024-03-09T00:00:00+00:00","2024-03-07T00:00:00+00:00","2024-05-11T00:00:00+00:00","2023-12-23T00:00:00+00:00","2023-10-12T00:00:00+00:00","2023-12-16T00:00:00+00:00","2024-01-12T00:00:00+00:00","2024-02-04T00:00:00+00:00","2023-10-16T00:00:00+00:00","2024-04-22T00:00:00+00:00","2024-04-11T00:00:00+00:00","2024-05-14T00:00:00+00:00","2023-12-15T00:00:00+00:00","2024-03-30T00:00:00+00:00","2023-10-10T00:00:00+00:00","2024-01-01T00:00:00+00:00","2024-01-24T00:00:00+00:00","2023-11-03T00:00:00+00:00","2023-10-21T00:00:00+00:00","2024-04-29T00:00:00+00:00","2023-11-26T00:00:00+00:00","2024-04-06T00:00:00+00:00","2023-12-25T00:00:00+00:00","2024-05-29T00:00:00+00:00","2024-03-28T00:00:00+00:00","2024-05-15T00:00:00+00:00","2023-12-05T0 ...

# %% [markdown]
# # Tagged project address registry

# %%
query = """
    select distinct
      a.project_id,
      a.artifact_source,
      a.artifact_source_id,
      a.artifact_type
    from `opensource-observer.oso.int_artifacts_in_ossd_by_project` a
    join `opensource-observer.oso.projects_by_collection_v1` pbc
      on a.project_id = pbc.project_id
    where
      pbc.collection_name = 'op-retrofunding-4'
      and a.artifact_type in ('DEPLOYER', 'CONTRACT', 'REPOSITORY')
      and a.artifact_source in ('OPTIMISM', 'BASE', 'ANY_EVM', 'METAL', 'MODE', 'FRAX', 'ZORA', 'GITHUB')
"""
ossd_results = client.query(query)

# %%
df_ossd = ossd_results.to_dataframe()
df_ossd.head(1)
# Out:
#                                      project_id artifact_source  \
# 0  DVMDNW7lcfKhTfv83r_SPJiqNz0bcQ6SoHAnrIV2ZI4=            ZORA
#
#                            artifact_source_id artifact_type
# 0  0xca11bde05977b3631167028862be2a173976ca11      CONTRACT

# %%
df_ossd[df_ossd['artifact_type'] == 'DEPLOYER']['artifact_source_id'].nunique()
# Out:
# 424

# %%
df_ossd[df_ossd['artifact_type'] == 'CONTRACT']['artifact_source_id'].nunique()
# Out:
# 9088

# %%
df_ossd.groupby(['artifact_source', 'artifact_type'])['artifact_source_id'].count().reset_index()
# Out:
#    artifact_source artifact_type  artifact_source_id
# 0          ANY_EVM      DEPLOYER                 280
# 1             BASE      CONTRACT                1234
# 2             BASE      DEPLOYER                 105
# 3             FRAX      CONTRACT                   2
# 4           GITHUB    REPOSITORY                5058
# 5             MODE      CONTRACT                  13
# 6             MODE      DEPLOYER                  15
# 7         OPTIMISM      CONTRACT                7907
# 8         OPTIMISM      DEPLOYER                  60
# 9             ZORA      CONTRACT                  32
# 10            ZORA      DEPLOYER                  23

# %% [markdown]
# # Contract discovery model

# %%
query = """
    select
      application_id,
      project_name,
      event_source as network,
      to_artifact_name as contract_address,
      in_ossd,
      in_agora_app,
      total_gas,
      total_addresses
    from `opensource-observer.static_data_sources.RF4_ContractMetricsByProject_20240626_Snapshot`
"""
contract_discovery_results = client.query(query)

# %%
df_contracts = contract_discovery_results.to_dataframe()
#df_contracts.to_parquet('data/op_rf4_contracts_by_project.parquet') # backup
df_contracts.head(1)
# Out:
#                                       application_id  \
# 0  0xb98778ca9ff41446e2bc304f7b5d27f0fa7c2bcd11df...
#
#                      project_name network  \
# 0  Account Abstraction - ERC-4337    BASE
#
#                              contract_address  in_ossd  in_agora_app  \
# 0  0x5ff137d4b0fdcd49dca30c7cf57e578a026d2789     True         False
#
#     total_gas  total_addresses
# 0  197.718467             1123

# %%
len(df_contracts[df_contracts['in_agora_app'] == True])
# Out:
# 1660

# %%
len(df_contracts[df_contracts['in_ossd'] == True])
# Out:
# 1810

# %%
(
    df_contracts[(df_contracts['in_ossd'] == False) & (df_contracts['in_agora_app'] == False)]
    .groupby('project_name')['contract_address']
    .nunique()
    .sort_values()
).tail(10)
# Out:
# project_name
# Aragon                                      112
# Supswap                                     114
# Synthetix                                   117
# Unlonely                                    122
# Reserve Protocol                            127
# Decent.xyz                                  128
# Ionic Protocol                              131
# SwapBased                                   131
# Kim Exchange                                133
# Harvest Finance                             133
# DackieSwap                                  138
# ModeChat.xyz | Onchain Social on Mode       143
# Balancer                                    164
# Alien Base                                  165
# Virtuals Protocol                           171
# Base on Rarible                             173
# Velocimeter/Graphene                        192
# Gitcoin                                     203
# Wormhole Foundation                         226
# Arcadia Finance                             240
# sudoswap                                    244
# Tarot                                       251
# Let's Get HAI                               263
# NiftyKit                                    287
# Equalizer                                   292
# dHEDGE                                      399
# Hypersub                                    415
# Tokepad                                     489
# Seamless Protocol                           567
# Summer.fi                                   642
# Builder Protocol                            825
# LlamaPay                                    840
# Archly                                      878
# Beefy                                       947
# BaseSwap                                   1071
# Omnisea                                    1432
# Paragraph                                  1443
# Velodrome Finance                          1572
# Sound.xyz                                  1614
# Aerodrome Finance                          1925
# Sushiswap                                  2255
# TITLES                                     2659
# Polynomial Trade                           2870
# Boost                                      4127
# Kwenta                                     5441
# Holograph Foundation                       7461
# Party.app + Party Protocol                 7995
# Thales Protocol                            8037
# NFTs2Me                                   20951
# Zora                                     283585
# Name: contract_address, dtype: int64

# %%
px.treemap(
    data_frame=df_contracts,
    path=['network', 'project_name'],
    values='total_gas',
    title=f'L2 Gas Fees over RF4 window by application ({df_contracts.total_gas.sum():,.0f} ETH)'
)
# Out:
# <div>                            <div id="d0dcafcf-c687-43cb-83fc-e2b40d397231" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0dcafcf-c687-43cb-83fc-e2b40d397231")) {                    Plotly.newPlot(                        "d0dcafcf-c687-43cb-83fc-e2b40d397231",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>total_gas=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["ZORA/$ENJOY","BASE//send","BASE/0x Protocol","OPTIMISM/0x Protocol","OPTIMISM/3DNS","BASE/Aave","OPTIMISM/Aave","BASE/Account Abstraction - ERC-4337","FRAX/Account Abstraction - ERC-4337","MODE/Account Abstraction - ERC-4337","OPTIMISM/Account Abstraction - ERC-4337","ZORA/Account Abstraction - ERC-4337","BASE/Across Protocol","MODE/Across Protocol","OPTIMISM/Across Protocol","BASE/Aerodrome Finance","OPTIMISM/Alchemix","BASE/Alien Base","BASE/Ambire","OPTIMISM/Ambire","BASE/Aragon","BASE/Arcadia Finance","OPTIMISM/Arcadia Finance","BASE/Archly","FRAX/Archly","MODE/Archly","OPTIMISM/Archly","ZORA/Archly","BASE/Astaria","MODE/Astaria","BASE/Aura Finance","OPTIMISM/Aura Finance","BASE/Avantis","ZORA/BLOCKS","BASE/BMX by Morphex","BASE/BSX","BASE/Balancer","FRAX/Balancer","MODE/Balancer","OPTIMISM/Balancer","BASE/Base Runners","BASE/Base on Rarible","BASE/BaseDoge","BASE/BaseSwap","BASE/Based Bodega","BASE/Based Onchain Cubes","BASE/Based Onchain Dinos","BASE/Based Onchain Punks","BASE/Basepaint","BASE/Basic Dog Meme","OPTIMISM/Beam","BASE/Beefy","FRAX/Beefy","MODE/Beefy","OPTIMISM/Beefy","BASE/Biconomy","OPTIMISM/Biconomy","BASE/Blob Farm","OPTIMISM/Bodhi","BASE/Boost","OPTIMISM/Boost","ZORA/Boost","BASE/Bored Town","MODE/Bored Town","OPTIMISM/Bored Town","ZORA/Bored Town","BASE/Builder Protocol","OPTIMISM/Builder Protocol","ZORA/Builder Protocol","BASE/Building Blocks","BASE/Catalog Radio","BASE/Circle.tech","BASE/Clipper DEX","OPTIMISM/Clipper DEX","BASE/Coinvise","OPTIMISM/Coinvise","BASE/Compound Finance","OPTIMISM/Compound Finance","OPTIMISM/Coordinape","BASE/Copin.io","OPTIMISM/Copin.io","BASE/CreateMyToken","BASE/Crowdmuse","OPTIMISM/Crowdmuse","ZORA/Crowdmuse","BASE/Crypto Composite","BASE/CyberConnect Protocol","OPTIMISM/CyberConnect Protocol","BASE/Cygnus Finance","BASE/DackieNFT","OPTIMISM/DackieNFT","BASE/DackieSwap","MODE/DackieSwap","OPTIMISM/DackieSwap","BASE/Daimo","OPTIMISM/DappLearning ZK redpacket","OPTIMISM/DappRadar","BASE/Decent.xyz","MODE/Decent.xyz","OPTIMISM/Decent.xyz","ZORA/Decent.xyz","OPTIMISM/DefiLlama","BASE/Dmail Network","OPTIMISM/Dmail Network","BASE/Drakula.app","BASE/Egg Wars: A Game on Base","BASE/Equalizer","BASE/EthXY","OPTIMISM/Ethereum Attestation Service (EAS)","OPTIMISM/Ethos Reserve","OPTIMISM/Exactly Protocol","BASE/Extra Finance","OPTIMISM/Extra Finance","BASE/Fractal Visions","OPTIMISM/Fractal Visions","BASE/Gamma","MODE/Gamma","OPTIMISM/Gamma","BASE/Gangster Arena","BASE/Get Mint","OPTIMISM/Get Mint","ZORA/Get Mint","BASE/Gitcoin","OPTIMISM/Gitcoin","OPTIMISM/Gitcoin Passport","OPTIMISM/Giveth","BASE/Glo Dollar","OPTIMISM/Glo Dollar","BASE/Gloom","OPTIMISM/Gloom","BASE/Guac (Farcaster)","BASE/Guild.xyz","OPTIMISM/Guild.xyz","BASE/HOMES","BASE/Ham","BASE/Harvest Finance","BASE/Hats Protocol","OPTIMISM/Hats Protocol","BASE/Hedgey","FRAX/Hedgey","MODE/Hedgey","OPTIMISM/Hedgey","ZORA/Hedgey","BASE/Highlight","OPTIMISM/Highlight","ZORA/Highlight","BASE/Holograph Foundation","OPTIMISM/Holograph Foundation","ZORA/Holograph Foundation","BASE/Hyperlane","MODE/Hyperlane","OPTIMISM/Hyperlane","BASE/Hypersub","OPTIMISM/Hypersub","ZORA/Hypersub","BASE/INT","OPTIMISM/Idle","BASE/Infusion","BASE/IntentX","BASE/Ionic Protocol","MODE/Ionic Protocol","BASE/Ironclad Finance","FRAX/Ironclad Finance","MODE/Iron ...

# %% [markdown]
# # Metric analysis

# %%
df_results = pd.read_csv('data/op_rf4_impact_metrics_by_project.csv')
df_results
# Out:
#                                       project_name  \
# 0                                             Aave
# 1                                         Alchemix
# 2                                         Biconomy
# 3                                      0x Protocol
# 4                                    CreateMyToken
# ..                                             ...
# 225                                       sudoswap
# 226   tanX - The World's Leading Institutional DEX
# 227            zkBob smart contract privacy wallet
# 228                                   🏰 BuidlGuidl
# 229  👑 King of the Degens 🎩 - Farcaster Frame Game
#
#                                         application_id  is_oss   gas_fees  \
# 0    0x3061b642db56c507e265f03029735b0413a613bda434...    True  10.354093
# 1    0x12d482385e2c26d37da1f30c513d66c1fa39e9ed4980...    True   0.026137
# 2    0x220685a4514003f22cbf18a7ddd9c09f88c2383daed6...   False   0.680701
# 3    0x0fad18f37ecec4f4f4ca18e60c353eb11462363e8aa1...    True  75.066083
# 4    0xdf3eb6b429b2150c71241de0c591b18c98a3528ad0e8...   False   0.000020
# ..                                                 ...     ...        ...
# 225  0x73899e48df9f895ffbffc36d53ce970c1454c8eeb070...    True   0.831091
# 226  0xa8213245a57be579692ead3a2381364f5942a68afd17...   False   0.005960
# 227  0x61d2e05f988e678b240a7f00c5f722a5a69f06f085f4...   False   0.377365
# 228  0x79196c0af1a1f78fe5a009a4753c46d2271b17fc2836...    True   0.409022
# 229  0xded5569a48e46a8b71d2b347d90b0319a7dc8f2f599f...   False   0.262541
#
#      transaction_count  trusted_transaction_count  trusted_transaction_share  \
# 0             622906.0                    57100.0                   0.091667
# 1               4523.0                      492.0                   0.108777
# 2            3668646.0                      103.0                   0.000000
# 3            1739387.0                    88370.0                   0.050805
# 4                  3.0                        0.0                   0.000000
# ..                 ...                        ...                        ...
# 225             3835.0                     1677.0                   0.437288
# 226            17607.0                     5434.0                   0.308627
# 227            18176.0                      354.0                   0.019476
# 228            25015.0                     2301.0                   0.091985
# 229            11547.0                     8648.0                   0.761737
#
#      trusted_users_onboarded  daily_active_addresses  \
# 0                      831.0             1263.372951
# 1                        3.0               10.000000
# 2                        4.0              896.418033
# 3                     2260.0             3728.635246
# 4                        0.0                0.012295
# ..                       ...                     ...
# 225                     67.0                7.516393
# 226                    267.0               44.606557
# 227                      4.0               18.225410
# 228                    174.0               90.868852
# 229                    114.0               14.618852
#
#      trusted_daily_active_users  monthly_active_addresses  \
# 0                    126.942623              24398.148148
# 1                      1.241803                206.296296
# 2                      0.336066               3634.444444
# 3                    240.336066              67667.777778
# 4                      0.000000                  0.370370
# ..                          ...                       ...
# 225                    3.684426                142.345679
# 226                   16.303279               1289.876543
# 227                    1.307377                380.617284
# 228                    7.684426               2725.925926
# 229                   10.340164                125.925926
#
#      trusted_monthly_active_users  recurring_addresses  \
# 0                     2339.876543              10650.0
# 1                       27.407407                103.0
# 2                        8.641975                386.0
# 3                     3766.419753              31404.0
# 4                        0.000000                  0.0
# ..                            ...                  ...
# 225                     63.703704                 40.0
# 226                    484.074074                 12.0
# 227                     24.074074                200.0
# 228                    228.641975                  9.0
# 229                     86.172840                  4.0
#
#      trusted_recurring_users  power_user_addresses  \
# 0                     1777.0               24816.0
# 1                       13.0                 599.0
# 2                        3.0                 109.0
# 3                     3502.0               24012.0
# 4                        0.0                   0.0
# ..                       ...                   ...
# 225                     30.0                 346.0
# 226                      0.0                6790.0
# 227                     13.0                 231.0
# 228                      2.0                1990.0
# 229                      3.0                 383.0
#
#      openrank_trusted_users_count  log_gas_fees  log_transaction_count  \
# 0                           230.0      1.055152               5.794423
# 1                            10.0      0.011205               3.655523
# 2                             4.0      0.225490               6.564506
# 3                          1094.0      1.881191               6.240396
# 4                             0.0      0.000009               0.602060
# ..                            ...           ...                    ...
# 225                         115.0      0.262710               3.583879
# 226                          44.0      0.002581               4.245710
# 227                           7.0      0.139049               4.259522
# 228                          86.0      0.148918               4.398218
# 229                         123.0      0.101245               4.062507
#
#      log_trusted_transaction_count
# 0                         4.756644
# 1                         2.692847
# 2                         2.017033
# 3                         4.946310
# 4                         0.000000
# ..                             ...
# 225                       3.224792
# 226                       3.735200
# 227                       2.550228
# 228                       3.362105
# 229                       3.936966
#
# [230 rows x 19 columns]

# %%
fig = px.scatter(
    data_frame=df_results,
    x='transaction_count',
    y='trusted_transaction_count',
    color_discrete_sequence=['#FF0420'],
    custom_data=['project_name'],
    size='trusted_transaction_share',
    title=f'Transactions over RF4 window by application (n={df_results.transaction_count.sum():,.0f} txns)'
)
fig.update_traces(
    hovertemplate="<br>".join([
        "Project: %{customdata[0]}",
        "Transactions: %{x:,.0f}",
        "Trusted Transactions: %{y:,.0f}"
    ]),
    line=dict(width=.1, color='gray')
)
fig.update_layout(
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=False),
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)
# Out:
# <div>                            <div id="716fbbcf-c5cb-4b05-9b6a-261c90c13ff7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("716fbbcf-c5cb-4b05-9b6a-261c90c13ff7")) {                    Plotly.newPlot(                        "716fbbcf-c5cb-4b05-9b6a-261c90c13ff7",                        [{"customdata":[["Aave"],["Alchemix"],["Biconomy"],["0x Protocol"],["CreateMyToken"],["Poster"],["Loot2"],["Wombat Exchange"],["Ethereum Attestation Service (EAS)"],["Wormhole Foundation"],["$ENJOY"],["/send"],["3DNS"],["Account Abstraction - ERC-4337"],["Across Protocol"],["Aerodrome Finance"],["Alien Base"],["Ambire"],["Aragon"],["Arcadia Finance"],["Archly"],["Astaria"],["Aura Finance"],["Avantis"],["BLOCKS"],["BMX by Morphex"],["BSX"],["Balancer"],["Base Runners"],["Base on Rarible"],["BaseDoge"],["BaseSwap"],["Based Bodega"],["Based Onchain Cubes"],["Based Onchain Dinos"],["Based Onchain Punks"],["Basepaint"],["Basic Dog Meme"],["Beam"],["Beefy"],["Blob Farm"],["Bodhi"],["Boost"],["Bored Town"],["Builder Protocol"],["Building Blocks"],["Catalog Radio"],["Circle.tech"],["Clipper DEX"],["Coinvise"],["Compound Finance"],["Coordinape"],["Copin.io"],["Crowdmuse"],["Crypto Composite"],["CyberConnect Protocol"],["Cygnus Finance"],["DackieNFT"],["DackieSwap"],["Daimo"],["DappLearning ZK redpacket"],["DappRadar"],["Decent.xyz"],["DefiLlama"],["Dmail Network"],["Drakula.app"],["Egg Wars: A Game on Base"],["Equalizer"],["EthXY"],["Ethos Reserve"],["Exactly Protocol"],["Extra Finance"],["Fractal Visions"],["Gamma"],["Gangster Arena"],["Get Mint"],["Gitcoin"],["Gitcoin Passport"],["Giveth"],["Glo Dollar"],["Gloom"],["Guac (Farcaster)"],["Guild.xyz"],["HOMES"],["Ham"],["Harvest Finance"],["Hats Protocol"],["Hedgey"],["Highlight"],["Holograph Foundation"],["Hyperlane"],["Hypersub"],["INT"],["Idle"],["Infusion"],["IntentX"],["Ionic Protocol"],["Ironclad Finance"],["Keng Lernitas"],["Kim Exchange"],["Kiwi News"],["Kwenta"],["L2Pass"],["LI.FI"],["Layer3"],["LayerZero"],["Let's Get HAI"],["Lido Finance"],["Linkdrop"],["Liquidify"],["LlamaPay"],["LogX"],["MYSTCL ($MYST)"],["Manifold"],["Maverick Protocol"],["Metronome"],["MiniBridge"],["Mintify"],["Mochimons"],["ModeChat.xyz | Onchain Social on Mode"],["Moonwell"],["Morkie"],["Multicall3"],["Multicaller"],["NFT HOOK"],["NFTs2Me"],["NiftyKit"],["Nogem"],["Noggles ($NOGS)"],["ODOS"],["ORA Onchain AI Oracle on Optimism"],["Oku Trade"],["Omni X"],["OmniHub"],["Omnisea"],["Onchain Blobs - Randomly generated onchain blobs minted via a Farcaster frame"],["OpenOcean"],["Opti.Domains"],["OptiChads NFT Community"],["Orderly Network"],["Overnight Finance"],["Owlto Finance"],["PAWS Wildlife Room Onchain Vote in a Frame"],["PRINT3R"],["ParaSwap"],["Paragraph"],["Party.app + Party Protocol"],["Perp V2 - Curie"],["Pheasant Network"],["Phi"],["Pika Protocol"],["PiraNFT"],["Pixotchi"],["Polynomial Trade"],["PoolTogether"],["Portals"],["Preon Finance"],["Pyth Network"],["QiDao - Mai.Finance"],["RMRK"],["Rainbow (Rainbow Router)"],["Receipts"],["Reserve Protocol"],["Revert"],["Router Protocol"],["RubyScore"],["Sablier"],["Scry Protocol"],["Seamless Protocol"],["Sequence"],["Slice"],["Slugs"],["Smol"],["Sonne Finance"],["Sound.xyz"],["Speedtracer"],["Splits"],["Stargate Finance"],["Streameth"],["Sturdy"],["Summer.fi"],["Superfluid"],["Supswap"],["Sushiswap"],["SwapBased"],["SwapMode"],["Synapse Protocol"],["Synonym Finance"],["Synthetix"],["TITLES"],["TLX"],["Talent Protocol"],["Tarot"],["Thales Protocol"],["The Open X Project"],["Tiny Based Frogs"],["Tokepad"],["Trash NFTs"],["UNCX Network"],["Umbra"],["Union"],["Unitap"],["Unlonely"],["Velocimeter/Graphene"],["Velodrome Finance"],["Vesper Finance"],["Virtuals Protocol"],["WOOFi"],["Whale"],["Whimsical Euphoria: A White Inflatable Sheep"],[ ...

# %%
fig = px.scatter(
    data_frame=df_results,
    x='transaction_count',
    y='trusted_transaction_count',
    color_discrete_sequence=['#FF0420'],
    custom_data=['project_name'],
    size='trusted_transaction_share',
    title=f'LOG SCALE: Transactions over RF4 window by application (n={df_results.transaction_count.sum():,.0f} txns)',
    log_x=True,
    log_y=True
)
fig.update_traces(
    hovertemplate="<br>".join([
        "Project: %{customdata[0]}",
        "Transactions: %{x:,.0f}",
        "Trusted Transactions: %{y:,.0f}"
    ]),
    line=dict(width=.1, color='gray')
)
fig.update_layout(
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=False),
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)',
)
# Out:
# <div>                            <div id="b7d7d785-e24d-486b-8388-ae684fc1915b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7d7d785-e24d-486b-8388-ae684fc1915b")) {                    Plotly.newPlot(                        "b7d7d785-e24d-486b-8388-ae684fc1915b",                        [{"customdata":[["Aave"],["Alchemix"],["Biconomy"],["0x Protocol"],["CreateMyToken"],["Poster"],["Loot2"],["Wombat Exchange"],["Ethereum Attestation Service (EAS)"],["Wormhole Foundation"],["$ENJOY"],["/send"],["3DNS"],["Account Abstraction - ERC-4337"],["Across Protocol"],["Aerodrome Finance"],["Alien Base"],["Ambire"],["Aragon"],["Arcadia Finance"],["Archly"],["Astaria"],["Aura Finance"],["Avantis"],["BLOCKS"],["BMX by Morphex"],["BSX"],["Balancer"],["Base Runners"],["Base on Rarible"],["BaseDoge"],["BaseSwap"],["Based Bodega"],["Based Onchain Cubes"],["Based Onchain Dinos"],["Based Onchain Punks"],["Basepaint"],["Basic Dog Meme"],["Beam"],["Beefy"],["Blob Farm"],["Bodhi"],["Boost"],["Bored Town"],["Builder Protocol"],["Building Blocks"],["Catalog Radio"],["Circle.tech"],["Clipper DEX"],["Coinvise"],["Compound Finance"],["Coordinape"],["Copin.io"],["Crowdmuse"],["Crypto Composite"],["CyberConnect Protocol"],["Cygnus Finance"],["DackieNFT"],["DackieSwap"],["Daimo"],["DappLearning ZK redpacket"],["DappRadar"],["Decent.xyz"],["DefiLlama"],["Dmail Network"],["Drakula.app"],["Egg Wars: A Game on Base"],["Equalizer"],["EthXY"],["Ethos Reserve"],["Exactly Protocol"],["Extra Finance"],["Fractal Visions"],["Gamma"],["Gangster Arena"],["Get Mint"],["Gitcoin"],["Gitcoin Passport"],["Giveth"],["Glo Dollar"],["Gloom"],["Guac (Farcaster)"],["Guild.xyz"],["HOMES"],["Ham"],["Harvest Finance"],["Hats Protocol"],["Hedgey"],["Highlight"],["Holograph Foundation"],["Hyperlane"],["Hypersub"],["INT"],["Idle"],["Infusion"],["IntentX"],["Ionic Protocol"],["Ironclad Finance"],["Keng Lernitas"],["Kim Exchange"],["Kiwi News"],["Kwenta"],["L2Pass"],["LI.FI"],["Layer3"],["LayerZero"],["Let's Get HAI"],["Lido Finance"],["Linkdrop"],["Liquidify"],["LlamaPay"],["LogX"],["MYSTCL ($MYST)"],["Manifold"],["Maverick Protocol"],["Metronome"],["MiniBridge"],["Mintify"],["Mochimons"],["ModeChat.xyz | Onchain Social on Mode"],["Moonwell"],["Morkie"],["Multicall3"],["Multicaller"],["NFT HOOK"],["NFTs2Me"],["NiftyKit"],["Nogem"],["Noggles ($NOGS)"],["ODOS"],["ORA Onchain AI Oracle on Optimism"],["Oku Trade"],["Omni X"],["OmniHub"],["Omnisea"],["Onchain Blobs - Randomly generated onchain blobs minted via a Farcaster frame"],["OpenOcean"],["Opti.Domains"],["OptiChads NFT Community"],["Orderly Network"],["Overnight Finance"],["Owlto Finance"],["PAWS Wildlife Room Onchain Vote in a Frame"],["PRINT3R"],["ParaSwap"],["Paragraph"],["Party.app + Party Protocol"],["Perp V2 - Curie"],["Pheasant Network"],["Phi"],["Pika Protocol"],["PiraNFT"],["Pixotchi"],["Polynomial Trade"],["PoolTogether"],["Portals"],["Preon Finance"],["Pyth Network"],["QiDao - Mai.Finance"],["RMRK"],["Rainbow (Rainbow Router)"],["Receipts"],["Reserve Protocol"],["Revert"],["Router Protocol"],["RubyScore"],["Sablier"],["Scry Protocol"],["Seamless Protocol"],["Sequence"],["Slice"],["Slugs"],["Smol"],["Sonne Finance"],["Sound.xyz"],["Speedtracer"],["Splits"],["Stargate Finance"],["Streameth"],["Sturdy"],["Summer.fi"],["Superfluid"],["Supswap"],["Sushiswap"],["SwapBased"],["SwapMode"],["Synapse Protocol"],["Synonym Finance"],["Synthetix"],["TITLES"],["TLX"],["Talent Protocol"],["Tarot"],["Thales Protocol"],["The Open X Project"],["Tiny Based Frogs"],["Tokepad"],["Trash NFTs"],["UNCX Network"],["Umbra"],["Union"],["Unitap"],["Unlonely"],["Velocimeter/Graphene"],["Velodrome Finance"],["Vesper Finance"],["Virtuals Protocol"],["WOOFi"],["Whale"],["Whimsical Euphoria: A White Inflatable Sheep"],[ ...

# %%
dff = df_results.sort_values(by='openrank_trusted_users_count', ascending=False).head(40)
fig = px.bar_polar(
    data_frame=dff,
    r='openrank_trusted_users_count',
    theta='project_name',
    color_discrete_sequence=['#FF0420'],
    title='Top 40 applications by Badgeholder OpenRank'
)
fig.update_layout(
    polar = dict(
            bgcolor = "white",
            angularaxis = dict(tickfont = dict(size=11)),            
            radialaxis = dict(showticklabels=False, ticks='', gridcolor = 'black')
        )
)
# Out:
# <div>                            <div id="25a1c8a4-6ff7-41ff-9c18-f45dec7665e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25a1c8a4-6ff7-41ff-9c18-f45dec7665e7")) {                    Plotly.newPlot(                        "25a1c8a4-6ff7-41ff-9c18-f45dec7665e7",                        [{"hovertemplate":"openrank_trusted_users_count=%{r}<br>project_name=%{theta}<extra></extra>","legendgroup":"","marker":{"color":"#FF0420","pattern":{"shape":""}},"name":"","r":[3172.0,1451.0,1372.0,1313.0,1252.0,1094.0,969.0,889.0,888.0,826.0,788.0,753.0,701.0,666.0,638.0,595.0,449.0,441.0,425.0,424.0,388.0,382.0,376.0,370.0,367.0,352.0,341.0,336.0,327.0,323.0,321.0,319.0,315.0,314.0,312.0,286.0,281.0,272.0,272.0,268.0],"showlegend":false,"subplot":"polar","theta":["Zora","Highlight","Manifold","Decent.xyz","Party.app + Party Protocol","0x Protocol","Sound.xyz","Rainbow (Rainbow Router)","Hypersub","$ENJOY","Hedgey","Synapse Protocol","Aerodrome Finance","Paragraph","Basepaint","LI.FI","pods.media","Stargate Finance","Layer3","Gitcoin","Ham","Splits","TITLES","ODOS","Velodrome Finance","Speedtracer","far.quest - Farcaster Super App","Builder Protocol","Slice","Boost","Across Protocol","NFTs2Me","Phi","ParaSwap","Coinvise","Guild.xyz","Synthetix","Unlonely","Gitcoin Passport","Ethereum Attestation Service (EAS)"],"type":"barpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26 ...

# %% [markdown]
# # Backup: check for duplicate contracts

# %%
dupes = df_contracts.groupby(['contract_address', 'network'])['project_name'].nunique().sort_values()
dupes = dupes[dupes>1]
print((len(dupes) / len(df_contracts)) * 100)
(
    df_contracts
    .set_index(['contract_address', 'network'])
    .loc[dupes.index, ['project_name', 'total_gas']]
    .sort_values(by='total_gas', ascending=False)
)
