# %%
from dotenv import load_dotenv
import os
import pandas as pd
from pyoso import Client

load_dotenv()
OSO_API_KEY = os.environ['OSO_API_KEY']
client = Client(api_key=OSO_API_KEY)

# %%
def stringify(arr):
    return "'" + "','".join(arr) + "'"

# %% [markdown]
# ## Get devtools

# %%
json_path = "https://raw.githubusercontent.com/ethereum-optimism/Retro-Funding/refs/heads/main/results/S7/m1_devtooling_results.json"
df_devtools = pd.read_json(json_path)
df_devtools.head(3)
# Out:
#                                      project_id  \
# 0  FT3wZj26UAebMH4ywu7oQvrie1GQSmu9aogl40bsCWQ=
# 1  T5JyiUTt5UnCt95/6Xyjn04da6UU9epzDAizTapPUUU=
# 2  5/9fRbVoDF7pHwBdiMbNUbKhidEt/12Ojt9f8cWoZnQ=
#
#                                         project_name       display_name  \
# 0  0x0008577196fa6ec286440b418e2f6305fc10e62ce759...            CreateX
# 1  0x07222a857f4522026d91faec337e3cb8cf6ec5f7afb8...   Impersonator.xyz
# 2  0x08df6e20a3cfabbaf8f34d4f4d048fe7da40447c24be...  Velodrome Finance
#
#    round_id  is_eligible  op_reward  star_count  fork_count  \
# 0         7         True    4408.20         233          34
# 1         7         True    1418.48          75          23
# 2         7         True    1365.90         105          63
#
#    num_packages_in_deps_dev  package_connection_count  \
# 0                         0                         0
# 1                         0                         0
# 2                         0                         0
#
#    developer_connection_count  \
# 0                          21
# 1                           5
# 2                           9
#
#                      onchain_builder_oso_project_ids  \
# 0  [g6Z4CSsse62oS12pTQrmQ5gu1iLt74uJP5rwFgdhX1c=,...
# 1  [GFtPmpIWk2qUtklRVLF1k8VATmNH+3bHG4CA8iOfuxA=,...
# 2  [Jpscljo0tkzVDYKwVNnTSuR+AFUyy4EHg4AWd+Mdnd4=,...
#
#                         onchain_builder_op_atlas_ids  \
# 0  [0x7262ed9c020b3b41ac7ba405aab4ff37575f8b6f975...
# 1  [0x5614d129eba060ce7d224e8e8f9f29aeddfdb572b0d...
# 2  [0x02065e72fe4eebfa1ebca19238e6147c8571c2b7fef...
#
#                          trusted_developer_usernames  \
# 0  [pegahcarter, derekbar90, avious00, welps, sud...
# 1  [0xbigboss, chase-manning, pcaversaccio, murde...
# 2  [pegahcarter, fringlesinthestreet, 0xmotto, cr...
#
#                       onchain_builder_op_atlas_names
# 0  [Aave, Aragon OSx, Rainbow (Rainbow Router), S...
# 1                                             [Send]
# 2                [Exa App, Rainbow (Rainbow Router)]

# %%
OSO_IDS = list({_id for lst in df_devtools['onchain_builder_oso_project_ids'] for _id in lst})
ATLAS_IDS = list({_id for lst in df_devtools['onchain_builder_op_atlas_ids'] for _id in lst})
METRICS = [
    f"{c.upper()}_gas_fees_daily"
    for c in [
        'automata', 'cyber', 'ham', 
        'base', 'bob', 'frax', 'ink', 'kroma', 'lisk', 'lyra',
        'metal', 'mint', 'mode', 'optimism', 'orderly', 'polynomial',
        'race', 'redstone', 'shape', 'soneium', 'swan', 'swell',
        'unichain', 'worldchain', 'xterio', 'zora'
    ]
]

# %% [markdown]
# ## Lookup Gas Fees

# %%
df_onchain_metrics_oso = client.to_pandas(f"""

select
    p.project_id,
    p.project_name,
    p.display_name,
    SUM(tm.amount) as feb_gas_fees
from oso.timeseries_metrics_by_project_v0 tm
join oso.metrics_v0 m on tm.metric_id = m.metric_id
join oso.projects_v1 p on tm.project_id = p.project_id
where    
    tm.sample_date >= DATE('2025-02-01') AND tm.sample_date < DATE('2025-03-01')    
    and p.project_id IN ({stringify(OSO_IDS)})
    and m.metric_name IN ({stringify(METRICS)})
group by 1,2,3
order by 4 desc

""")

# %%
df_onchain_metrics_atlas = client.to_pandas(f"""

select
    p.project_id,
    p.project_name,
    p.display_name,
    SUM(tm.amount) as feb_gas_fees
from oso.timeseries_metrics_by_project_v0 tm
join oso.metrics_v0 m on tm.metric_id = m.metric_id
join oso.projects_v1 p on tm.project_id = p.project_id
where    
    tm.sample_date >= DATE('2025-02-01') AND tm.sample_date < DATE('2025-03-01')    
    and p.project_name IN ({stringify(ATLAS_IDS)})
    and m.metric_name IN ({stringify(METRICS)})
group by 1,2,3
order by 4 desc

""")

# %%
gas_by_oso_id = df_onchain_metrics_oso.set_index('project_id')['feb_gas_fees'].to_dict()
gas_by_atlas_id = df_onchain_metrics_atlas.set_index('project_name')['feb_gas_fees'].to_dict()

# %%
cols = ['project_name', 'display_name', 'onchain_builder_oso_project_ids', 'onchain_builder_op_atlas_ids']
df = df_devtools[cols].copy()

df['oso_gas_fees'] = df_devtools['onchain_builder_oso_project_ids'].apply(
    lambda lst: sum(gas_by_oso_id.get(_id,0) for _id in lst)
)
df['atlas_gas_fees'] = df_devtools['onchain_builder_op_atlas_ids'].apply(
    lambda lst: sum(gas_by_atlas_id.get(_id,0) for _id in lst)
)
df['fee_ratio'] = df['oso_gas_fees'] / df['atlas_gas_fees']

df.query("atlas_gas_fees > 0").sort_values(by='fee_ratio')
# Out:
#                                           project_name  \
# 40   0x4e175118c15129e6cc791203de92b23f11fef35ba4bc...
# 49   0x537097f27d55cb52d39b95c3ed65076349ab68aac480...
# 94   0x9d93ec97ef2d3bd4c2b8d95abac9ce0cf43e4f3eb1f0...
# 121  0xc377ed1b705bcc856a628f961f1e7c8ca943e6f3727b...
# 78   0x819775803938d78eaa95809971ce94cae6a54b4df585...
# ..                                                 ...
# 10   0x154a42e5ca88d7c2732fda74d6eb611057fc88dbe6f0...
# 42   0x4f8902ac6eba8e2243237247302ab778a1e1f496cf62...
# 53   0x5cfdb8c453a7eede1946071e9d7417d01cc2116f5756...
# 123  0xc71faa1bcb4ceb785816c3f22823377e9e5e7c48649b...
# 80   0x850df51e29f2846a5f085d88e6b6fc13fad51ad7161f...
#
#                    display_name  \
# 40                     EvmTools
# 49                    xdeployer
# 94                    Frames.js
# 121                MerkleTreeJS
# 78    Vscode Solidity Extension
# ..                          ...
# 10           🏗️  Scaffold-ETH 2
# 42                blocksmith.js
# 53         Optimism × Py-libp2p
# 123                   go-libp2p
# 80   Party.app + Party Protocol
#
#                        onchain_builder_oso_project_ids  \
# 40      [hE1BjGS8I9OXjnYATSkRnNJlsItBXO+CKXU6UPKJlRQ=]
# 49   [ckq4jTDZI8VgQseutflTvtvIG5SawYliPbHPn3thsIw=,...
# 94   [iOfFhoUyVo3E06Q1rH0JA6xoj/6XDj+7JQsnopmyhHQ=,...
# 121  [ZzH9XQNZ7nWOlugpkz8GaQQEmQzx1rKxaPrvhJ+l87Y=,...
# 78   [sw8ehEEk8y0FK2GSDVnFLz7M9erX6RSQdSAgGDmiwEs=,...
# ..                                                 ...
# 10   [v2QgByGF4okeRHMJmWN3tqZMxciee/qI2eeSPKK19gk=,...
# 42   [uAWTL5naoNXYNpp7weim8ypopqmN4+H9fO7/1wOjpeA=,...
# 53   [TsV9kZbHU7k/zigTlg8d7fFUcJ8Kn8YkaluyCauxUtM=,...
# 123  [hHje/yl10ng5XbAXgyeDEq3hxmOkjscMbS5XNqeAg7Q=,...
# 80   [OZc8hUTVvRXzEXAMJ6IqHeYqiGCecD6pH396GAijm/Y=,...
#
#                           onchain_builder_op_atlas_ids  oso_gas_fees  \
# 40   [0x3061b642db56c507e265f03029735b0413a613bda43...      2.011750
# 49   [0x70ba3cb2e433f1cd9ace8aea84c46d167ba5db12293...    677.642495
# 94   [0x5614d129eba060ce7d224e8e8f9f29aeddfdb572b0d...      2.192345
# 121  [0xbcb5c437d5347be21add3972512679054416805274f...   1264.807909
# 78   [0xa2a580dae44336df1cbcb7a5303880f393068fb9611...     15.616746
# ..                                                 ...           ...
# 10   [0xd3d00c946f62ac8cf49a85e3ab7d295d3b56f68d0b9...    402.482156
# 42   [0x800707befd6c94e7cea794200a6fee1155e54ca94bc...     12.884087
# 53   [0x149bc5c396fd3dccac39c92164bb6b8bccc4d215321...     13.396920
# 123  [0x149bc5c396fd3dccac39c92164bb6b8bccc4d215321...    160.417651
# 80   [0x9fb539aa3ddb63cda1c29b50fbeaa6071f290926ce1...    383.243668
#
#      atlas_gas_fees     fee_ratio
# 40         2.011750  1.000000e+00
# 49       670.497123  1.010657e+00
# 94         2.025524  1.082360e+00
# 121      728.688279  1.735732e+00
# 78         8.281891  1.885650e+00
# ..              ...           ...
# 10         0.434317  9.267021e+02
# 42         0.010967  1.174832e+03
# 53         0.009271  1.445007e+03
# 123        0.009271  1.730283e+04
# 80         0.000167  2.292180e+06
#
# [71 rows x 7 columns]

# %%
df.iloc[121].to_dict()
# Out:
# {'project_name': '0xc377ed1b705bcc856a628f961f1e7c8ca943e6f3727b7c179c657e227e8e852c',
#  'display_name': 'MerkleTreeJS',
#  'onchain_builder_oso_project_ids': ['ZzH9XQNZ7nWOlugpkz8GaQQEmQzx1rKxaPrvhJ+l87Y=',
#   'c/dKIiJnIKIxWPUPaAC30nS/TmqojvpagHXzV2L6td8=',
#   'VCeNot3diK3Kt0Da9SaRDvcNI1sGdrzyjTW62JUeI0U=',
#   'XREPTQE3axWeuZSDPwZorBfXWwCvrvu1FzVjQsnxEHU=',
#   '87Uygt4CNKHiBhvGlVmFtfsKiPrxJiEXWcRnubfQUpg=',
#   'RtKY/jR/ZQZcFZ3+6BIol7NCIenNffgO59/55hceklc=',
#   'lY3hN7xGe8jTGb9c9z2Sa6r2PmBV+FG9WJmC8Xwe46s=',
#   'R/brPbiaD8+ZOgc2k4NVBYT3oWYh50xHrkVT0zKFP94=',
#   'E9H3Htqh4/dCGgu9GUI+ksk7cayGewmtONFiBQWlveo=',
#   'kCF+D9wyJM2PvCFVlX9aKksPQmQEIKOsEnQUW3Bipog=',
#   '8/YZC7L8xkH8nVh1zywNf0hccJAYI09brdiIW1eizWg=',
#   '1PqWi/6kQu3j9O311xKAqoA9vYRJjIlLefadHnswYrE=',
#   '2l+DcexWOerkhRsKXiaWZam/soE6IQ5tVe7t4K202lo=',
#   'xyJHxLgvqigps6mdxRScLr8Gs8Xqs1UE/5JC7l6r/J0=',
#   'UP1CZduWIgDJysUtiSKzySeyLCf8ZoZD5PdWYPKiOIw=',
#   'SbFbagHrVLpnhXLPsZg6EYdenq1+y5k/aOkGXo32/Ww=',
#   'hMNrmX7nfpMimNe0zQmqdkZVy4PrhU3MIliN9gVR9y0=',
#   '/48A4/LZsBf1ztk3blMoY9kPQjx8knNp/EabsEszQ4Y=',
#   'PjPqPTput/vvThUxx6bMhInMKHuCV3t1s+K4YiHjIRg=',
#   'aGpGH8qz3FmBNtMGV/yB4PSWzsO7SlVKvqR+vk3+7NE=',
#   'SknvJ1fKqsEjRQTERy44BdTmY67lcFa3Yg9AHT5MwxQ=',
#   'oSD0LKbjJGzhzGmFtIPwPVNjbpM+H0nYDjLqoqi1dFs=',
#   'TNWtjYaVY+RmLblly/3JMQUQoo2A0sgOHU+Orzu3ETw=',
#   'Vx7z1aILR1NjIdw41GQj8a/WS4tsO4qYDFWrXQZGICg=',
#   'db8LWE2icLZuD0o0yjqQoxT4+oXvlmHMVT4O2TqKJCo=',
#   '+Yqnb1vNtZ7qeamha1KsaDhLsAIFFNR4ZVgM4svDOZ4=',
#   'BQZp9XtcWlf1qtTEAYicuop1b3B1gFkjBXa7eM0y4bE=',
#   'hE1BjGS8I9OXjnYATSkRnNJlsItBXO+CKXU6UPKJlRQ=',
#   '0rInH1b9Mh04BAwmikdFhcH/YDDR7xg7vxtho7SyKsY=',
#   'i/gSAlLU7P+FhIOzDQEk2+c5aOXKLmzAQILG8vqqJOE=',
#   'fHqtzjjFUIWmBZyZ3AAjjo7JPFRrTW4B3EvYGLVV3lY=',
#   'bH7G/ENlnW5HBSboJy/YMSBdS/hFmXXBXLowJ6OjsgE=',
#   '6E3DyJA6elKGNzeUnrVYN/T9kutfmbzXXNbOlvSfnZM=',
#   'ckq4jTDZI8VgQseutflTvtvIG5SawYliPbHPn3thsIw=',
#   'Eu/G6TDshnc7KD+Mp7VPTpdCuzNo2dWgG122vlC80bs=',
#   'Jpscljo0tkzVDYKwVNnTSuR+AFUyy4EHg4AWd+Mdnd4=',
#   'YHiJ6aGP9ewErBaAX0mIXKnffPEH5HMfEv+nFn0QuHU=',
#   'TsV9kZbHU7k/zigTlg8d7fFUcJ8Kn8YkaluyCauxUtM=',
#   'AZ2Cqzo/nAUqbj7th1e993Xfpf7qvT2WvHlomSZQ78o=',
#   'yZEfzA9tUugnZhQ0Yqx6FvvyEHiEgXVgx6A6tpglPdw=',
#   'qZ/9AgJZsXtI8LO6Oo4rtHU49ALCa5uQqRqOYmJVbts=',
#   'bOfxh42p5sbTXszPNBr2Puo/Pi8K58FoD42L35YvfqE=',
#   'L1FGc2AIMWcbDulPkpgzndWnljElZEAxxr+jPOdn0WQ=',
#   'UwA+rfAJH1h9rWmpcFNmmXQgXGDkkQvjALJ3ejmCWRc=',
#   '2D5YRxufnDHKS+HeGRxq/fquJWda1owfPsxOQFcXAys=',
#   'SIoNRfJjZLggEx5EQh0PpIOHxsUr1CAMkth1qolKAkk=',
#   'OZc8hUTVvRXzEXAMJ6IqHeYqiGCecD6pH396GAijm/Y=',
#   'CEgSH0sLKChprauip73TEAlNieWnpX+HRIV5re4xPIc=',
#   'g6Z4CSsse62oS12pTQrmQ5gu1iLt74uJP5rwFgdhX1c=',
#   'dOKZpVgYpZmAJZ+f0bYZWqKGpkz25Klgk4ZjY/fdyAc=',
#   'DD4IGEpD+WTpbHEOV/qeLj2x2WFlFsOAZJmuiEz/i4M=',
#   'bT2YDJIjVtlPp1jGKrofRmJ/UaIFeUD1eq1J+jeAkbA=',
#   'iOfFhoUyVo3E06Q1rH0JA6xoj/6XDj+7JQsnopmyhHQ=',
#   '4iXU/Dlz1CBdUGyuiUP6IiMJtBR+GKUn1tkbSSLOGQQ=',
#   'sPO1pl4Y+FnbbMxaMnMwDEGVxZFJzf6bGUNniLdJcaU=',
#   'SrAW7CxbX2q6KzPf1xXwJsc5IQZqIkDDOkAx3/nTS0M=',
#   'JTetyUvTgu3P3fKekPJHOjCG1Uuv2TfuDHm9hjADzPM=',
#   'v2QgByGF4okeRHMJmWN3tqZMxciee/qI2eeSPKK19gk=',
#   'Yip6KSrs+gfno8g3/30S4yVywtpfCLbKveLH48qcdHc=',
#   'hHje/yl10ng5XbAXgyeDEq3hxmOkjscMbS5XNqeAg7Q=',
#   'Ct5jVbi/Zrg6jKnkdVfUDhpX7W5we/1IuILp2FEDTi4=',
#   'Q3otD2dVMuz3OUvC1yAKkIrl9KIt8ksR1rOXG/vLvfI=',
#   '7CbZT+Alw8Biv6iCgptzNOvAwOUFg3FBfHQ/Msuw4no=',
#   '2n4F6KamVgheEeDfEHSMpn4cCKa8Y1WrMldDpvmLhqI=',
#   'VsbnIqH0Z8ErW7VixsMTGcLVf45E645bcxAVcD/KZT0=',
#   'imahnjIpbGgSkNyqkOjhlczoUga8ECPoEpirrLs68jQ=',
#   'UC5tcNndmH8tCdnc342+GHveHm2UcUu0bRRWa1afnXw=',
#   'GSKZ57Z6v+gqJ9WCtvjWJAhRCTpckr9IqrhyL3Xme4w=',
#   'bHGrs5wFQsPVTRZ9AALMgCizZwlL1BrL6iFLaIo9F2k=',
#   '1XmrMwdqgUb8jliAn9nIScPx7fAicOqIFPW42ioD1x0=',
#   'swsq1vWkoGPZXz3zXY+RKpFZO86SG8M0M69el1mleao=',
#   'LCI8TFIFGUudioEaZRR/WH6nLRppA/hazF5JKlZUil8=',
#   'MhGlk8E5mHyFD0WtdrjTXKY+be+00GhxWASP1V/Aieg=',
#   'pWEQHj4IsxU8lx2EDLJpphYaGAvw/yRps3vgTbVCXjQ=',
#   'f0ViLPH52qYlD4KiwHpElzx60i+1cXavyYjlA6MEDh0=',
#   'eid5gZ3mC0JHbMYg33dvcofcqwp2cvkhO3LZAt8fl7A='],
#  'onchain_builder_op_atlas_ids': ['0xbcb5c437d5347be21add3972512679054416805274f80e85ab8053ae79340a69',
#   '0x7539f43dc91f9c406c83a06339708e4033cdbf630916c6dfb9de2b5ef811affd',
#   '0x558ad0914eaf21a4965b2e4b7fef4cd66ef9d5bb861c5c42f4795a9e4614df71',
#   '0xa2a580dae44336df1cbcb7a5303880f393068fb96116e10e180e10f5745dccd4',
#   '0xca3f26e1c876e821d2384a5cb699c6be494f9810301c2e2be49c232656262642',
#   '0x72723e07fe409557489a6643b43d9493a94c10ba68230b0527f01834cb6a550f',
#   '0x000c2ce4773defb3010a58d3800d0ec9d432189c574ba26d3103f1db44a5af6d',
#   '0xafca3591b83586f14e21b397135b95af668f5ebb54cb45053af44a73df7d7640',
#   '0x79159d9bd4981ce68651fb4d585fd5827215309e503f46209adb0ec438f71b30',
#   '0x3061b642db56c507e265f03029735b0413a613bda43456a31e78128baeb18754',
#   '0xf87906563da69538c969ba438f127ce5f2196e76c84c9026ab6dafc4280b6be3',
#   '0x517eaa9c56951de89261f2d7830ea49aae92f2a903104a17d9c5c2edd4959806',
#   '0x149bc5c396fd3dccac39c92164bb6b8bccc4d215321b58e241af07a76616e031',
#   '0xf7669f10edbb4ca465f6a6b5ec7e90521a0011e8b3233c43e3cd0dd22633d67f',
#   '0x02065e72fe4eebfa1ebca19238e6147c8571c2b7fefae4e86e62ce768edceeb9',
#   '0xa492e54cf4d492c5f8a9c16038b4e5d47cd3bac575fbea7979f5cd1f1e575482',
#   '0xc6052138bbdae5976fa2866f46b0537182d4126c4bb97485738d1b43f2276134',
#   '0x0ee3defac0e2a31b995bc073ac02a2140aaf01679e141eb8d1d80409f75f90ea',
#   '0x08df6e20a3cfabbaf8f34d4f4d048fe7da40447c24be0f3ad513db6f13c755dd',
#   '0xe8833ceee8beb2b3fb0f7f2dcef576f6f9cf20e35d8e53324d71b0ed47b01982',
#   '0xff1edf67227651293a9cff4dce3577c6ca52bf8c7c6f5f133f07b05255379b27',
#   '0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff3f425de3503fd8dfa535',
#   '0xb9b7f1175044c211555b5589ee389263d2e455f99c1505e6b121cf6e3f5caaff',
#   '0x7eb6ba7a1057659d04ec414446c1b32509bf57704958139266c7120903446ad6'],
#  'oso_gas_fees': 1264.8079093293718,
#  'atlas_gas_fees': 728.6882786983473,
#  'fee_ratio': 1.7357324747815248}
