# %% [markdown]
# # Simulation of RF5 GitHub Metrics
#
# Ideas:
# 1. stars_total
# 2. stars_from_top_devs
# 3. forks_total
# 4. forks_from_top_devs
# 5. age_of_project
# 6. avg_fulltime_developers
# 7. unique_contributors_last_6_months

# %%
from google.cloud import bigquery
import os
import pandas as pd

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../../gcp_credentials.json'
client = bigquery.Client()

# %% [markdown]
# ## Queries to OSO

# %%
# get projects in RF3 but not in RF4

projects_query = """
    select
      project_id,
      project_name
    from `opensource-observer.oso.projects_by_collection_v1`
    where
        collection_name = 'op-rpgf3'
        and project_id not in (
            select project_id
            from `opensource-observer.oso.projects_by_collection_v1`
            where collection_name = 'op-retrofunding-4'
        )
"""
projects_query_results = client.query(projects_query)

# store as a dict
project_ids_names = projects_query_results.to_dataframe().set_index('project_id')['project_name'].to_dict()
len(project_ids_names)
# Out:
# 264

# %%
# warning: this query is expensive! use the parquet

events_query = f"""
    select
      events.project_id,
      events.bucket_day,      
      events.from_artifact_id as user_id,
      users.artifact_name as user,
      events.to_artifact_id as repo_id,
      repos.artifact_namespace as repo_owner,
      repos.artifact_name as repo_name,
      events.event_type,      
      events.amount
    from `opensource-observer.oso.int_events_daily_to_project` as events
    join `opensource-observer.oso.artifacts_v1` as users
      on events.from_artifact_id = users.artifact_id
    join `opensource-observer.oso.artifacts_v1` as repos
      on events.to_artifact_id = repos.artifact_id
    where
        events.event_source = 'GITHUB'
        and events.project_id in (
            select project_id
            from ({projects_query})
        )
"""

# events_query_results = client.query(events_query)
# df_events = events_query_results.to_dataframe()
# df_events.to_parquet("data/rf5_events.parquet")

df_events = pd.read_parquet("data/rf5_events.parquet")
df_events['project_name'] = df_events['project_id'].map(project_ids_names)
df_events.tail(1)
# Out:
#                                            project_id  \
# 2186651  y9t7a2RCN_Cxpi-g-8Qmb5txYxaC0nARzZwmwSWinuI=
#
#                        bucket_day  \
# 2186651 2022-03-09 00:00:00+00:00
#
#                                               user_id      user  \
# 2186651  ZQ53uNOIn9siBHNyFN836ij1XJf3R5I045bQGbTpZ_w=  emazurek
#
#                                               repo_id  repo_owner repo_name  \
# 2186651  aQosZmfg_aQpa6Hpb5kbbERkVVpkIsfmCqvzz-rsgvE=  foundry-rs      book
#
#                   event_type  amount project_name
# 2186651  PULL_REQUEST_OPENED     1.0      foundry

# %%
# get code metrics for projects

metrics_query = f"""
    select *
    from `opensource-observer.oso.code_metrics_by_project_v1`
    where project_id in (
        select project_id
        from ({projects_query})
    )
"""

metrics_query_results = client.query(metrics_query)
df_metrics = metrics_query_results.to_dataframe()
df_metrics.tail(1)
# Out:
#                                        project_id project_source  \
# 249  UNKoHLpnT_OziRiPCuX21uhgLNIJygsxuZz3A0TL-cg=  OSS_DIRECTORY
#
#     project_namespace    project_name    display_name event_source  \
# 249               oso  protocol-guild  Protocol Guild       GITHUB
#
#      repository_count         first_commit_date          last_commit_date  \
# 249               304 2015-01-01 18:35:06+00:00 2024-08-04 04:16:12+00:00
#
#      star_count  ...  contributor_count  contributor_count_6_months  \
# 249      175570  ...            17429.0                      1538.0
#
#      new_contributor_count_6_months  fulltime_developer_average_6_months  \
# 249                           901.0                            14.379121
#
#      active_developer_count_6_months  commit_count_6_months  \
# 249                            106.0                11757.0
#
#      opened_pull_request_count_6_months  merged_pull_request_count_6_months  \
# 249                              5574.0                              4315.0
#
#      opened_issue_count_6_months  closed_issue_count_6_months
# 249                       1688.0                       1711.0
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Derive some metrics

# %%
# identify the top N users from openrank

N = 420
users = pd.read_csv('data/openrank/users.csv')
top_users = users['peer'].iloc[:N].to_list()

# %%
# find the top ranked repo (by openrank) for each project

repos = pd.read_csv('data/openrank/repos.csv')
repos['rank'] = repos['a=0.5'].rank(ascending=False)
repo_rank = repos.set_index('peer')['rank'].to_dict()

df_repos = df_events[['project_name', 'repo_owner', 'repo_name']].drop_duplicates()
df_repos['artifact'] = df_repos.apply(lambda x: '/'.join([x['repo_owner'], x['repo_name']]), axis=1)
df_repos['repo_rank'] = df_repos['artifact'].apply(lambda x: repo_rank.get(x))

top_repo_rank = df_repos.groupby('project_name')['repo_rank'].min().sort_values()
top_repo_rank.head()
# Out:
# project_name
# testinprod-io        2.0
# reth-paradigmxyz    11.0
# foundry             18.0
# go-ethereum         23.0
# protocol-guild      23.0
# Name: repo_rank, dtype: float64

# %%
# derive the other metrics from the OSO event data

def metric_factory(metric, user_filter=None):
    metric_name = metric.lower()
    dff = df_events.query('event_type == @metric')
    if user_filter:
        metric_name += '_by_top_devs'
        dff = dff.query('user in @user_filter')
    series = (
        dff
        .groupby('project_name')['amount']
        .sum()
        .sort_values(ascending=False)
    )
    series.name = metric_name
    return series

metric_factory('STARRED', user_filter=top_users).head()
# Out:
# project_name
# protocol-guild    1332.0
# foundry            288.0
# openzeppelin       251.0
# wevm               160.0
# ipfs               156.0
# Name: starred_by_top_devs, dtype: float64

# %%
# get age of project

TODAY = 2024. + 8/12
age_of_project = df_events.groupby('project_name')['bucket_day'].min().apply(lambda x: TODAY - (x.year + x.month/12))
age_of_project.name = 'age_of_project_years'

# %% [markdown]
# ## Consolidate and export the data

# %%
metrics = [
    top_repo_rank,
    metric_factory('STARRED'),
    metric_factory('STARRED', user_filter=top_users),
    metric_factory('FORKED'),
    metric_factory('FORKED', user_filter=top_users),
    age_of_project
]

df = (
    df_metrics
    .set_index('project_name')
    [['display_name', 'repository_count', 'star_count', 'fork_count', 'fulltime_developer_average_6_months', 'new_contributor_count_6_months']]
    .join(pd.concat(metrics, axis=1))
)
df
# Out:
#                                                display_name  repository_count  \
# project_name
# hypeshothq                                       HypeshotHQ                 1
# ethereumbarcelona                              ETHBarcelona                 2
# project-squallet-refractor-labs  Project Squallet from Lore                 1
# nacion-bankless                             Nación Bankless                 2
# cannon-rs-badboilabs                              Cannon-rs                 1
# ...                                                     ...               ...
# justcause-smeee23                                 JustCause                 2
# filosofiacodigo                             FilosofiaCodigo                36
# revoke-cash                                          Revoke                 8
# nethermindeth                                    Nethermind               258
# protocol-guild                               Protocol Guild               304
#
#                                  star_count  fork_count  \
# project_name
# hypeshothq                                1           0
# ethereumbarcelona                         0           0
# project-squallet-refractor-labs           2           0
# nacion-bankless                           1           0
# cannon-rs-badboilabs                     44           6
# ...                                     ...         ...
# justcause-smeee23                         2           1
# filosofiacodigo                          61          51
# revoke-cash                             757         267
# nethermindeth                          3844        1379
# protocol-guild                       175570       78952
#
#                                  fulltime_developer_average_6_months  \
# project_name
# hypeshothq                                                       NaN
# ethereumbarcelona                                                NaN
# project-squallet-refractor-labs                                  NaN
# nacion-bankless                                                  NaN
# cannon-rs-badboilabs                                        0.000000
# ...                                                              ...
# justcause-smeee23                                           0.000000
# filosofiacodigo                                             0.000000
# revoke-cash                                                 0.862637
# nethermindeth                                               3.642857
# protocol-guild                                             14.379121
#
#                                  new_contributor_count_6_months  repo_rank  \
# project_name
# hypeshothq                                                  NaN        NaN
# ethereumbarcelona                                           NaN        NaN
# project-squallet-refractor-labs                             NaN    20253.0
# nacion-bankless                                             NaN        NaN
# cannon-rs-badboilabs                                        0.0      136.0
# ...                                                         ...        ...
# justcause-smeee23                                           0.0        NaN
# filosofiacodigo                                             0.0     6786.0
# revoke-cash                                                29.0      963.0
# nethermindeth                                             200.0       79.0
# protocol-guild                                            901.0       23.0
#
#                                   starred  starred_by_top_devs   forked  \
# project_name
# hypeshothq                            NaN                  NaN      NaN
# ethereumbarcelona                     NaN                  NaN      NaN
# project-squallet-refractor-labs       3.0                  NaN      NaN
# nacion-bankless                       1.0                  NaN      NaN
# cannon-rs-badboilabs                 51.0                 15.0      8.0
# ...                                   ...                  ...      ...
# justcause-smeee23                     2.0                  NaN      NaN
# filosofiacodigo                      63.0                  NaN     63.0
# revoke-cash                         883.0                 13.0    315.0
# nethermindeth                      4677.0                116.0   1624.0
# protocol-guild                   219990.0               1332.0  97706.0
#
#                                  forked_by_top_devs  age_of_project_years
# project_name
# hypeshothq                                      NaN                   NaN
# ethereumbarcelona                               NaN                   NaN
# project-squallet-refractor-labs                 NaN              0.750000
# nacion-bankless                                 NaN              1.000000
# cannon-rs-badboilabs                            1.0              1.833333
# ...                                             ...                   ...
# justcause-smeee23                               NaN              2.916667
# filosofiacodigo                                 NaN              3.250000
# revoke-cash                                     6.0              4.833333
# nethermindeth                                  39.0              6.583333
# protocol-guild                               1187.0              9.583333
#
# [250 rows x 12 columns]

# %%
df.to_csv("data/rf5_metrics_simulation.csv")
