# %% [markdown]
# # Simulation of RF5 GitHub Repo-Level Metrics
#
# Ideas:
# 1. stars_total
# 2. stars_from_top_devs
# 3. forks_total
# 4. forks_from_top_devs
# 5. age_of_project
# 6. avg_fulltime_developers
# 7. unique_contributors_last_6_months

# %%
from google.cloud import bigquery
import os
import pandas as pd

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../../gcp_credentials.json'
client = bigquery.Client()

# %% [markdown]
# ## Queries to OSO

# %%
# get projects in RF3 but not in RF4

projects_query = """
    select
      project_id,
      project_name
    from `opensource-observer.oso.projects_by_collection_v1`
    where
        collection_name = 'op-rpgf3'
        and project_id not in (
            select project_id
            from `opensource-observer.oso.projects_by_collection_v1`
            where collection_name = 'op-retrofunding-4'
        )
"""
projects_query_results = client.query(projects_query)

# store as a dict
project_ids_names = projects_query_results.to_dataframe().set_index('project_id')['project_name'].to_dict()
len(project_ids_names)
# Out:
# 264

# %%
# warning: this query is expensive! use the parquet

events_query = f"""
    select
      events.project_id,
      events.bucket_day,      
      events.from_artifact_id as user_id,
      users.artifact_name as user,
      events.to_artifact_id as repo_id,
      repos.artifact_namespace as repo_owner,
      repos.artifact_name as repo_name,
      events.event_type,      
      events.amount
    from `opensource-observer.oso.int_events_daily_to_project` as events
    join `opensource-observer.oso.artifacts_v1` as users
      on events.from_artifact_id = users.artifact_id
    join `opensource-observer.oso.artifacts_v1` as repos
      on events.to_artifact_id = repos.artifact_id
    where
        events.event_source = 'GITHUB'
        and events.project_id in (
            select project_id
            from ({projects_query})
        )
"""

# events_query_results = client.query(events_query)
# df_events = events_query_results.to_dataframe()
# df_events.to_parquet("data/rf5_events.parquet")

df_events = pd.read_parquet("data/rf5_events.parquet")
df_events['project_name'] = df_events['project_id'].map(project_ids_names)
df_events['artifact'] = df_events.apply(lambda x: '/'.join([x['repo_owner'], x['repo_name']]), axis=1)
artifact_list = df_events['artifact'].unique()
df_events.tail(1)
# Out:
#                                            project_id  \
# 2186651  y9t7a2RCN_Cxpi-g-8Qmb5txYxaC0nARzZwmwSWinuI=
#
#                        bucket_day  \
# 2186651 2022-03-09 00:00:00+00:00
#
#                                               user_id      user  \
# 2186651  ZQ53uNOIn9siBHNyFN836ij1XJf3R5I045bQGbTpZ_w=  emazurek
#
#                                               repo_id  repo_owner repo_name  \
# 2186651  aQosZmfg_aQpa6Hpb5kbbERkVVpkIsfmCqvzz-rsgvE=  foundry-rs      book
#
#                   event_type  amount project_name         artifact
# 2186651  PULL_REQUEST_OPENED     1.0      foundry  foundry-rs/book

# %%
# get code metrics for artifacts

metrics_query = f"""
    select *
    from `opensource-observer.oso.code_metrics_by_artifact_v0`
"""

metrics_query_results = client.query(metrics_query)
df_metrics = metrics_query_results.to_dataframe()
df_metrics['artifact'] = df_metrics.apply(lambda x: '/'.join([x['artifact_namespace'], x['artifact_name']]), axis=1)
df_metrics = df_metrics[df_metrics['artifact'].isin(artifact_list)]
df_metrics.tail(1)
# Out:
#                                         artifact_id artifact_namespace  \
# 46479  oq9zx8kNuZh4oAXf-0JFXmvNiXO93qdTfSqX07ZlDeM=               web3
#
#       artifact_name event_source         first_commit_date  \
# 46479       web3.js       GITHUB 2021-04-29 23:41:15+00:00
#
#                last_commit_date  star_count  fork_count  contributor_count  \
# 46479 2024-08-06 12:43:24+00:00       19066        4894             2303.0
#
#        contributor_count_6_months  new_contributor_count_6_months  \
# 46479                       104.0                            86.0
#
#        fulltime_developer_average_6_months  active_developer_count_6_months  \
# 46479                                  0.0                              6.0
#
#        commit_count_6_months  opened_pull_request_count_6_months  \
# 46479                  120.0                               188.0
#
#        merged_pull_request_count_6_months  opened_issue_count_6_months  \
# 46479                               121.0                        148.0
#
#        closed_issue_count_6_months      artifact
# 46479                        172.0  web3/web3.js

# %% [markdown]
# ## Derive some metrics

# %%
# identify the top N users from openrank

N = 420
users = pd.read_csv('data/openrank/users.csv')
top_users = users['peer'].iloc[:N].to_list()

# %%
# find the top ranked repo (by openrank) for each project
repos = pd.read_csv('data/openrank/repos.csv')
repos['rank'] = repos['a=0.5'].rank(ascending=False)
repo_rank = repos.set_index('peer')['rank'].to_dict()

df_repos = df_events[['repo_owner', 'repo_name']].drop_duplicates()
df_repos['artifact'] = df_repos.apply(lambda x: '/'.join([x['repo_owner'], x['repo_name']]), axis=1)
df_repos['repo_rank'] = df_repos['artifact'].apply(lambda x: repo_rank.get(x))

top_repo_rank = (
    df_repos
    .sort_values(['repo_owner', 'repo_rank'])
    .drop_duplicates('repo_owner', keep='first')
    .set_index('artifact')['repo_rank']
    .dropna()
    .sort_values()
)
top_repo_rank.head()
# Out:
# artifact
# testinprod-io/op-erigon     2.0
# paradigmxyz/reth           11.0
# foundry-rs/foundry         18.0
# ethereum/go-ethereum       23.0
# optimism-java/hildr        28.0
# Name: repo_rank, dtype: float64

# %%
# derive the other metrics from the OSO event data

def metric_factory(metric, user_filter=None):
    metric_name = metric.lower()
    dff = df_events.query('event_type == @metric')
    if user_filter:
        metric_name += '_by_top_devs'
        dff = dff.query('user in @user_filter')
    series = (
        dff
        .groupby('artifact')['amount']
        .sum()
        .sort_values(ascending=False)
    )
    series.name = metric_name
    return series

metric_factory('STARRED', user_filter=top_users).head()
# Out:
# artifact
# ethereum/go-ethereum    218.0
# ethereum/eips           126.0
# ethereum/solidity       114.0
# foundry-rs/foundry       95.0
# paradigmxyz/reth         76.0
# Name: starred_by_top_devs, dtype: float64

# %%
# get age of project

TODAY = 2024. + 8/12
age_of_project = df_events.groupby('artifact')['bucket_day'].min().apply(lambda x: TODAY - (x.year + x.month/12))
age_of_project.name = 'age_of_project_years'

# %%
df_metrics
# Out:
#                                         artifact_id artifact_namespace  \
# 11     P1MEbreq9MK5pnr7GehyoJKOwhHwM6WvxXwFoNSbAgE=          otterscan
# 34     -n3iNAgT2earAsOtMvgOkRUnPRd1B-pZa3e6RMhSIfg=      boardroom-inc
# 41     FAJnhumGCXneOf6dA1IuJnWjl_hxCnXcyVjp2tXkUZM=      gelatodigital
# 151    iQwCOYv0GooMWo1yP3ZZopX11qkG3ePVFXdkM5O0FEs=      boardroom-inc
# 169    jE83t1iRt1r-fEPRafbxaLfPhtc8jM-b4TEjPZZoNm4=    filosofiacodigo
# ...                                             ...                ...
# 46461  EZzhO7pzHe-oighbVcjMPHZt9nCPOLWMMBiJUAkBEZg=            crustio
# 46463  sUZ875Tw1HOIDmwjwWXLbX23sfSXhE2mVsO7yGOQwC0=        blocknative
# 46464  y7E_pBqUub6t4UDmk2MmeO_4UD8hAJLieYhD3ls5sbk=               ipfs
# 46469  OJsaun1W8kBAAICsz1IDjnt_cjDtOzR0vHuhHJg4zpg=           ethereum
# 46479  oq9zx8kNuZh4oAXf-0JFXmvNiXO93qdTfSqX07ZlDeM=               web3
#
#           artifact_name event_source         first_commit_date  \
# 11         go-otterscan       GITHUB                       NaT
# 34      subgraph-moloch       GITHUB                       NaT
# 41     range-orders-lib       GITHUB                       NaT
# 151        snapshot-hub       GITHUB                       NaT
# 169         web3example       GITHUB                       NaT
# ...                 ...          ...                       ...
# 46461      free-storage       GITHUB 2021-09-10 06:46:05+00:00
# 46463      web3-onboard       GITHUB 2019-10-03 19:07:17+00:00
# 46464      ipfs-desktop       GITHUB 2021-04-30 14:21:48+00:00
# 46469         remix-ide       GITHUB 2016-05-17 23:26:40+00:00
# 46479           web3.js       GITHUB 2021-04-29 23:41:15+00:00
#
#                last_commit_date  star_count  fork_count  contributor_count  \
# 11                          NaT           1           0                NaN
# 34                          NaT           1           0                NaN
# 41                          NaT           0           0                NaN
# 151                         NaT           1           0                NaN
# 169                         NaT           1           1                NaN
# ...                         ...         ...         ...                ...
# 46461 2021-12-24 06:36:03+00:00          37           2              286.0
# 46463 2024-08-07 19:13:25+00:00         820         483              446.0
# 46464 2024-06-13 22:31:11+00:00        5896         853              796.0
# 46469 2024-07-21 10:40:31+00:00        2243        1104              495.0
# 46479 2024-08-06 12:43:24+00:00       19066        4894             2303.0
#
#        contributor_count_6_months  new_contributor_count_6_months  \
# 11                            NaN                             NaN
# 34                            NaN                             NaN
# 41                            NaN                             NaN
# 151                           NaN                             NaN
# 169                           NaN                             NaN
# ...                           ...                             ...
# 46461                        21.0                            21.0
# 46463                        60.0                            44.0
# 46464                        53.0                            44.0
# 46469                        10.0                             7.0
# 46479                       104.0                            86.0
#
#        fulltime_developer_average_6_months  active_developer_count_6_months  \
# 11                                     NaN                              NaN
# 34                                     NaN                              NaN
# 41                                     NaN                              NaN
# 151                                    NaN                              NaN
# 169                                    NaN                              NaN
# ...                                    ...                              ...
# 46461                             0.000000                              0.0
# 46463                             0.203297                              2.0
# 46464                             0.000000                              2.0
# 46469                             0.000000                              3.0
# 46479                             0.000000                              6.0
#
#        commit_count_6_months  opened_pull_request_count_6_months  \
# 11                       NaN                                 NaN
# 34                       NaN                                 NaN
# 41                       NaN                                 NaN
# 151                      NaN                                 NaN
# 169                      NaN                                 NaN
# ...                      ...                                 ...
# 46461                    0.0                                 0.0
# 46463                   84.0                               142.0
# 46464                   31.0                                18.0
# 46469                   19.0                                21.0
# 46479                  120.0                               188.0
#
#        merged_pull_request_count_6_months  opened_issue_count_6_months  \
# 11                                    NaN                          NaN
# 34                                    NaN                          NaN
# 41                                    NaN                          NaN
# 151                                   NaN                          NaN
# 169                                   NaN                          NaN
# ...                                   ...                          ...
# 46461                                 0.0                         28.0
# 46463                               112.0                         41.0
# 46464                                17.0                         68.0
# 46469                                18.0                          0.0
# 46479                               121.0                        148.0
#
#        closed_issue_count_6_months                        artifact
# 11                             NaN          otterscan/go-otterscan
# 34                             NaN   boardroom-inc/subgraph-moloch
# 41                             NaN  gelatodigital/range-orders-lib
# 151                            NaN      boardroom-inc/snapshot-hub
# 169                            NaN     filosofiacodigo/web3example
# ...                            ...                             ...
# 46461                          6.0            crustio/free-storage
# 46463                         20.0        blocknative/web3-onboard
# 46464                         59.0               ipfs/ipfs-desktop
# 46469                          0.0              ethereum/remix-ide
# 46479                        172.0                    web3/web3.js
#
# [5694 rows x 19 columns]

# %% [markdown]
# ## Consolidate and export the data

# %%
metrics = [
    top_repo_rank,
    metric_factory('STARRED'),
    metric_factory('STARRED', user_filter=top_users),
    metric_factory('FORKED'),
    metric_factory('FORKED', user_filter=top_users),
    age_of_project
]

df = (
    df_metrics
    .set_index('artifact')
    [['star_count', 'fork_count', 'fulltime_developer_average_6_months', 'new_contributor_count_6_months']]
    .join(pd.concat(metrics, axis=1))
)
df = df[df['repo_rank'].isna() == False]
df.fillna(0, inplace=True)
df.sort_values(by='repo_rank', inplace=True)
df.head(20)
# Out:
#                            star_count  fork_count  \
# artifact
# testinprod-io/op-erigon            85          14
# paradigmxyz/reth                 3634         966
# foundry-rs/foundry               7969        1619
# ethereum/go-ethereum            47234       20139
# optimism-java/hildr                39          11
# bluealloy/revm                   1521         492
# alloy-rs/alloy                    492         166
# statechannels/go-nitro             37          20
# sigp/lighthouse                  2854         713
# nicenode/nice-node                181          27
# latticexyz/mud                    701         176
# ledgerwatch/erigon-lib             59          86
# l2beat/l2beat                     478         376
# nethermindeth/eigenlayer           32          20
# snapshot-labs/snapshot.js         225         575
# crytic/slither                   5181         953
# primitivefinance/arbiter          656          65
# opensource-observer/oso            57          13
# scopelift/scopelint                77           5
# otterscan/otterscan              1227         164
#
#                            fulltime_developer_average_6_months  \
# artifact
# testinprod-io/op-erigon                               0.038462
# paradigmxyz/reth                                      4.961538
# foundry-rs/foundry                                    2.302198
# ethereum/go-ethereum                                  1.631868
# optimism-java/hildr                                   0.000000
# bluealloy/revm                                        1.000000
# alloy-rs/alloy                                        2.439560
# statechannels/go-nitro                                0.000000
# sigp/lighthouse                                       0.000000
# nicenode/nice-node                                    0.368132
# latticexyz/mud                                        1.214286
# ledgerwatch/erigon-lib                                0.000000
# l2beat/l2beat                                         5.054945
# nethermindeth/eigenlayer                              0.000000
# snapshot-labs/snapshot.js                             0.153846
# crytic/slither                                        0.000000
# primitivefinance/arbiter                              0.192308
# opensource-observer/oso                               2.335165
# scopelift/scopelint                                   0.000000
# otterscan/otterscan                                   0.445055
#
#                            new_contributor_count_6_months  repo_rank  \
# artifact
# testinprod-io/op-erigon                              15.0        2.0
# paradigmxyz/reth                                    207.0       11.0
# foundry-rs/foundry                                  327.0       18.0
# ethereum/go-ethereum                                338.0       23.0
# optimism-java/hildr                                   2.0       28.0
# bluealloy/revm                                       54.0       29.0
# alloy-rs/alloy                                      125.0       32.0
# statechannels/go-nitro                                1.0       34.0
# sigp/lighthouse                                      59.0       47.0
# nicenode/nice-node                                    5.0       52.0
# latticexyz/mud                                       23.0       55.0
# ledgerwatch/erigon-lib                                0.0       65.0
# l2beat/l2beat                                        70.0       69.0
# nethermindeth/eigenlayer                              0.0       79.0
# snapshot-labs/snapshot.js                             9.0       83.0
# crytic/slither                                       43.0       93.0
# primitivefinance/arbiter                              2.0       94.0
# opensource-observer/oso                              12.0       95.0
# scopelift/scopelint                                   2.0       96.0
# otterscan/otterscan                                   4.0       99.0
#
#                             starred  starred_by_top_devs   forked  \
# artifact
# testinprod-io/op-erigon       104.0                 23.0     17.0
# paradigmxyz/reth             4182.0                 76.0   1336.0
# foundry-rs/foundry           9904.0                 95.0   2104.0
# ethereum/go-ethereum       118696.0                218.0  52818.0
# optimism-java/hildr            49.0                 13.0     10.0
# bluealloy/revm               1818.0                 55.0    585.0
# alloy-rs/alloy                578.0                 18.0    207.0
# statechannels/go-nitro         50.0                 14.0     17.0
# sigp/lighthouse              3639.0                 57.0    910.0
# nicenode/nice-node            211.0                  8.0     34.0
# latticexyz/mud                857.0                 22.0    247.0
# ledgerwatch/erigon-lib         84.0                  7.0    115.0
# l2beat/l2beat                 571.0                 12.0    451.0
# nethermindeth/eigenlayer       62.0                  3.0     21.0
# snapshot-labs/snapshot.js     262.0                  3.0    644.0
# crytic/slither               6288.0                 44.0   1281.0
# primitivefinance/arbiter      831.0                 35.0     82.0
# opensource-observer/oso        53.0                  5.0     14.0
# scopelift/scopelint            92.0                 15.0      7.0
# otterscan/otterscan          1498.0                 35.0    204.0
#
#                            forked_by_top_devs  age_of_project_years
# artifact
# testinprod-io/op-erigon                   2.0              1.500000
# paradigmxyz/reth                         83.0              1.666667
# foundry-rs/foundry                       94.0              2.916667
# ethereum/go-ethereum                    346.0              9.583333
# optimism-java/hildr                       3.0              1.250000
# bluealloy/revm                           48.0              2.916667
# alloy-rs/alloy                           26.0              0.750000
# statechannels/go-nitro                    1.0              2.833333
# sigp/lighthouse                          50.0              6.083333
# nicenode/nice-node                        1.0              2.333333
# latticexyz/mud                            4.0              2.000000
# ledgerwatch/erigon-lib                    9.0              3.166667
# l2beat/l2beat                            15.0              3.416667
# nethermindeth/eigenlayer                  1.0              0.833333
# snapshot-labs/snapshot.js                11.0              3.916667
# crytic/slither                           15.0              5.916667
# primitivefinance/arbiter                  5.0              1.750000
# opensource-observer/oso                   2.0              1.083333
# scopelift/scopelint                       0.0              1.833333
# otterscan/otterscan                       4.0              3.083333

# %%
df.to_csv("data/rf5_repo_metrics_simulation.csv")
