# %% [markdown]
# # RF5 GitHub Repo-Level Metrics
#
# - num contributors
# - num trusted_contributors
# - num active_contributors_6_months
# - num stars
# - num trusted_stars
# - num trust_weighted_stars
# - num forks
# - num trusted_forks
# - num trust_weighed_forks
# - age_of_repo
# - license

# %%
from google.cloud import bigquery
import json
import os
import pandas as pd

# %%
# add GCP project and credentials here
PROJECT = 'opensource-observer'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../../gcp_credentials.json'

# connect to OSO
client = bigquery.Client()

# %% [markdown]
# # Load and process the applications

# %%
applications = json.load(open("data/applications.json"))

# %%
projects_data = []

for app in applications:
    project = app.get('project', {})
    repos = project.get('repos', [])
    project_name = project.get('name')
    project_id = project.get('id')

    if repos:
        for repo in repos:
            repo_url = repo.get('url', None)
            
            # fix one edge case
            if repo_url.lower() == 'https://github.com/protocolguild/membership':
                repo_url = 'https://github.com/protocolguild/documentation'

            projects_data.append({
                'project_name': project_name,
                'project_id': project_id,
                'repo_url': repo_url,
                'repo_name': repo.get('name', None)
            })
    else:
        projects_data.append({
            'project_name': project_name,
            'project_id': project_id,
            'repo_url': None,
            'repo_name': None
        })

df_projects = pd.DataFrame(projects_data)

def extract_owner_and_repo(url):
    if url and isinstance(url, str):
        url = url.lower()
        if "github.com" in url:
            parts = url.split('/')
            if len(parts) >= 5:
                return f"{parts[3]}/{parts[4]}"
    return None

def clean_repo_url(owner_and_name):
    if owner_and_name:
        return f"https://github.com/{owner_and_name}"

df_projects['repo_owner_and_name'] = df_projects['repo_url'].apply(extract_owner_and_repo)
df_projects['clean_url'] = df_projects['repo_owner_and_name'].apply(clean_repo_url)

project_name_mappings = df_projects.set_index('project_id')['project_name'].to_dict()

df_projects
# Out:
#                                   project_name  \
# 0                        Stepan's test project
# 1                                Jonas Project
# 2                                 Test Project
# 3                               MonstersOnBase
# 4                             BASE BTC EARTH 🌍
# ..                                         ...
# 198                                NFT Starter
# 199                             Hedgio Podcast
# 200  Blockchef | Blockchain; From Farm to Fork
# 201                                  Rentality
# 202                                    OP Reth
#
#                                             project_id  \
# 0    0xbdd994bf9b06072f6f8603591c8907ca5a09a21fa14d...
# 1    0x83b46efce8ff1937a49883b323b22d3483d1843522f6...
# 2    0x52d53d44856f5a356053e55e3ad339d7207486b0210f...
# 3    0x1480383a90f1ab95cfedee6ea130dca700e5236eceb7...
# 4    0xcb0434aaf86a5dca68f96edefc22bf04a16bbfaa48b0...
# ..                                                 ...
# 198  0xd8012752e512ed8c6a47e61293bbad8cd942c9d016de...
# 199  0xe88826f4dde8d4abaa647a68763a4826fbb446e977cc...
# 200  0x679e661b67e85d937baace0bc56a6274dddfdffd8cce...
# 201  0xf04c2c47624bc0191001f655e147986439541493ee06...
# 202  0x5759249c433d67eeb2ca1b6ff827feec164b60b92e84...
#
#                                               repo_url        repo_name  \
# 0                                                 None             None
# 1            https://github.com/JSeiferth/op-analytics  This is my repo
# 2
# 3        https://github.com/mali030303/MonstersOnBasee             None
# 4       https://github.com/mali030303/BASE-BTC-EARTH--             None
# ..                                                 ...              ...
# 198           https://github.com/nonboring/nft-starter      NFT Starter
# 199                                               None             None
# 200            https://github.com/blockchef-io/OP-RPGF     OP-RPGF Repo
# 201  https://github.com/Rentality-xyz/Rentality-dem...             None
# 202                https://github.com/paradigmxyz/reth          OP Reth
#
#                         repo_owner_and_name  \
# 0                                      None
# 1                    jseiferth/op-analytics
# 2                                      None
# 3                mali030303/monstersonbasee
# 4               mali030303/base-btc-earth--
# ..                                      ...
# 198                   nonboring/nft-starter
# 199                                    None
# 200                    blockchef-io/op-rpgf
# 201  rentality-xyz/rentality-demo-contracts
# 202                        paradigmxyz/reth
#
#                                              clean_url
# 0                                                 None
# 1            https://github.com/jseiferth/op-analytics
# 2                                                 None
# 3        https://github.com/mali030303/monstersonbasee
# 4       https://github.com/mali030303/base-btc-earth--
# ..                                                 ...
# 198           https://github.com/nonboring/nft-starter
# 199                                               None
# 200            https://github.com/blockchef-io/op-rpgf
# 201  https://github.com/rentality-xyz/rentality-dem...
# 202                https://github.com/paradigmxyz/reth
#
# [203 rows x 6 columns]

# %%
repo_urls = list(df_projects['clean_url'].dropna().unique())
len(repo_urls)
# Out:
# 151

# %% [markdown]
# # Fetch data from OSO

# %%
# Get snapshot of repo metrics (taken 2024-09-16)

repo_urls_str = "'" + "','".join(repo_urls) + "'"
repos_query = f"""
    select
      abp.artifact_id,
      abp.artifact_namespace,
      abp.artifact_name,
      abp.artifact_url,
      abp.artifact_type,
      rm.is_fork,
      rm.fork_count,
      rm.star_count,
      rm.language,
      rm.license_spdx_id,
      abp.project_id as oso_project_id,
    from `{PROJECT}.oso.int_artifacts_in_ossd_by_project` as abp
    join `{PROJECT}.oso.int_repo_metrics_by_project` as rm
      on abp.artifact_id = rm.artifact_id
    where abp.artifact_url in ({repo_urls_str})
"""
repos_query_result = client.query(repos_query)
df_repos = repos_query_result.to_dataframe()
df_repos.tail(1)
# Out:
#                                       artifact_id artifact_namespace  \
# 136  aXbDRz3QGK6qa0CcrBNLAMi1qlw_eVaB-vq06PnT0O4=      kroma-network
#
#     artifact_name                            artifact_url artifact_type  \
# 136         kroma  https://github.com/kroma-network/kroma    REPOSITORY
#
#      is_fork  fork_count  star_count language license_spdx_id  \
# 136    False          80         158       Go     NOASSERTION
#
#                                    oso_project_id
# 136  F8npEwagURJOf7hOCr27eOcUjo9m51wa4KlOH0ZsO9c=

# %%
# identify any repos in apps that do not have data
print("Ignored repos:")
valid_repo_urls = []
for repo in repo_urls:
    if repo not in df_repos['artifact_url'].unique():
        print(repo)
    else:
        valid_repo_urls.append(repo)

print()        
print("Indexed repos:",len(valid_repo_urls))
# Out:
# Ignored repos:
# https://github.com/jseiferth/op-analytics
# https://github.com/mali030303/monstersonbasee
# https://github.com/mali030303/base-btc-earth--
# https://github.com/mali030303/dragons-on-op-stack--
# https://github.com/blockpilabs/aggregator
# https://github.com/richardgreg/execution-specs-contribution
# https://github.com/richardgreg/op-docs-improvements
# https://github.com/zeus199803/8-bit-cats--
# https://github.com/zeus199803/opstack-for-cats-dream-
# https://github.com/users/zeus199803
# https://github.com/blockchaindevsh/optimism
# https://github.com/jsvisa/retro5
# https://github.com/nonboring/nft-starter
# https://github.com/blockchef-io/op-rpgf
#
# Indexed repos: 137

# %%
len(sorted(valid_repo_urls))
# Out:
# 137

# %%
repo_app_mapping = (
    df_projects[df_projects.clean_url.isin(valid_repo_urls)]
    [['clean_url', 'project_id']]
    .drop_duplicates()
    .set_index('clean_url')['project_id']
    .to_dict()
)
df_repos['application_id'] = df_repos['artifact_url'].map(repo_app_mapping)
df_repos['license_spdx_id'].replace({'NOASSERTION': 'Custom'}, inplace=True)
df_repos.tail(10)
# Out:
#                                       artifact_id artifact_namespace  \
# 127  3jCFruW298HpaaxFgM7oXehQepEyqNA5FYxUG90VE6U=             libp2p
# 128  jTjb4W8VNrbdytj2UndNOJZW2YbnLjDvJLOJB5HfW7w=          probe-lab
# 129  RQjVPU9r1_204yjI-4JLaw7ntJBH58r37UYNOv3MN48=          status-im
# 130  uYxN0IH7L8_gIMv06vFY4gGaXUntqedx8Yoml0S2TQU=          vyperlang
# 131  K9mNvObyRSF085wsnLchYPEesFoyqjRMjL5q6p0OsRw=      kroma-network
# 132  CMQNxUSya5sOdelhRgeHXBcP_f8Dvv46jQCBBaXY134=      nethermindeth
# 133  l0eOSixCA_3ZFeg0dJhNNWW63p7JMWgvsSDvd9CX7z0=    cryptozombieshq
# 134  MEVv3odm6a8w83G5PB91ToGB_Om8A5WgqXJEb-aMx3E=             lexdao
# 135  D94ciJAItLnioR-AZ4XPeOgMD3boW46nMQLaJslkTuM=             libp2p
# 136  aXbDRz3QGK6qa0CcrBNLAMi1qlw_eVaB-vq06PnT0O4=      kroma-network
#
#             artifact_name                                       artifact_url  \
# 127             js-libp2p                https://github.com/libp2p/js-libp2p
# 128                hermes                https://github.com/probe-lab/hermes
# 129           nimbus-eth2           https://github.com/status-im/nimbus-eth2
# 130                 vyper                 https://github.com/vyperlang/vyper
# 131               tachyon           https://github.com/kroma-network/tachyon
# 132                 sedge             https://github.com/nethermindeth/sedge
# 133  cryptozombie-lessons  https://github.com/cryptozombieshq/cryptozombi...
# 134             lexcorpus                https://github.com/lexdao/lexcorpus
# 135            jvm-libp2p               https://github.com/libp2p/jvm-libp2p
# 136                 kroma             https://github.com/kroma-network/kroma
#
#     artifact_type  is_fork  fork_count  star_count    language  \
# 127    REPOSITORY    False         438        2293  TypeScript
# 128    REPOSITORY    False           5          15          Go
# 129    REPOSITORY    False         223         519         Nim
# 130    REPOSITORY    False         788        4839      Python
# 131    REPOSITORY    False         227        7777         C++
# 132    REPOSITORY    False          41         149          Go
# 133    REPOSITORY    False         545        1057  TypeScript
# 134    REPOSITORY    False          43         164    Solidity
# 135    REPOSITORY    False          75         264      Kotlin
# 136    REPOSITORY    False          80         158          Go
#
#     license_spdx_id                                oso_project_id  \
# 127          Custom  DIFwzDKrLDsrfbdzXMd0V-K852SAS7sR0loKq0bIlco=
# 128          Custom  N7NAEbsz1DwsTbATG73PWP0CeIk1uh2x4MLbXMaJkzs=
# 129          Custom  TPWyJq_aZvIAi16Dn7k_r3FBdrMq_sQZIyAWGZGzHF8=
# 130          Custom  9FPohrEjU-h_5BTmL-HBlyLH7f9rLprx2zqBddNDtn0=
# 131             MIT  F8npEwagURJOf7hOCr27eOcUjo9m51wa4KlOH0ZsO9c=
# 132      Apache-2.0  gwH5b9-f9zIzeDdketoo-MiyF-XZONwn-rkLJzNnf-U=
# 133          Custom  9S2DoYN6WOL4sAAa7RwQqFeyQXNju78UfpLWAO5HiQU=
# 134         GPL-3.0  k5ip2ng8cFp1NCCK9GmxeHKrGnciiE2JUd0uD8Fffb8=
# 135      Apache-2.0  DIFwzDKrLDsrfbdzXMd0V-K852SAS7sR0loKq0bIlco=
# 136          Custom  F8npEwagURJOf7hOCr27eOcUjo9m51wa4KlOH0ZsO9c=
#
#                                         application_id
# 127  0x5a7e7c7acb21521e99021d746740b368801cbfe53130...
# 128  0x7504e494cb8d227193182e083128912173c14eaeecec...
# 129  0xe346264e87202b47f1057eb0b0fcaa0ea7f83e14507c...
# 130  0x9ca1f7b0e0d10d3bd2619e51a54f2e4175e029c87a29...
# 131  0x8c76c13d8d0e63a7de499d47b9da5a4495d1151c0b20...
# 132  0x8431c44e2f0903879f34134e68fba4c05833b02451cc...
# 133  0xbd7efe4f47254e152bc1193b095dbad6711748577df2...
# 134  0x193256f7753cf4350332ab5222990944b45d7ae280cd...
# 135  0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d...
# 136  0x8c76c13d8d0e63a7de499d47b9da5a4495d1151c0b20...

# %%
artifact_app_mapping = df_repos.set_index('artifact_id')['application_id'].to_dict()
len(artifact_app_mapping)
# Out:
# 137

# %% [markdown]
# # Fetch OSO event data from relevant repos

# %%
# Get all event data (cutoff date of 2024-08-01)

artifact_ids = list(artifact_app_mapping.keys())
artifact_ids_str = "'" + "','".join(artifact_ids) + "'"

CUTOFF = '2024-08-01'

events_query = f"""
    select
        time,
        event_type,
        from_artifact_name as user,
        from_artifact_id,
        to_artifact_id 
    from `{PROJECT}.oso.int_events`
    where
        to_artifact_id in ({artifact_ids_str})
        and time < '{CUTOFF}'
"""

# uncomment everything below if you want live data, otherwise uses local backup

# events_query_results = client.query(events_query)
# df_events = events_query_results.to_dataframe()

# # add application ids
# df_events['application_id'] = df_events['to_artifact_id'].map(artifact_app_mapping)

# # filter bot activity
# bot_list = ['codecov-commenter', 'claassistant', 'googlebot', 'omahs']
# github_users = list(df_events['user'].unique())
# bots = [x for x in github_users if '[bot]' in x or x in bot_list]
# df_events = df_events[df_events['user'].isin(bots) == False]

# df_events.to_parquet("data/rf5_events.parquet")

# %%
df_events = pd.read_parquet("data/rf5_events.parquet")

df_events['bucket_day'] = pd.to_datetime(df_events['time'].dt.date)
df_events['amount'] = 1

df_events.tail(1)
# Out:
#                              time                   event_type  \
# 1052682 2023-07-31 13:25:23+00:00  PULL_REQUEST_REVIEW_COMMENT
#
#                    user                              from_artifact_id  \
# 1052682  thomaseizinger  xOfgF7_wYw1J5fCCwpUuFs53BTw1iXb1wenhuspVXXM=
#
#                                        to_artifact_id  \
# 1052682  dxsMNRXWzfg8lMvq0M4bY-NZ5961glN0Q-X64anZ8BI=
#
#                                             application_id bucket_day  amount
# 1052682  0xdf1bb03d08808e2d789f5eac8462bdc560f1bb5b0877... 2023-07-31       1

# %% [markdown]
# # Derive some metrics

# %%
# identify the top N users from openrank

N = 420
users = pd.read_csv('data/openrank/users.csv')
top_users = users['peer'].iloc[:N].to_list()

# %%
contributor_event_types = [
    'COMMIT_CODE',
    'PULL_REQUEST_OPENED',
    'PULL_REQUEST_REVIEW_COMMENT',
    'ISSUE_OPENED'
]

# %%
METRIC_INDEX = 'application_id'
metrics = []

metrics.append(
    df_repos
    .groupby(METRIC_INDEX)['artifact_url']
    .unique()
    .apply(lambda x: ', '.join(x))
    .rename('repo(s)')
)

metrics.append(
    df_events[df_events.event_type.isin(contributor_event_types)]
    .groupby(METRIC_INDEX)['from_artifact_id']
    .nunique()
    .rename('num_contributors')
)

metrics.append(
    df_events[
        (df_events.event_type.isin(contributor_event_types))
        & (df_events.user.isin(top_users))
    ]
    .groupby(METRIC_INDEX)['from_artifact_id']
    .nunique()
    .rename('num_trusted_contributors')
)

metrics.append(
    df_events[
        (df_events.event_type.isin(contributor_event_types))
        & (df_events['bucket_day'] >= pd.to_datetime('2024-02-01'))
    ]
    .groupby(METRIC_INDEX)['from_artifact_id']
    .nunique()
    .rename('num_contributors_last_6_months')
)

metrics.append(
    df_repos
    .groupby(METRIC_INDEX)['star_count']
    .sum()
    .rename('num_stars')
)

metrics.append(
    df_events[
        (df_events.event_type == 'STARRED')
        & (df_events.user.isin(top_users))
    ]
    .groupby(METRIC_INDEX)['from_artifact_id']
    .nunique()
    .rename('num_trusted_stars')
)

metrics.append(
    df_repos
    .groupby(METRIC_INDEX)['fork_count']
    .sum()
    .rename('num_forks')
)

metrics.append(
    df_events[
        (df_events.event_type == 'FORKED')
        & (df_events.user.isin(top_users))
    ]
    .groupby(METRIC_INDEX)['from_artifact_id']
    .nunique()
    .rename('num_trusted_forks')
)

metrics.append(
    df_events
    .groupby(METRIC_INDEX)['bucket_day']
    .min()
    .apply(lambda x: (2024. + 8/12.) - (x.year + x.month/12.))
    .rename('age_of_project_years')
)

metrics.append(
    df_repos
    .groupby(METRIC_INDEX)['license_spdx_id']
    .unique()
    .apply(lambda x: ', '.join([repo for repo in x if len(repo)]))
    .rename('license(s)')
)

df_metrics = pd.concat(metrics, axis=1)
df_metrics['project_name'] = df_metrics.index.map(project_name_mappings)

df_metrics
# Out:
#                                                                                               repo(s)  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...                 https://github.com/sigp/lighthouse
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...    https://github.com/ethereum-optimism/developers
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...  https://github.com/smartcontracts/simple-optim...
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...               https://github.com/libp2p/jvm-libp2p
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...        https://github.com/wakeuplabs/rfg1-optimism
# ...                                                                                               ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...  https://github.com/optimism-java/dispute-explo...
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...               https://github.com/dappnode/dappnode
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...  https://github.com/succinctlabs/sp1, https://g...
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...  https://github.com/rdubois-crypto/freshcryptol...
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...         https://github.com/testinprod-io/op-erigon
#
#                                                     num_contributors  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...             585.0
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...              44.0
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...              67.0
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...              49.0
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...               4.0
# ...                                                              ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...               3.0
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...             137.0
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...             111.0
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...              14.0
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...              27.0
#
#                                                     num_trusted_contributors  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...                      44.0
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...                       6.0
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...                       6.0
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...                      10.0
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...                       NaN
# ...                                                                      ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...                       NaN
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...                       5.0
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...                       5.0
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...                       3.0
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...                      11.0
#
#                                                     num_contributors_last_6_months  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...                           101.0
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...                            31.0
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...                            16.0
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...                             4.0
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...                             3.0
# ...                                                                            ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...                             3.0
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...                            11.0
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...                           111.0
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...                             6.0
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...                            19.0
#
#                                                     num_stars  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...       2882
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...         67
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...        323
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...        264
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...          2
# ...                                                       ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...          0
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...        581
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...        982
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...        161
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...         86
#
#                                                     num_trusted_stars  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...               44.0
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...                4.0
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...               22.0
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...                4.0
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...                NaN
# ...                                                               ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...                NaN
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...                8.0
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...               28.0
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...                8.0
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...               20.0
#
#                                                     num_forks  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...        724
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...         43
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...        112
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...         75
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...          1
# ...                                                       ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...          0
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...         99
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...        278
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...         24
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...         14
#
#                                                     num_trusted_forks  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...               41.0
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...                3.0
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...                8.0
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...                9.0
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...                NaN
# ...                                                               ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...                NaN
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...                1.0
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...                4.0
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...                2.0
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...                2.0
#
#                                                     age_of_project_years  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...              6.083333
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...              0.833333
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...              2.250000
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...              5.250000
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...              0.666667
# ...                                                                  ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...              0.166667
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...              6.500000
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...              0.500000
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...              1.416667
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...              1.500000
#
#                                                     license(s)  \
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...  Apache-2.0
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...     CC0-1.0
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...         MIT
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...  Apache-2.0
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...         MIT
# ...                                                        ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...         MIT
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...     GPL-3.0
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...  Apache-2.0
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...         MIT
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...    LGPL-3.0
#
#                                                                                          project_name
# application_id
# 0x04b1cd5a7c59117474ce414b309fa48e985bdaab4b0da...                                         Lighthouse
# 0x09875cfe708f0c3acaca3d8af6b1ca2bd45b43c4a268a...                                  TechNERDs Program
# 0x09b95c7697625da4915338750c5f78446817a3634cb38...                   Maintaining simple-optimism-node
# 0x0be3a0fa062180bdfbfdefa993b09acd9edcae93ba0d8...                                         jvm-libp2p
# 0x10e9fc6dd7d01e09bd9440d507846432333a06f779287...                           Token Historical Balance
# ...                                                                                               ...
# 0xf6ab5ce1bb1cade3c885b0668addb79ea8997b6dd2b10...                                         superproof
# 0xf839a585342327848d4541a6fcc315404e879537a60a1...                                           Dappnode
# 0xfad78fad680d407f81e7fd46632b4b4936676d1776a5c...  OP Succinct: Full ZK Validity Proving of OP St...
# 0xfef0eaf3c745a7175550a75ecfc0056d0a3276eeb0ce8...                                  Smoo.th Cryptolib
# 0xff3bed7d64f6f616e89032f8661f61259bc0b416ff39e...                                          OP Erigon
#
# [93 rows x 11 columns]

# %%
df_metrics.to_csv('data/rf5_applicant_github_metrics.csv')
