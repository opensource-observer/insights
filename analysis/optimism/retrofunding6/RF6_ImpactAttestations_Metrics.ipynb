# %% [markdown]
# # RF6 Impact Attestation Metrics
#
# Spec [here](https://plaid-cement-e44.notion.site/Impact-Attestations-Data-b8b1c79a624c46ad94305c74def64783).

# %%
import datetime
import json
import pandas as pd

from scripts.agora import agora_api
from scripts.farcaster import load_farcaster, refresh_farcaster
from scripts.metrics import calculate_metrics

# %% [markdown]
# # Load data

# %%
def convert_farcaster(farcaster_id):
    return int(farcaster_id['hex'], 16) if farcaster_id else None

# %%
#refresh_farcaster()
f = load_farcaster()

FARCASTER_USERS = pd.DataFrame(f)[['fid', 'username']].drop_duplicates().set_index('fid')['username'].to_dict()
FARCASTER_LINKED_ADDRESSES = pd.DataFrame(f)[['fid', 'address']].dropna().groupby('fid')['address'].apply(set).to_dict()
FARCASTER_ADDRESS_TO_ID = pd.DataFrame(f)[['fid', 'address']].dropna().set_index('address')['fid'].to_dict()

# %%
delegate_data = agora_api('delegates', params={'limit': 100, 'offset': 0, 'sort': 'voting_power'})
rf6_projects = agora_api('retrofunding/rounds/6/projects')

DELEGATES = [x['address'].lower() for x in delegate_data]
AGORA_IDS = [x['projectId'] for x in rf6_projects]
# Out:
# Fetched a total of 100 items from delegates.
# Fetched a total of 88 items from retrofunding/rounds/6/projects.

# %%
df_delegates = pd.DataFrame(delegate_data)
df_delegates['fid'] = df_delegates['address'].map(FARCASTER_ADDRESS_TO_ID)
df_delegates['username'] = df_delegates['fid'].map(FARCASTER_USERS)
df_delegates['username'].dropna()
# Out:
# 5       mattlosquadro
# 6               linda
# 7             polynya
# 8       olimpiocrypto
# 9        lefteris.eth
# 11         jackanorak
# 15          opmichael
# 18            brichis
# 22        katiegarcia
# 33                 wj
# 40             dmihal
# 41       theethernaut
# 42         griffgreen
# 43              gonna
# 47            launamu
# 48           afdudley
# 49            yoaveth
# 53      mattlosquadro
# 55              devon
# 61             pseudo
# 62    minimalgravitas
# 63             jrocki
# 73       alexpoon.eth
# 74          butterbum
# 80            forrest
# 86       chomtana.eth
# 89          nathanvdh
# 93        nanobro.eth
# 95               wish
# 96           dennison
# 97          0xdonpepe
# 98              zemse
# Name: username, dtype: object

# %%
rf6_projects_data = [{
    'id': x['id'],
    'applicationId': x['applicationId'],
    'projectId': x['projectId'],
    'name': x['name'],
    'organization': x['organization']['name'] if x.get('organization') else None,
    'applicationCategory': x['applicationCategory']
    }
    for x in rf6_projects
]
rf6_projects_df = pd.DataFrame(rf6_projects_data)
AGORA_NAMES = rf6_projects_df.set_index('projectId')['name'].to_dict()
AGORA_NAMES.update({'0x09261dbfb4dfa7116ee387d17dbbbdab9494de24cae1561ef7f25c8836b59e71': 'Syntra'})
rf6_projects_df.to_csv('data/_local/rf6_projects.csv')

# %%
def load_json(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    return data

project_attestation_data = load_json('data/attestations/472.json')
print("Project attestations:", len(project_attestation_data))

app_attestation_data = load_json('data/attestations/609.json')
print("Application attestations:", len(app_attestation_data))

badgeholder_attestation_data = load_json('data/attestations/599.json')
print("Badgeholder attestations:", len(badgeholder_attestation_data))

gov_council_attestation_data = load_json('data/attestations/141.json')
print("Gov Council attestations:", len(gov_council_attestation_data))

impact_attestation_data = load_json('data/attestations/566.json')
print("Impact attestations:", len(impact_attestation_data))
# Out:
# Project attestations: 4335
# Application attestations: 407
# Badgeholder attestations: 305
# Gov Council attestations: 222
# Impact attestations: 864

# %%
ATTESTER_ADDR = "0xf6872d315cc2e1aff6abae5dd814fd54755fe97c"

df_project_metadata = pd.DataFrame(project_attestation_data)
df_project_metadata = df_project_metadata[df_project_metadata.attester.str.lower() == ATTESTER_ADDR]
df_project_metadata.sort_values(by="timeCreated", ascending=False, inplace=True)
df_project_metadata.drop_duplicates(subset="projectRefUID", keep="first", inplace=True)

PROJECTS = list(df_project_metadata['projectRefUID'].unique())
print("Projects:", len(PROJECTS))
# Out:
# Projects: 3075

# %%
df_applications = pd.DataFrame(app_attestation_data)
df_applications = df_applications[df_applications.attester.str.lower() == ATTESTER_ADDR]
df_applications['round'] = df_applications['round'].apply(lambda x: str(x))
df_applications.sort_values(by="timeCreated", ascending=False, inplace=True)
df_applications.drop_duplicates(subset="metadataSnapshotRefUID", keep="first", inplace=True)

latest_metadata = list(df_project_metadata.id.unique())
df_applications = df_applications[df_applications.metadataSnapshotRefUID.isin(latest_metadata)]
print("Applications:", len(df_applications))
# Out:
# Applications: 138

# %% [markdown]
# # Clean / filter attestation data

# %%
ATTESTERS = []

for a in badgeholder_attestation_data:
    if a['attester'] != '0xE4553b743E74dA3424Ac51f8C1E586fd43aE226F':
        continue
    if a['voterType'] == 'Guest':
        continue

    addr = a['recipient'].lower()
    fid = convert_farcaster(a['farcasterID'])
    username = FARCASTER_USERS.get(fid, '')
    ATTESTERS.append({
        'address': addr,
        'farcaster_id': fid,
        'farcaster_username': username,
        'governance_role': 'Citizen',
        'source': 'attestation_schema_599'
    })
    linked_addresses = FARCASTER_LINKED_ADDRESSES.get(fid, [])
    for addr in linked_addresses:
        ATTESTERS.append({
            'address': addr.lower(),
            'farcaster_id': fid,
            'farcaster_username': username,
            'governance_role': 'Citizen',
            'source': 'farcaster_linked_address'
        })

for addr in DELEGATES:
    fid = FARCASTER_ADDRESS_TO_ID.get(addr, '')
    username = FARCASTER_USERS.get(fid, '')
    ATTESTERS.append({
        'address': addr.lower(),
        'farcaster_id': fid,
        'farcaster_username': username,
        'governance_role': 'Top 100 Delegate',
        'source': 'agora_api'
    })
    linked_addresses = FARCASTER_LINKED_ADDRESSES.get(fid, [])
    for addr in linked_addresses:
        ATTESTERS.append({
            'address': addr.lower(),
            'farcaster_id': fid,
            'farcaster_username': username,
            'governance_role': 'Top 100 Delegate',
            'source': 'farcaster_linked_address'
        })
    
len(ATTESTERS)
# Out:
# 560

# %%
mapped_roles = {
    'Badgeholder Reviewer': None,
    
    'ACC (Second half)': 'Anticapture Commission',
    'Anticapture Commission Member': 'Anticapture Commission',
    'Anticapture Commission Lead': 'Anticapture Commission',
    
    'Code of Conduct Council': 'Code of Conduct',
    'Code of Conduct Council Lead': 'Code of Conduct',
    'Code of Conduct Council Member': 'Code of Conduct',
    
    'Developer Advisory Board Lead': 'Developer Advisory Board',
    'Developer Advisory Board Member': 'Developer Advisory Board',
    
    'Optimism Grants Council Lead': 'Grants Council',
    'Optimism Grants Council Member': 'Grants Council',
    'DeFi Committee Group A': 'Grants Council',
    'DeFi Committee Group B': 'Grants Council',
    'DeFi Committee Group C': 'Grants Council',
    'NFT and Gaming Committee': 'Grants Council',    
    'Tooling and Infrastructure Committee': 'Grants Council',    
    
    'Security Council Lead': 'Security Council',
    'Security Council Member': 'Security Council',
    
    'Token House Feedback Commission': 'Feedback Commission',
    'Citizens House Feedback Commission': 'Feedback Commission'
}
df_gov_councils = pd.DataFrame(gov_council_attestation_data)
df_gov_councils = df_gov_councils[
    (df_gov_councils['attester'] == '0xE4553b743E74dA3424Ac51f8C1E586fd43aE226F')
]
df_gov_councils['recipient'] = df_gov_councils['recipient'].str.lower()
df_gov_councils['governance_council'] = df_gov_councils['govRole'].map(mapped_roles)

df_gov_councils['fid'] = df_gov_councils['recipient'].map(FARCASTER_ADDRESS_TO_ID)
df_gov_councils['farcaster_username'] = df_gov_councils['fid'].map(FARCASTER_USERS)

df_gov_councils.to_csv('data/_local/gov_council_members.csv')
df_gov_councils = df_gov_councils[df_gov_councils['govSeason'].isin(['5','6'])]
df_gov_councils['governance_council'].value_counts()
# Out:
# governance_council
# Anticapture Commission      23
# Grants Council              15
# Security Council            15
# Code of Conduct              7
# Developer Advisory Board     5
# Name: count, dtype: int64

# %%
df_attesters = (
    pd.DataFrame(ATTESTERS)
    .groupby(['address', 'farcaster_id', 'farcaster_username'])['governance_role']
    .agg(set)
    .reset_index()
    .set_index('address')
    .join(
        df_gov_councils
        .groupby('recipient')['governance_council']
        .apply(set)
    )
    .sort_values(by='governance_council')
    .reset_index()
    .rename(columns={'index': 'address'})
)

df_attesters.to_csv("data/_local/governance_users.csv")
df_attesters
# Out:
#                                         address farcaster_id  \
# 0    0x07fda67513ec0897866098a11dc3858089d4a505       318387
# 1    0xe93d59cc0bcecfd4ac204827ef67c5266079e2b5
# 2    0xe422d6c46a69e989ba6468ccd0435cb0c5c243e3       195722
# 3    0xdc0a92c350a52b6583e235a57901b8731af8b249       247606
# 4    0x8c580556fdb1f57853e49f409ae9b89f7658e7a2         7255
# ..                                          ...          ...
# 221  0xf51c53b2c184aa43a7d24aa4f0cf13d0e8b56c51        10572
# 222  0xf86a7a5b7c703b1fd8d93c500ac4cc75b67477f0            2
# 223  0xf9551c66995ed3ff9bb05c9fd7ff148bd75dc99a         5782
# 224  0xfb0a98121c3939657e59f835c66cfe20abb0cd4f       233135
# 225  0xfc10a71b1e7974401d840fd15cebf08ed7e115cc        20605
#
#     farcaster_username     governance_role        governance_council
# 0               v3naru           {Citizen}          {Grants Council}
# 1                       {Top 100 Delegate}  {Anticapture Commission}
# 2               joanbp           {Citizen}                    {None}
# 3                cpstl           {Citizen}                    {None}
# 4                 wish  {Top 100 Delegate}  {Anticapture Commission}
# ..                 ...                 ...                       ...
# 221              zemse  {Top 100 Delegate}                       NaN
# 222                  v           {Citizen}                       NaN
# 223          nathanvdh  {Top 100 Delegate}                       NaN
# 224          krzkaczor           {Citizen}                       NaN
# 225             jrocki  {Top 100 Delegate}                       NaN
#
# [226 rows x 5 columns]

# %%
df_mgl = pd.read_csv('data/_local/governance_infra_and_tooling_with_badgeholder.csv', index_col=0)
df_mgl.set_index('attestationUID', inplace=True, drop=True)
mgl_uids = list(df_mgl.index)
df_mgl.tail(1)
# Out:
#                                                     userfid  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...     9193
#
#                                                                                     ethaddress  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...  0x0000000000000000000000000000000000000000
#
#                                                    projectName    category  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...  Superfluid  Governance
#
#                                                         subcategory ecosystem  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...  Infra & Tooling  Optimism
#
#                                                     likely_to_recommend  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...                    7
#
#                                                    feeling_if_didnt_exist  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...                Neutral
#
#                                                                                           explanation  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...  I have only had limited interaction with it (a...
#
#                                                    private_feedback  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...              NaN
#
#                                                                    createdAt  \
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...  2024-10-28 02:46:52.4753
#
#                                                    contribution  Badgeholder
# attestationUID
# 0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736b...   Superfluid         True

# %%
df = pd.DataFrame(impact_attestation_data)
df['farcasterID'] = df['farcasterID'].apply(convert_farcaster)
df['farcasterUsername'] = df['farcasterID'].map(FARCASTER_USERS)
df['timeCreated'] = df['timeCreated'].apply(lambda x: datetime.datetime.utcfromtimestamp(x))

def get_name(metadata):
    if metadata.get('projectName'):
        return metadata.get('projectName')
    elif metadata.get('project'):
        return metadata.get('project').get('name')
    else:
        return None

df = df[df.id.isin(mgl_uids)]
df['mgl_project_name'] = df['metadata'].apply(get_name)

# provided by MGL team
overrides = {
    "0x8baac027df9c78c3dbda664c8f0190391e6b4bdabf240da9ccc4f0837933d8f2": "0x7753d360506e1d538e9a4720677595b2b811b3a3e74b81bd54c52ddfaaf51537", # MGL
    "0xfbca8cf7af5e74ffe1aea1f6850d0a427fb77286db170e478aca89f09b68e57c": "0xbb1e4aadda991e93d4ba4630582f222b2c57c0b0d729e29247cf2a3873936808", # Tribuni
    "0xf7248ad55667beaa6babe4700b52f5c868f60bdcb0e552f31369f78a22c7f1a6": "0xa88844cea135382e3484e39c3172033437121b35ca0bc8b10b9b8253984876b5", # EAS
    "0xdabe2dc1924e4422a8c9bc6ca7192666809579eb00c10e09360d5c4faa298001": "0x2aed462c71fc322e9b783e4b4454cdd01eb1909cdaf85f32ce70e9e5f3dc0f33", # Delegate Match
}
df['agoraProjectRegUID'] = df['projectRegUID'].apply(lambda x: overrides.get(x,x))

df['agora_project_name'] = df['agoraProjectRegUID'].map(AGORA_NAMES)

def get_scores(metadata):
    impact_eval_questions = metadata.get('impactAttestations', [])
    nps = pmf = None
    for q in impact_eval_questions:
        val = q.get('value')
        if not val:
            continue
        if q['name'] == 'Likely to Recommend':
            nps = pd.to_numeric(val)
        elif q['name'] == 'Feeling if didnt exist':
            pmf = pd.to_numeric(val)
    return {
        "NPS": nps,
        "PMF": pmf
    }

df['nps_score'] = df['metadata'].apply(lambda x: get_scores(x)['NPS'])
df['pmf_score'] = df['metadata'].apply(lambda x: get_scores(x)['PMF'])

roles = df_attesters.groupby('farcaster_id')['governance_role'].agg(lambda x: set.union(*x)).to_dict()
councils = (
    df_attesters[['farcaster_id', 'governance_council']]
    .dropna()
    .groupby('farcaster_id')['governance_council']
    .agg(lambda x: set.union(*x)).to_dict()
)
councils = {key: value for key, value in councils.items() if value != {None} and key != ''}
df['governance_role'] = df['farcasterID'].map(roles)
df['is_citizen'] = df['governance_role'].apply(lambda x: isinstance(x, set) and 'Citizen' in x)
df['is_top_delegate'] = df['governance_role'].apply(lambda x: isinstance(x, set) and 'Top 100 Delegate' in x)
df['governance_membership'] = df['farcasterID'].map(councils)
df = df.sort_values(by='timeCreated', ascending=False).drop_duplicates(
    subset=['farcasterID', 'is_top_delegate', 'projectRegUID']
)
df.tail(1)
# Out:
#                                                     id  \
# 106  0xb8b6bf5458a2f89a1b318817fecc5a9ec6696388bd56...
#
#                                        attester  \
# 106  0x7484aABFef9f39464F332e632047983b67571C0a
#
#                                       recipient         timeCreated  \
# 106  0x0000000000000000000000000000000000000000 2024-09-24 03:02:20
#
#                                     contributionRegUID  \
# 106  0x60d53d3890856123b9736ee8f6ef9c96ce8a218ec1db...
#
#                                          projectRegUID  farcasterID issuer  \
# 106  0xfbca8cf7af5e74ffe1aea1f6850d0a427fb77286db17...        11596    MGL
#
#                                            metadataurl  \
# 106  https://gateway.pinata.cloud/ipfs/QmPAYKUmYfba...
#
#                                               metadata farcasterUsername  \
# 106  {'id': 1777, 'userFid': '350951', 'projectName...           launamu
#
#     mgl_project_name                                 agoraProjectRegUID  \
# 106          Tribuni  0xbb1e4aadda991e93d4ba4630582f222b2c57c0b0d729...
#
#        agora_project_name  nps_score  pmf_score              governance_role  \
# 106  Tribuni Telegram Bot        NaN        NaN  {Citizen, Top 100 Delegate}
#
#      is_citizen  is_top_delegate governance_membership
# 106        True             True                   NaN

# %%
df_badgies = df.set_index('id').join(df_mgl)[['farcasterID', 'userfid','farcasterUsername', 'Badgeholder', 'is_citizen', 'is_top_delegate']]
df_badgies['match'] = df_badgies['Badgeholder'] == df_badgies['is_citizen']
df_badgies[df_badgies['match']==False].drop_duplicates()
# Out:
#                                                     farcasterID  userfid  \
# id
# 0xd9525afdf54265bffacd0e2231268b2f781ea1416f1ec...        20540    20540
# 0x4f3c64647fcab364494715c9c3e66c7678a65c62c41e3...          472      472
# 0x2bed302cf6a0635cf81d071b9d31c8f953ea4f454011a...       811331   811331
# 0x0d6c857e50ede71745bf0ed5a2d2e64bea4fed648c1fb...        12690    12690
# 0xf0e50324990451bc7cf78a5c78756da6d5cd120041ba7...        18507    18507
# 0xe70ff7efc95bae5d4c6d5031c80ebaa2daac8f459d9d2...       777864   777864
# 0xd01e1e803d3c1b116d090d0a76b97e15bbdfc24a09439...       300324   300324
#
#                                                    farcasterUsername  \
# id
# 0xd9525afdf54265bffacd0e2231268b2f781ea1416f1ec...   cryptochica.eth
# 0x4f3c64647fcab364494715c9c3e66c7678a65c62c41e3...              None
# 0x2bed302cf6a0635cf81d071b9d31c8f953ea4f454011a...          elenoosh
# 0x0d6c857e50ede71745bf0ed5a2d2e64bea4fed648c1fb...            owocki
# 0xf0e50324990451bc7cf78a5c78756da6d5cd120041ba7...       publicworks
# 0xe70ff7efc95bae5d4c6d5031c80ebaa2daac8f459d9d2...              None
# 0xd01e1e803d3c1b116d090d0a76b97e15bbdfc24a09439...      theethernaut
#
#                                                     Badgeholder  is_citizen  \
# id
# 0xd9525afdf54265bffacd0e2231268b2f781ea1416f1ec...         True       False
# 0x4f3c64647fcab364494715c9c3e66c7678a65c62c41e3...         True       False
# 0x2bed302cf6a0635cf81d071b9d31c8f953ea4f454011a...        False        True
# 0x0d6c857e50ede71745bf0ed5a2d2e64bea4fed648c1fb...         True       False
# 0xf0e50324990451bc7cf78a5c78756da6d5cd120041ba7...        False        True
# 0xe70ff7efc95bae5d4c6d5031c80ebaa2daac8f459d9d2...         True       False
# 0xd01e1e803d3c1b116d090d0a76b97e15bbdfc24a09439...        False        True
#
#                                                     is_top_delegate  match
# id
# 0xd9525afdf54265bffacd0e2231268b2f781ea1416f1ec...            False  False
# 0x4f3c64647fcab364494715c9c3e66c7678a65c62c41e3...            False  False
# 0x2bed302cf6a0635cf81d071b9d31c8f953ea4f454011a...            False  False
# 0x0d6c857e50ede71745bf0ed5a2d2e64bea4fed648c1fb...            False  False
# 0xf0e50324990451bc7cf78a5c78756da6d5cd120041ba7...            False  False
# 0xe70ff7efc95bae5d4c6d5031c80ebaa2daac8f459d9d2...            False  False
# 0xd01e1e803d3c1b116d090d0a76b97e15bbdfc24a09439...             True  False

# %% [markdown]
# # Create attestations dataframe

# %%
valid_attestations = (
    (df['agora_project_name'].isna()==False)
    & (df['governance_role'].isna()==False)
    & (df['nps_score'].isna() == False)
)
df_filtered = df[valid_attestations]
df_filtered['agora_project_name'].value_counts()
# Out:
# agora_project_name
# Snapshot                                                                            25
# Impact Evaluation Framework + Metrics Garden Database                               22
# Pairwise                                                                            15
# Superfluid                                                                          14
# Ethereum Attestation Service (EAS)                                                  14
# Curia OP Governance Analytics Dashboard                                             13
# CharmVerse Grants                                                                   13
# Gitcoin                                                                             13
# RetroPGF Hub                                                                        11
# RetroList                                                                           11
# OP Governance App                                                                   11
# Retro Funding Application Review                                                     9
# Onchain Impact Metrics for Retro Funding                                             8
# Praise                                                                               8
# Retro Funding 3 Voting App                                                           7
# GovScore                                                                             7
# Passport XYZ | Gitcoin Passport                                                      6
# OP Governance Contracts                                                              6
# Impact Calculator Experiment                                                         6
# Tribuni Telegram Bot                                                                 5
# Retro Funding App (Sign up and Identity)                                             5
# Token Engineering Commons                                                            4
# OPDelegate.com                                                                       4
# Delegate Match                                                                       4
# Attest Fest                                                                          4
# Retro 5 Metrics: Trusted Github Contributors/Stars/Forks                             4
# OP Passport                                                                          4
# Retro 4 Metrics: Trusted User Models and OpenRank Trusted User Model                 4
# Retro Funding & Token House API                                                      4
# Boardroom                                                                            3
# Proving Retroactive Funding with EZKL                                                3
# Optimism Grants Changelog                                                            3
# Retro 5 Expert Voter Selection: Developer Reputation Score using Recursive Trust     3
# Farcaster Attestation                                                                3
# Optimism Newsfeed + Assistant                                                        3
# Self-Serve Developer Ranking platform                                                2
# Impact Calculator Prototype                                                          2
# Lighthouse | Native Governance                                                       2
# Cantina.xyz - Security Audit for OP Cycle 19                                         2
# DeVouch powered by Giveth                                                            2
# Governance widget for X and Farcaster                                                1
# Superchain Attestation Explorer                                                      1
# Optimism Delegate Frame on Farcaster                                                 1
# FrameMaker                                                                           1
# Name: count, dtype: int64

# %%
df_normalized = df.copy()

df_normalized['valid_attestation'] = valid_attestations

cols = [
    'timeCreated', 'projectRegUID', 'mgl_project_name', 'agoraProjectRegUID', 'agora_project_name',
    'farcasterUsername', 'farcasterID', 'is_citizen', 'is_top_delegate', 'governance_role',
    'governance_membership', 'nps_score', 'pmf_score', 'valid_attestation',
    'id', 'attester', 'recipient', 'contributionRegUID', 'metadataurl', 'metadata'
]

df_normalized = df_normalized[cols]
df_normalized.sort_values(by='timeCreated', ascending=False, inplace=True)
df_normalized.to_csv("data/normalized_attestations.csv")

# %%
df_filtered[df_filtered['agoraProjectRegUID'] == '0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff3f425de3503fd8dfa535']
# Out:
#                                                     id  \
# 818  0x53478a97fec9fa86429c0bfded6b19a7e9b3b13b1736...
# 816  0x4a568b09573d058ccd75fcb5272df5ab0a722ae97413...
# 849  0xd1d65ee2b32e6465ba1357c11f1c156e46abcf68976c...
# 660  0x22ca426b47dbd5d4168c35c592cda7ef0573d65bd77e...
# 548  0x7d75887255b9ff4af9b2180808b081d7637ad1806100...
# 542  0x79c806e9d6b90396aa6c62b8868dfc7ffe0c861c3a3c...
# 451  0x226279e6283b6356d9b9fa9199dbdcef75a33da9e25f...
# 638  0xeeae87d62cef5152c758ca50f7d3c825ddc593a4a46d...
# 498  0x59cf59af45fc0221d381fe44b43113c568b61cf74ede...
# 448  0x18b25e07e8a9afed2fb13a3ab9f7a4b0031b78e070c6...
# 363  0x8c944c4a5443708bf6af320f029f65945eb993a35ad3...
# 300  0x2c03d54a8ed9447f0995e002f626fdf8989a1906c9a8...
# 274  0xa15895b97e3405364c0a39effda72f9be1f1410720de...
# 206  0x05b22b31f4debb391ff7f0b68fad115f3c4daa9a61f7...
#
#                                        attester  \
# 818  0x7484aABFef9f39464F332e632047983b67571C0a
# 816  0x7484aABFef9f39464F332e632047983b67571C0a
# 849  0x7484aABFef9f39464F332e632047983b67571C0a
# 660  0x7484aABFef9f39464F332e632047983b67571C0a
# 548  0x7484aABFef9f39464F332e632047983b67571C0a
# 542  0x7484aABFef9f39464F332e632047983b67571C0a
# 451  0x7484aABFef9f39464F332e632047983b67571C0a
# 638  0x7484aABFef9f39464F332e632047983b67571C0a
# 498  0x7484aABFef9f39464F332e632047983b67571C0a
# 448  0x7484aABFef9f39464F332e632047983b67571C0a
# 363  0x7484aABFef9f39464F332e632047983b67571C0a
# 300  0x7484aABFef9f39464F332e632047983b67571C0a
# 274  0x7484aABFef9f39464F332e632047983b67571C0a
# 206  0x7484aABFef9f39464F332e632047983b67571C0a
#
#                                       recipient         timeCreated  \
# 818  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-28 02:46:52
# 816  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-27 21:00:05
# 849  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-27 16:15:31
# 660  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-23 16:30:20
# 548  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-23 07:29:18
# 542  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-22 20:04:18
# 451  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-21 20:30:34
# 638  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-21 18:26:54
# 498  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-21 16:19:11
# 448  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-21 14:30:38
# 363  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-18 17:41:09
# 300  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-16 22:29:45
# 274  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-15 18:01:41
# 206  0x6b9Bd00ac672CBD939F5Ea88B9e5cF1A4013f6ef 2024-10-12 08:31:07
#
#                                     contributionRegUID  \
# 818  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 816  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 849  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 660  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 548  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 542  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 451  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 638  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 498  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 448  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 363  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 300  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 274  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
# 206  0x14efe58273fb2e2c53cec0e30c293aed48be721d1cfc...
#
#                                          projectRegUID  farcasterID issuer  \
# 818  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...         9193    MGL
# 816  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...       328679    MGL
# 849  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...         4293    MGL
# 660  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...         8317    MGL
# 548  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...       384391    MGL
# 542  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...         9305    MGL
# 451  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...         6187    MGL
# 638  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...         9749    MGL
# 498  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...        17229    MGL
# 448  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...         3864    MGL
# 363  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...        21291    MGL
# 300  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...       318387    MGL
# 274  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...        19412    MGL
# 206  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...       776318    MGL
#
#                                            metadataurl  \
# 818  https://gateway.pinata.cloud/ipfs/QmXiWX36LtUv...
# 816  https://gateway.pinata.cloud/ipfs/QmREAo5nkSzY...
# 849  https://gateway.pinata.cloud/ipfs/QmXbPGS47nEK...
# 660  https://gateway.pinata.cloud/ipfs/QmVN7Tq7fjEY...
# 548  https://gateway.pinata.cloud/ipfs/QmS66FqmuqiW...
# 542  https://gateway.pinata.cloud/ipfs/QmZdn3ZJJ9cM...
# 451  https://gateway.pinata.cloud/ipfs/QmWVAj8VxfUj...
# 638  https://gateway.pinata.cloud/ipfs/QmTzjqwSUWvj...
# 498  https://gateway.pinata.cloud/ipfs/QmUxaKuGj1pz...
# 448  https://gateway.pinata.cloud/ipfs/QmQE9EgtoPLq...
# 363  https://gateway.pinata.cloud/ipfs/QmaD1cyQp9MR...
# 300  https://gateway.pinata.cloud/ipfs/QmYaG1okt7Zg...
# 274  https://gateway.pinata.cloud/ipfs/QmQgSNBAJpJw...
# 206  https://gateway.pinata.cloud/ipfs/QmbqHxDUdu1R...
#
#                                               metadata farcasterUsername  \
# 818  {'id': 1865, 'project': {'name': 'Superfluid',...            ricmoo
# 816  {'id': 1865, 'project': {'name': 'Superfluid',...      chomtana.eth
# 849  {'id': 1865, 'project': {'name': 'Superfluid',...         dcbuilder
# 660  {'id': 1865, 'project': {'name': 'Superfluid',...        thesleeper
# 548  {'id': 1865, 'project': {'name': 'Superfluid',...            fujiar
# 542  {'id': 1865, 'project': {'name': 'Superfluid',...        criptonita
# 451  {'id': 1865, 'project': {'name': 'Superfluid',...        weboftrust
# 638  {'id': 1865, 'project': {'name': 'Superfluid',...               kbw
# 498  {'id': 1865, 'project': {'name': 'Superfluid',...             gonna
# 448  {'id': 1865, 'project': {'name': 'Superfluid',...      spengrah.eth
# 363  {'id': 1865, 'project': {'name': 'Superfluid',...       nanobro.eth
# 300  {'id': 1865, 'project': {'name': 'Superfluid',...            v3naru
# 274  {'id': 1865, 'project': {'name': 'Superfluid',...             cerv1
# 206  {'id': 1865, 'project': {'name': 'Superfluid',...            tamper
#
#     mgl_project_name                                 agoraProjectRegUID  \
# 818       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 816       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 849       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 660       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 548       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 542       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 451       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 638       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 498       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 448       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 363       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 300       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 274       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
# 206       Superfluid  0x3ecbf66c1b21342b26acb0f7d4c6b8bbbef168ffafff...
#
#     agora_project_name  nps_score  pmf_score              governance_role  \
# 818         Superfluid        7.0        1.0                    {Citizen}
# 816         Superfluid        7.0        2.0           {Top 100 Delegate}
# 849         Superfluid       10.0        3.0                    {Citizen}
# 660         Superfluid        7.0        1.0                    {Citizen}
# 548         Superfluid       10.0        3.0                    {Citizen}
# 542         Superfluid        6.0        1.0                    {Citizen}
# 451         Superfluid        7.0        2.0                    {Citizen}
# 638         Superfluid        8.0        2.0                    {Citizen}
# 498         Superfluid        7.0        1.0  {Citizen, Top 100 Delegate}
# 448         Superfluid        8.0        2.0                    {Citizen}
# 363         Superfluid       10.0        2.0           {Top 100 Delegate}
# 300         Superfluid       10.0        3.0                    {Citizen}
# 274         Superfluid       10.0        2.0                    {Citizen}
# 206         Superfluid       10.0        3.0                    {Citizen}
#
#      is_citizen  is_top_delegate                     governance_membership
# 818        True            False                                       NaN
# 816       False             True                                       NaN
# 849        True            False                                       NaN
# 660        True            False                                       NaN
# 548        True            False                                       NaN
# 542        True            False                                       NaN
# 451        True            False                  {Anticapture Commission}
# 638        True            False                                       NaN
# 498        True             True  {Anticapture Commission, Grants Council}
# 448        True            False                                       NaN
# 363       False             True                                       NaN
# 300        True            False                          {Grants Council}
# 274        True            False                                       NaN
# 206        True            False                                       NaN

# %% [markdown]
# # Implement metrics on relevant attestations

# %%
metrics = calculate_metrics(df_filtered)

with open("data/attestation_metrics.json", "w") as f:
    json.dump(metrics,f,indent=2)

# %% [markdown]
# # Create dummy attestations

# %%
import random
import secrets

# %%
ATTESTERS = {}
for _, a in df_attesters.iterrows():
    addr = a['address']
    if addr in ATTESTERS:
        continue
    ATTESTERS.update({
        addr: {
            'is_citizen': 'Citizen' in a['governance_role'],
            'is_top_delegate': 'Top 100 Delegate' in a['governance_role'],
            'governance_membership': a['governance_council'] if isinstance(a, set) else {}
        }
    })

# %%
NUM_PROJECTS = 30
NUM_ATTESTERS = 100
NUM_ATTESTATIONS = 1000
PMF_SCALE = 3
NPS_SCALE = 10

projects = {
    p: random.random()
    for p in random.choices(PROJECTS, k=NUM_PROJECTS)
}

attesters = {
    addr:ATTESTERS[addr]
    for addr in random.choices(list(ATTESTERS.keys()), k=NUM_ATTESTERS)
}

dummy_attestations = []
for i in range(NUM_ATTESTATIONS):
    random_project = random.choice(list(projects.keys()))
    random_attester = random.choice(list(attesters.keys()))
    project_impact = projects.get(random_project)
    pmf_score = random.randint(int(project_impact*PMF_SCALE), PMF_SCALE)
    nps_score = random.randint(int(project_impact*NPS_SCALE), NPS_SCALE)
    dummy_attestations.append({
        'id': f"0x{secrets.token_hex(32)}",
        'attester': random_attester,
        'projectRegUID': random_project,
        'pmf_score': max(1,pmf_score),
        'nps_score': max(1,nps_score),
        **attesters[random_attester]
    })

# %%
df_dummy = pd.DataFrame(dummy_attestations)
dummy_metrics = calculate_metrics(df_dummy)

# %%
# with open("data/dummy_metrics_v2.json", "w") as f:
#     json.dump(dummy_metrics, f, indent=2)
