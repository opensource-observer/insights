# %%
import pandas as pd
import json
import yaml

# %%
oso = pd.read_csv("RetroPGF3 Projects - OSO Snapshot.csv", index_col=0)
slug_mapping = dict(oso['OSO Slug'])

# %%
df = pd.read_csv("RetroPGF3 Results - ConsolidatedData.csv")
df['slug'] = df['Project ID'].map(slug_mapping)
url = "https://vote.optimism.io/retropgf/3/application/"
df['link'] = df['Project ID'].apply(lambda x: f"{url}{x}")
df.rename(columns={'Meta: Project Name': 'project', 'Result: Received OP': 'amount'}, inplace=True)
df = df[['project', 'link', 'amount', 'slug']]
df['tags'] = "RetroPGF3"

df.loc[122,'slug'] = 'rainbow'
df.loc[33,'slug'] = 'gitcoin'

df.head()
# Out:
#           project                                               link  \
# 0  Protocol Guild  https://vote.optimism.io/retropgf/3/applicatio...
# 1     go-ethereum  https://vote.optimism.io/retropgf/3/applicatio...
# 2        Solidity  https://vote.optimism.io/retropgf/3/applicatio...
# 3          Erigon  https://vote.optimism.io/retropgf/3/applicatio...
# 4       ethers.js  https://vote.optimism.io/retropgf/3/applicatio...
#
#       amount                slug       tags
# 0  663853.62      protocol-guild  RetroPGF3
# 1  496896.42         go-ethereum  RetroPGF3
# 2  422361.96            solidity  RetroPGF3
# 3  339545.72  erigon-ledgerwatch  RetroPGF3
# 4  298137.85           ethers-io  RetroPGF3

# %%
df2 = pd.read_json("2023-10-01_op_tracked_grants.json")

def fix_tags(x):
    if isinstance(x, list):
        s = ", ".join(x)
    else:
        s = ", ".join(eval(x))
    return s.replace("RPGF", "RetroPGF")
        
df2['tags'] = df2['tags'].apply(fix_tags)

# %%
combined = pd.concat([df,df2], axis=0, ignore_index=True)
combined['slug'] = combined['slug'].apply(lambda x: x if x != "" else None)
combined
# Out:
#                            project  \
# 0                   Protocol Guild
# 1                      go-ethereum
# 2                         Solidity
# 3                           Erigon
# 4                        ethers.js
# ...                            ...
# 1073   Perpetuals Dune Abstraction
# 1074  raise_exception (rotate.eth)
# 1075           Optimism Cult Merch
# 1076             Thumbs Up Finance
# 1077                        Ospace
#
#                                                    link     amount  \
# 0     https://vote.optimism.io/retropgf/3/applicatio...  663853.62
# 1     https://vote.optimism.io/retropgf/3/applicatio...  496896.42
# 2     https://vote.optimism.io/retropgf/3/applicatio...  422361.96
# 3     https://vote.optimism.io/retropgf/3/applicatio...  339545.72
# 4     https://vote.optimism.io/retropgf/3/applicatio...  298137.85
# ...                                                 ...        ...
# 1073  https://app.optimism.io/retropgf-discovery/0x0...    2069.00
# 1074  https://app.optimism.io/retropgf-discovery/0x4...    2044.00
# 1075  https://app.optimism.io/retropgf-discovery/0x5...    1863.00
# 1076  https://app.optimism.io/retropgf-discovery/0x4...     725.00
# 1077  https://app.optimism.io/retropgf-discovery/0x9...     594.00
#
#                     slug       tags
# 0         protocol-guild  RetroPGF3
# 1            go-ethereum  RetroPGF3
# 2               solidity  RetroPGF3
# 3     erigon-ledgerwatch  RetroPGF3
# 4              ethers-io  RetroPGF3
# ...                  ...        ...
# 1073                None  RetroPGF2
# 1074                None  RetroPGF2
# 1075                None  RetroPGF2
# 1076                None  RetroPGF2
# 1077                None  RetroPGF2
#
# [1078 rows x 5 columns]

# %%
d = yaml.safe_load(open("../dune/op_dune_namespaces_to_ossd.yaml"))
dune = pd.Series(d).reset_index()
dune.columns = ['dune_namespace', 'slug']
dune_mapping = dune.groupby('slug')['dune_namespace'].agg(lambda x: ", ".join(set(x)))

# %%
combined['dune_namespace'] = combined['slug'].map(dune_mapping)

# %%
combined.sort_values(by=['dune_namespace', 'slug', 'project']).reset_index(drop=True).to_csv("2024-02-06_op_tracked_grants.csv")

# %%
combined[combined['slug'].isna()==False]
# Out:
#                        project  \
# 0               Protocol Guild
# 1                  go-ethereum
# 2                     Solidity
# 3                       Erigon
# 4                    ethers.js
# ..                         ...
# 972                        Gov
# 973  ERC-5560: Redeemable NFTs
# 974                  Questbook
# 975                  Rigoblock
# 976                   NFTEarth
#
#                                                   link     amount  \
# 0    https://vote.optimism.io/retropgf/3/applicatio...  663853.62
# 1    https://vote.optimism.io/retropgf/3/applicatio...  496896.42
# 2    https://vote.optimism.io/retropgf/3/applicatio...  422361.96
# 3    https://vote.optimism.io/retropgf/3/applicatio...  339545.72
# 4    https://vote.optimism.io/retropgf/3/applicatio...  298137.85
# ..                                                 ...        ...
# 972  https://app.optimism.io/retropgf-discovery/0xa...    1080.00
# 973  https://app.optimism.io/retropgf-discovery/0x5...    1073.00
# 974  https://app.optimism.io/retropgf-discovery/0x4...    1015.00
# 975  https://app.optimism.io/retropgf-discovery/0x0...     928.00
# 976  https://app.optimism.io/retropgf-discovery/0xD...     594.00
#
#                    slug       tags dune_namespace
# 0        protocol-guild  RetroPGF3            NaN
# 1           go-ethereum  RetroPGF3            NaN
# 2              solidity  RetroPGF3            NaN
# 3    erigon-ledgerwatch  RetroPGF3            NaN
# 4             ethers-io  RetroPGF3            NaN
# ..                  ...        ...            ...
# 972            gov-w3hc  RetroPGF2            NaN
# 973             ato-nft  RetroPGF2            NaN
# 974           questbook  RetroPGF2            NaN
# 975          rigo-block  RetroPGF2      RigoBlock
# 976            nftearth  RetroPGF2       NFTEarth
#
# [651 rows x 6 columns]

# %%
combined['amount'].sum()
# Out:
# 108792336.64
