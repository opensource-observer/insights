# %% [markdown]
# # Worldchain User Modeling
#
# - Get data via Pyoso --> [here](https://docs.opensource.observer/docs/get-started/python)
# - Get raw data via BigQuery --> [here](https://docs.opensource.observer/docs/integrate/datasets/#superchain)
# - View OSO staging model definitions --> [here](https://github.com/opensource-observer/oso/tree/main/warehouse/oso_sqlmesh/models/staging/superchain)

# %%
# ! pip install pyoso

# %%
from dotenv import load_dotenv
import os
import pandas as pd
from pyoso import Client

load_dotenv()
OSO_API_KEY = os.environ['OSO_API_KEY']
client = Client(api_key=OSO_API_KEY)

# %%
TEST_CONTRACT = '0xcd1E32B86953D79a6AC58e813D2EA7a1790cAb63'.lower()

# %%
df_traces = client.to_pandas(f"""
    SELECT *
    FROM stg_superchain__traces
    WHERE
        chain = 'WORLDCHAIN'
        AND to_address = '{TEST_CONTRACT}'
        AND block_timestamp BETWEEN DATE '2025-03-29' and DATE '2025-03-30'
    LIMIT 5
""")
df_traces
# Out:
#            block_timestamp                                   transaction_hash  \
# 0  2025-03-29 13:39:05.000  0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...
# 1  2025-03-29 18:23:45.000  0xaeedc08c15c43d638bcbf5c15a26f7c7739e0e969906...
# 2  2025-03-29 02:40:21.000  0x762d0aa92b99823c0b61328f122b82e485e892f43ae9...
# 3  2025-03-29 14:42:15.000  0x2ac72a868587388ea7d0708c3080b733406b9c2e6b64...
# 4  2025-03-29 16:18:21.000  0xebebf1d6f1c94dc9eec033a52d613bf4543f52a4c514...
#
#                                  from_address  \
# 0  0xe7155fbfe051f624091efbb050b19a36ece2e044
# 1  0xfd7539c735f0e415cad6c5a81a3973d07eb30533
# 2  0xaeabb822aa345e4daeef75d015983ee1ace75cdb
# 3  0x377d74d621852cd891071e55283608233d4d4fd7
# 4  0x70854a3335c2dbdb85df592069e16a6f6f4750eb
#
#                                    to_address  gas_used       chain
# 0  0xcd1e32b86953d79a6ac58e813d2ea7a1790cab63    229871  WORLDCHAIN
# 1  0xcd1e32b86953d79a6ac58e813d2ea7a1790cab63    229871  WORLDCHAIN
# 2  0xcd1e32b86953d79a6ac58e813d2ea7a1790cab63    229871  WORLDCHAIN
# 3  0xcd1e32b86953d79a6ac58e813d2ea7a1790cab63    229871  WORLDCHAIN
# 4  0xcd1e32b86953d79a6ac58e813d2ea7a1790cab63    229871  WORLDCHAIN

# %%
TEST_HASH = df_traces['transaction_hash'].iloc[0]
TEST_HASH
# Out:
# '0xc1c70e8820e4f3752a7851c1d648205c969e3067889f66f1eb4e1fb2f1fb53fe'

# %%
df_4337_traces = client.to_pandas(f"""
    SELECT *
    FROM stg_superchain__4337_traces
    WHERE
        chain = 'WORLDCHAIN'
        AND transaction_hash = '{TEST_HASH}'
        AND block_timestamp BETWEEN DATE '2025-03-29' and DATE '2025-03-30'
""")
df_4337_traces.tail()
# Out:
#          chain          block_timestamp  \
# 7   WORLDCHAIN  2025-03-29 13:39:05.000
# 8   WORLDCHAIN  2025-03-29 13:39:05.000
# 9   WORLDCHAIN  2025-03-29 13:39:05.000
# 10  WORLDCHAIN  2025-03-29 13:39:05.000
# 11  WORLDCHAIN  2025-03-29 13:39:05.000
#
#                                      transaction_hash  \
# 7   0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...
# 8   0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...
# 9   0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...
# 10  0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...
# 11  0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...
#
#                                           userop_hash   method_id  \
# 7   0x75d49e1b6ae58184178da056464f3fac1e3a9ac3834a...  0x7bb37428
# 8   0x0c8fb54404844f6db1d6de1392f98b73da0ca6fa1dda...  0x7bb37428
# 9   0x1325fd65c67a06b39890f65cc0e2d4760872cbc7d19d...  0x7bb37428
# 10  0xa1bc8a974bad49b4cbef1f7a05a29b56d4cf0375056f...  0x7bb37428
# 11  0x52402b78d1e309c5c7a11b05afec02efb7e240d56494...  0x7bb37428
#
#                                   from_address  \
# 7   0x4e8ab9d3e2a290b565bc77c2287c6d68e5479901
# 8   0xa8b0fe5b6126e31f9761238c0c9cf42d05e7d575
# 9   0xe7155fbfe051f624091efbb050b19a36ece2e044
# 10  0x0d012028073a568c4836077265a14902aacefa14
# 11  0x93b993556f4680be0ddf44e16d8acb47e55c69d9
#
#                                     to_address  \
# 7   0x75cf11467937ce3f2f357ce24ffc3dbf8fd5c226
# 8   0x75cf11467937ce3f2f357ce24ffc3dbf8fd5c226
# 9   0x75cf11467937ce3f2f357ce24ffc3dbf8fd5c226
# 10  0x75cf11467937ce3f2f357ce24ffc3dbf8fd5c226
# 11  0x75cf11467937ce3f2f357ce24ffc3dbf8fd5c226
#
#                                bundler_address  \
# 7   0x8f47a238c7701247ee8469ddc37ac1df121cfcce
# 8   0x8f47a238c7701247ee8469ddc37ac1df121cfcce
# 9   0x8f47a238c7701247ee8469ddc37ac1df121cfcce
# 10  0x8f47a238c7701247ee8469ddc37ac1df121cfcce
# 11  0x8f47a238c7701247ee8469ddc37ac1df121cfcce
#
#                              paymaster_address  userop_gas_price  \
# 7   0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b       69148154660
# 8   0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b       77491436490
# 9   0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b      125301433088
# 10  0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b       74132676046
# 11  0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b       64003262882
#
#     userop_gas_used                 value
# 7            567430  0.000000000000000000
# 8            635895  0.000000000000000000
# 9           1028224  0.000000000000000000
# 10           608333  0.000000000000000000
# 11           525211  0.000000000000000000

# %%
df_4337_logs = client.to_pandas(f"""
    SELECT *
    FROM stg_superchain__4337_userop_logs
    WHERE
        chain = 'WORLDCHAIN'
        AND transaction_hash = '{TEST_HASH}'
        AND block_timestamp BETWEEN DATE '2025-03-29' and DATE '2025-03-30'
""")
df_4337_logs.tail()
# Out:
#             block_timestamp  \
# 7   2025-03-29 13:39:05.000
# 8   2025-03-29 13:39:05.000
# 9   2025-03-29 13:39:05.000
# 10  2025-03-29 13:39:05.000
# 11  2025-03-29 13:39:05.000
#
#                                      transaction_hash  log_index  \
# 7   0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...        236
# 8   0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...        255
# 9   0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...        245
# 10  0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...        217
# 11  0xc1c70e8820e4f3752a7851c1d648205c969e3067889f...        227
#
#                                           userop_hash  \
# 7   0xd953333376b5d60ae787b350494e72241bde7f8a237c...
# 8   0x1325fd65c67a06b39890f65cc0e2d4760872cbc7d19d...
# 9   0xde9ffc70a8fcf92c46d0a149a34fd7cf3eca93f95581...
# 10  0x0c8fb54404844f6db1d6de1392f98b73da0ca6fa1dda...
# 11  0xa3f342d5dbb1e332e5f282eca7ae3c2e867fff623b4a...
#
#                                 sender_address  \
# 7   0x30e04472766a96a4fe18483945871d5b0deebd68
# 8   0xe7155fbfe051f624091efbb050b19a36ece2e044
# 9   0xba97c26102db594ec885b283e7772e997115e536
# 10  0xa8b0fe5b6126e31f9761238c0c9cf42d05e7d575
# 11  0x8ca7cb5580205bca17d42c7f2b4970d1baf6a804
#
#                              paymaster_address  \
# 7   0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b
# 8   0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b
# 9   0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b
# 10  0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b
# 11  0xef725aa22d43ea69fb22be2ebe6eca205a6bcf5b
#
#                               contract_address  userop_gas_price  \
# 7   0x0000000071727de22e5e9d8baf0edac6f37da032      118053446914
# 8   0x0000000071727de22e5e9d8baf0edac6f37da032      125301433088
# 9   0x0000000071727de22e5e9d8baf0edac6f37da032       70105380670
# 10  0x0000000071727de22e5e9d8baf0edac6f37da032       77491436490
# 11  0x0000000071727de22e5e9d8baf0edac6f37da032      119700411844
#
#     userop_gas_used       chain
# 7            968747  WORLDCHAIN
# 8           1028224  WORLDCHAIN
# 9            575285  WORLDCHAIN
# 10           635895  WORLDCHAIN
# 11           982262  WORLDCHAIN
