# %%
# ! pip install pyoso

# %%
from dotenv import load_dotenv
import os
import pandas as pd
from pyoso import Client

load_dotenv()
OSO_API_KEY = os.environ['OSO_API_KEY']
client = Client(api_key=OSO_API_KEY)

# %%
# Helper function for inserting arrays into queries
def stringify(arr):
    return "'" + "','".join(arr) + "'"

# %% [markdown]
# ## Identifying relevant projects

# %%
# Approach 1: use OSO's collection_names
client.to_pandas("""
    SELECT
        p.project_id,
        p.project_source,
        p.project_name AS name_of_oso_project_file,
        p.display_name
    FROM projects_v1 AS p
    JOIN projects_by_collection_v1 AS pbc ON pbc.project_id = p.project_id
    WHERE pbc.collection_name = 'optimism'
""")
# Out:
#                                        project_id project_source  \
# 0    qH3xmb7F+NVyPA7WyNZBz38LjRiqgTyOm8BErjMO/Kw=  OSS_DIRECTORY
# 1    d3peEk5lBmuaMIpngrwaHzvw5AjlX80QqJk9TlrypaQ=  OSS_DIRECTORY
# 2    KHoI9CsfmTDAaqorYNCL2PnzxZSORHSuDAPZMma+sic=  OSS_DIRECTORY
# 3    ZPW/NLGzTCCfCUpb6LQD+Nei314hKSgnghJ5z0T1t7U=  OSS_DIRECTORY
# 4    36HjWnU2xdrCKxiyFGLV37hFZTUbq13dMxq8Pj0nNgY=  OSS_DIRECTORY
# ..                                            ...            ...
# 718  mSqhiRtouVTDJVd4W8gxDlEZLXPtyqSC5qComGVn17c=  OSS_DIRECTORY
# 719  SthV5g2Q1yIGtXOXTbasXOnGsP+YGZr3303aM3rZ0/k=  OSS_DIRECTORY
# 720  4ahxM2T2GW1Xl2gGh+jqUE7ICT1P4h8XqbW5RbyDGck=  OSS_DIRECTORY
# 721  9IE7nBPNl0g93qBfjjCAq2KUNwJeGPrzEeWsLxbolDM=  OSS_DIRECTORY
# 722  Q3otD2dVMuz3OUvC1yAKkIrl9KIt8ksR1rOXG/vLvfI=  OSS_DIRECTORY
#
#            name_of_oso_project_file                         display_name
# 0                            0xparc                               0xPARC
# 1                    0xdeployer-ham                                  Ham
# 2                           0xbcamp  Optimism Solidity Survivor Bootcamp
# 3                              xkcp                       Keccak hashing
# 4    op-stack-deployer-aymen-tirchi                    OP Stack Deployer
# ..                              ...                                  ...
# 718                        tockable                         Tockable.xyz
# 719                           zkbob                                zkBob
# 720            op-ai-web-asharibali                Optimism AI - ChatBot
# 721                    merkletreejs                         MerkleTreeJS
# 722                 orbiter-finance                      Orbiter Finance
#
# [723 rows x 4 columns]

# %%
# Approach 2: look for any project in OP Atlas
client.to_pandas("""
    SELECT
        project_id,
        project_name AS op_atlas_project_id,
        display_name
    FROM projects_v1
    WHERE project_source = 'OP_ATLAS'
""")
# Out:
#                                         project_id  \
# 0     d0+th/VV4DyybzeNhR/rwUq21vxXk06/m5M/cFj6uV0=
# 1     uaJShij8ROn3iSY1/RXM4rpoIsFfiMxiqnwz3hvZr2U=
# 2     uCKDCr1sSPS7CrtfaLKF1lSuUVdiqxg05olV1W5960w=
# 3     0ZCHPDlHDXDH3oukC8m8Y+j5fne2e8U27K0f7h4LAp0=
# 4     W+qRLLjycC/irEAyvLutPJc8vBxY2MA9LGO1TmvgY2E=
# ...                                            ...
# 4201  1oQNkde2mop7Zi9/zPHo0i0jgC+XaYrjoVYTNjmvq0o=
# 4202  F5HzmjRu6nzwsVjVysAegOirPGg/mkda6frIIu2Ub8c=
# 4203  R9FLih4SpPMNWxx0TDO64yaHObu9oNIUkxihwgxwYTQ=
# 4204  zRCEkA4DYlBaORjO2/HnM/49DW+j8Qn+aw/nL8uAfUs=
# 4205  6avWWRaFmPf1QJ9ZkFFypjS7NLG9CcKGtfF3LnBGUNc=
#
#                                     op_atlas_project_id  \
# 0     0xaa64734cea7bda013313aec2a1a60ecc7f7dd1e4236f...
# 1     0x7a6613bcd93169c489f4f26e0d9d2a7a566b515a5110...
# 2     0x558c98305d61f176db5e58ff2629c79669da243c4b54...
# 3     0x42f468879efad6fbb010a9180f84286646bbb0be1b5f...
# 4     0xdd3daa81ae038baa1c4dd58bc043f063a09f9cc6ad35...
# ...                                                 ...
# 4201  0x8624c6a494bfaa7632ff5c11553a7d9747ef96e78cc3...
# 4202  0x1d8c423fe6dd98d66ada25a19e800533d573cc27bb4b...
# 4203  0x6cb4bfbe64f50f4280280350e549d92bdabdd83dfe91...
# 4204  0x8b4a901ec1d46fae552f73782e0f8b851328eb6b4dc1...
# 4205  0x1874030dc79203f106c67f2b1f6a2b600c4efe9a2c15...
#
#                                            display_name
# 0                                                 stVol
# 1                                                Hallos
# 2                                     Superchain Headz
# 3                           WannaBet Weekly Tournaments
# 4                                /christin on farcaster
# ...                                                 ...
# 4201                                               gabo
# 4202                                             Unitap
# 4203                                           dFantasy
# 4204  Onchain Blobs - Randomly generated onchain blo...
# 4205                   The book of optimism fault proof
#
# [4206 rows x 3 columns]

# %%
# Approach 3: look for any GitHub org that shows up in either OSO or OP_ATLAS
df_projects = client.to_pandas("""
    WITH project_githubs AS (
      SELECT DISTINCT
        project_id,
        artifact_namespace AS github_org
      FROM artifacts_by_project_v1
      WHERE artifact_source = 'GITHUB'
    )
    SELECT
        pg.github_org,
        ARRAY_AGG(DISTINCT CASE WHEN pbc.collection_name = 'optimism' THEN p.project_name END)
          AS oso_project_files,
        ARRAY_AGG(DISTINCT CASE WHEN p.project_source = 'OP_ATLAS' THEN p.project_name END)
          AS op_atlas_project_ids,
        ARRAY_AGG(DISTINCT p.display_name) AS project_display_names,
        ARRAY_AGG(DISTINCT pg.project_id) AS oso_project_ids
    FROM project_githubs AS pg
    JOIN projects_by_collection_v1 AS pbc ON pg.project_id = pbc.project_id
    JOIN projects_v1 AS p ON pg.project_id = p.project_id
    WHERE pbc.collection_name = 'optimism' OR p.project_source = 'OP_ATLAS'
    GROUP BY 1
""")
df_projects
# Out:
#           github_org                             oso_project_files  \
# 0      gelatodigital                                [gelato, None]
# 1       openzeppelin  [openzeppelin, ethernaut-openzeppelin, None]
# 2    theopenxproject                             [theopenxproject]
# 3     cliqueofficial                              [cliqueofficial]
# 4        fraxfinance                                 [fraxfinance]
# ..               ...                                           ...
# 822        mcgingras                             [mcgingras-loot2]
# 823         seedclub                                  [enjoy-tech]
# 824          air3app                                        [None]
# 825     arpa-network                                [arpa-network]
# 826           0xngmi                                  [defi-llama]
#
#                                   op_atlas_project_ids  \
# 0    [None, 0xa492e54cf4d492c5f8a9c16038b4e5d47cd3b...
# 1    [None, 0x17fb589e599fe05e532b90c121eccc55b1249...
# 2                                               [None]
# 3                                               [None]
# 4                                               [None]
# ..                                                 ...
# 822                                             [None]
# 823                                             [None]
# 824  [0xf9ebb0464e7162627ab3de5fe03a21c879e932233e1...
# 825                                             [None]
# 826                                             [None]
#
#                                  project_display_names  \
# 0      [Gelato, Gelato Automate SDK, Gelato Relay SDK]
# 1    [OpenZeppelin, The Ethernaut, OpenZeppelin Con...
# 2                                 [The Open X Project]
# 3                                             [Clique]
# 4                                       [Frax Finance]
# ..                                                 ...
# 822                                            [Loot2]
# 823                                       [Enjoy.tech]
# 824                                             [Air3]
# 825                                    [ARPA Randcast]
# 826                                        [DefiLlama]
#
#                                        oso_project_ids
# 0    [CEgSH0sLKChprauip73TEAlNieWnpX+HRIV5re4xPIc=,...
# 1    [EFNan6yoGom5N81+Hlb8ZSQdM3B1+iJRRM0TxITQeG8=,...
# 2       [BWsrccmjhL8a4Qa3h3ZSCF0uxLKM9tK3ZAN9gWCY4a8=]
# 3       [YDCitqeeymU1hJBfZpJ4sMuWjk1bCwFgcMKaTiUoNVE=]
# 4       [1PqWi/6kQu3j9O311xKAqoA9vYRJjIlLefadHnswYrE=]
# ..                                                 ...
# 822     [x27+XcfTVX+0lGH6Red5Pig20HKKVE1/EjDtsOe5knc=]
# 823     [6rBTpjfkCGptucRNLz80FUkhaxg0Hm07bzb824NkHXA=]
# 824     [dk1gwy0G/dP9SOcyolL+bfgPQJ0ngqXF6ro9qyQdGwo=]
# 825     [Ft17RswF9aY0wmGSpke3RbNbjfHh8w64ve+mewxjqH8=]
# 826     [ySYOlDwzICYsw0F8V4bIuzehqWUIUDOV0hHu4r+nAWU=]
#
# [827 rows x 5 columns]

# %%
# How many total projects do we identify?
PROJECT_IDS = [x for lst in df_projects['oso_project_ids'] for x in lst]
len(PROJECT_IDS)
# Out:
# 1048

# %% [markdown]
# ## Let's pull some metrics

# %%
alltime_metrics = client.to_pandas("SELECT DISTINCT metric_name, display_name FROM metrics_v0 WHERE metric_name LIKE '%all_time' ORDER BY 1")
alltime_metrics.tail(5)
# Out:
#                                  metric_name          display_name
# 290      ZORA_active_contracts_over_all_time      Active Contracts
# 291  ZORA_contract_invocations_over_all_time  Contract Invocations
# 292         ZORA_defillama_tvl_over_all_time         Defillama TVL
# 293              ZORA_gas_fees_over_all_time              Gas Fees
# 294          ZORA_transactions_over_all_time          Transactions

# %%
sorted(list(alltime_metrics['display_name'].unique()))
# Out:
# ['Active Addresses Aggregation',
#  'Active Contracts',
#  'Active Developers',
#  'Average PR Time to Merge',
#  'Average Time to First Response',
#  'Closed Issues',
#  'Comments',
#  'Commits',
#  'Contract Invocations',
#  'Contributors',
#  'Defillama TVL',
#  'Forks',
#  'Funding Received',
#  'Gas Fees',
#  'Merged Pull Requests',
#  'Opened Issues',
#  'Opened Pull Requests',
#  'Releases',
#  'Repositories',
#  'Stars',
#  'Transactions']

# %%
daily_metrics = client.to_pandas("SELECT DISTINCT metric_name, display_name FROM metrics_v0 WHERE metric_name LIKE '%daily' ORDER BY 1")
daily_metrics.tail(5)
# Out:
#                          metric_name          display_name
# 288      ZORA_active_contracts_daily      Active Contracts
# 289  ZORA_contract_invocations_daily  Contract Invocations
# 290         ZORA_defillama_tvl_daily         Defillama TVL
# 291              ZORA_gas_fees_daily              Gas Fees
# 292          ZORA_transactions_daily          Transactions

# %%
df_metrics = client.to_pandas(f"""
  SELECT
    p.project_id,
    p.project_source,
    p.display_name,
    SUM(CASE WHEN m.display_name = 'Transactions' AND m.metric_name LIKE '%daily' THEN tm.amount ELSE 0 END) AS transactions,
    SUM(CASE WHEN m.display_name = 'Stars' AND m.metric_name LIKE '%all_time' THEN tm.amount ELSE 0 END) AS github_stars,
    MIN(CASE WHEN m.display_name = 'Commits' AND m.metric_name LIKE '%daily' THEN tm.sample_date ELSE null END) AS first_commit,
    MIN(CASE WHEN m.display_name = 'Transactions' AND m.metric_name LIKE '%daily' THEN tm.sample_date ELSE null END) AS first_transaction,
    MAX(CASE WHEN m.display_name = 'Active Developers' AND m.metric_name LIKE '%monthly' AND tm.sample_date = DATE '2025-02-01' THEN tm.amount ELSE 0 END) AS active_developers
  FROM timeseries_metrics_by_project_v0 AS tm
  JOIN metrics_v0 AS m ON m.metric_id = tm.metric_id
  JOIN projects_v1 AS p ON p.project_id = tm.project_id
  WHERE p.project_id IN ({stringify(PROJECT_IDS)})
  GROUP BY 1,2,3
  ORDER BY 4
""")
df_metrics.set_index(['project_id', 'project_source', 'display_name'], inplace=True)
df_metrics.tail()
# Out:
#                                                                                                          transactions  \
# project_id                                   project_source display_name
# MSfDkUunLKtfuMRdZuSxuemESQuIWKFCh1O6ySIEUs8= OP_ATLAS       Account Abstraction - ERC-4337                   41768895
# 1tglFLCPO1i0woe4TW7pBm1iMqrhlWJ1cv2L/5b0VUk= OSS_DIRECTORY  Infinitism (ERC-4337) - Account Abstraction      41768895
# Jr4krZ4lp1dMiTRDwmF2R9Hw4mF3rsukcBCM4pnF/fc= OP_ATLAS       Uniswap on Superchain (Oku)                      41898432
# o+HSkDisJ4Me0rmZT0iLKjKyUD8JxouPc31pw3ti4P8= OSS_DIRECTORY  LayerZero                                        45920450
# pWEQHj4IsxU8lx2EDLJpphYaGAvw/yRps3vgTbVCXjQ= OSS_DIRECTORY  Uniswap                                         146657957
#
#                                                                                                          github_stars  \
# project_id                                   project_source display_name
# MSfDkUunLKtfuMRdZuSxuemESQuIWKFCh1O6ySIEUs8= OP_ATLAS       Account Abstraction - ERC-4337                       1641
# 1tglFLCPO1i0woe4TW7pBm1iMqrhlWJ1cv2L/5b0VUk= OSS_DIRECTORY  Infinitism (ERC-4337) - Account Abstraction          1641
# Jr4krZ4lp1dMiTRDwmF2R9Hw4mF3rsukcBCM4pnF/fc= OP_ATLAS       Uniswap on Superchain (Oku)                             0
# o+HSkDisJ4Me0rmZT0iLKjKyUD8JxouPc31pw3ti4P8= OSS_DIRECTORY  LayerZero                                            3532
# pWEQHj4IsxU8lx2EDLJpphYaGAvw/yRps3vgTbVCXjQ= OSS_DIRECTORY  Uniswap                                             24053
#
#                                                                                                         first_commit  \
# project_id                                   project_source display_name
# MSfDkUunLKtfuMRdZuSxuemESQuIWKFCh1O6ySIEUs8= OP_ATLAS       Account Abstraction - ERC-4337                2021-09-29
# 1tglFLCPO1i0woe4TW7pBm1iMqrhlWJ1cv2L/5b0VUk= OSS_DIRECTORY  Infinitism (ERC-4337) - Account Abstraction   2021-09-29
# Jr4krZ4lp1dMiTRDwmF2R9Hw4mF3rsukcBCM4pnF/fc= OP_ATLAS       Uniswap on Superchain (Oku)                   2025-03-06
# o+HSkDisJ4Me0rmZT0iLKjKyUD8JxouPc31pw3ti4P8= OSS_DIRECTORY  LayerZero                                     2022-02-10
# pWEQHj4IsxU8lx2EDLJpphYaGAvw/yRps3vgTbVCXjQ= OSS_DIRECTORY  Uniswap                                       2018-10-13
#
#                                                                                                         first_transaction  \
# project_id                                   project_source display_name
# MSfDkUunLKtfuMRdZuSxuemESQuIWKFCh1O6ySIEUs8= OP_ATLAS       Account Abstraction - ERC-4337                     2023-04-22
# 1tglFLCPO1i0woe4TW7pBm1iMqrhlWJ1cv2L/5b0VUk= OSS_DIRECTORY  Infinitism (ERC-4337) - Account Abstraction        2023-04-22
# Jr4krZ4lp1dMiTRDwmF2R9Hw4mF3rsukcBCM4pnF/fc= OP_ATLAS       Uniswap on Superchain (Oku)                        2023-07-16
# o+HSkDisJ4Me0rmZT0iLKjKyUD8JxouPc31pw3ti4P8= OSS_DIRECTORY  LayerZero                                          2022-03-15
# pWEQHj4IsxU8lx2EDLJpphYaGAvw/yRps3vgTbVCXjQ= OSS_DIRECTORY  Uniswap                                            2021-11-15
#
#                                                                                                          active_developers
# project_id                                   project_source display_name
# MSfDkUunLKtfuMRdZuSxuemESQuIWKFCh1O6ySIEUs8= OP_ATLAS       Account Abstraction - ERC-4337                               3
# 1tglFLCPO1i0woe4TW7pBm1iMqrhlWJ1cv2L/5b0VUk= OSS_DIRECTORY  Infinitism (ERC-4337) - Account Abstraction                  3
# Jr4krZ4lp1dMiTRDwmF2R9Hw4mF3rsukcBCM4pnF/fc= OP_ATLAS       Uniswap on Superchain (Oku)                                  0
# o+HSkDisJ4Me0rmZT0iLKjKyUD8JxouPc31pw3ti4P8= OSS_DIRECTORY  LayerZero                                                   13
# pWEQHj4IsxU8lx2EDLJpphYaGAvw/yRps3vgTbVCXjQ= OSS_DIRECTORY  Uniswap                                                     19

# %%
txn_filter  = df_metrics['transactions'].between(df_metrics['transactions'].median(), df_metrics['transactions'].quantile(0.9))
star_filter = df_metrics['github_stars'].between(10, df_metrics['github_stars'].quantile(0.8))
dev_filter  = df_metrics['active_developers'].between(1, 20)

df_metrics_filtered = df_metrics[txn_filter & star_filter & dev_filter].dropna()
df_metrics_filtered
# Out:
#                                                                                 transactions  \
# project_id                                   project_source display_name
# umRqPpvKJk46Da+E4636QAR+Wzwo/0FLMGDKg53GyF0= OSS_DIRECTORY  Eco Association             1613
# I7MpjYBji+f8RTU2z82rl+dA9zAIY7EBL1dAYG9eDGs= OSS_DIRECTORY  Copin.io                    1897
# Icdd7UA5WRMMx/E2sEdPICMoNAWk6RX6GOHUhBkTndc= OSS_DIRECTORY  JEFE TOKEN                  2103
# pU+8a0LECe3IuQWgozjnrKWawkn70NE2gWtx16lge10= OSS_DIRECTORY  ZKP2P Fiat On Ramp          2228
# 7M4NI5CUzayK7YjK0VXLPGX0sxh3ashadfMP5586LII= OSS_DIRECTORY  Kiwi News                   3035
# ...                                                                                      ...
# dmXBoFu8JBive6XzLugqtI6hNxuT/oixb5nwteXZ5Y8= OSS_DIRECTORY  Agora                     814561
# 2l+DcexWOerkhRsKXiaWZam/soE6IQ5tVe7t4K202lo= OSS_DIRECTORY  Thales                    886440
# sZLQ7YXTrKyqwL630VpLPLJL8jAc0Pf2vv67yJ8qGlE= OSS_DIRECTORY  LogX                      902816
# vCa+wBp0799NJ8j9L6UgKxKmqiLT95Zk/aQX/hXty7c= OP_ATLAS       Mint Club                 942397
# OZc8hUTVvRXzEXAMJ6IqHeYqiGCecD6pH396GAijm/Y= OSS_DIRECTORY  Decent                    975993
#
#                                                                                 github_stars  \
# project_id                                   project_source display_name
# umRqPpvKJk46Da+E4636QAR+Wzwo/0FLMGDKg53GyF0= OSS_DIRECTORY  Eco Association               47
# I7MpjYBji+f8RTU2z82rl+dA9zAIY7EBL1dAYG9eDGs= OSS_DIRECTORY  Copin.io                      13
# Icdd7UA5WRMMx/E2sEdPICMoNAWk6RX6GOHUhBkTndc= OSS_DIRECTORY  JEFE TOKEN                    23
# pU+8a0LECe3IuQWgozjnrKWawkn70NE2gWtx16lge10= OSS_DIRECTORY  ZKP2P Fiat On Ramp            37
# 7M4NI5CUzayK7YjK0VXLPGX0sxh3ashadfMP5586LII= OSS_DIRECTORY  Kiwi News                     93
# ...                                                                                      ...
# dmXBoFu8JBive6XzLugqtI6hNxuT/oixb5nwteXZ5Y8= OSS_DIRECTORY  Agora                         91
# 2l+DcexWOerkhRsKXiaWZam/soE6IQ5tVe7t4K202lo= OSS_DIRECTORY  Thales                       117
# sZLQ7YXTrKyqwL630VpLPLJL8jAc0Pf2vv67yJ8qGlE= OSS_DIRECTORY  LogX                          15
# vCa+wBp0799NJ8j9L6UgKxKmqiLT95Zk/aQX/hXty7c= OP_ATLAS       Mint Club                     81
# OZc8hUTVvRXzEXAMJ6IqHeYqiGCecD6pH396GAijm/Y= OSS_DIRECTORY  Decent                        97
#
#                                                                                first_commit  \
# project_id                                   project_source display_name
# umRqPpvKJk46Da+E4636QAR+Wzwo/0FLMGDKg53GyF0= OSS_DIRECTORY  Eco Association      2019-09-30
# I7MpjYBji+f8RTU2z82rl+dA9zAIY7EBL1dAYG9eDGs= OSS_DIRECTORY  Copin.io             2023-10-02
# Icdd7UA5WRMMx/E2sEdPICMoNAWk6RX6GOHUhBkTndc= OSS_DIRECTORY  JEFE TOKEN           2021-12-07
# pU+8a0LECe3IuQWgozjnrKWawkn70NE2gWtx16lge10= OSS_DIRECTORY  ZKP2P Fiat On Ramp   2023-06-14
# 7M4NI5CUzayK7YjK0VXLPGX0sxh3ashadfMP5586LII= OSS_DIRECTORY  Kiwi News            2022-11-17
# ...                                                                                     ...
# dmXBoFu8JBive6XzLugqtI6hNxuT/oixb5nwteXZ5Y8= OSS_DIRECTORY  Agora                2023-03-13
# 2l+DcexWOerkhRsKXiaWZam/soE6IQ5tVe7t4K202lo= OSS_DIRECTORY  Thales               2021-05-31
# sZLQ7YXTrKyqwL630VpLPLJL8jAc0Pf2vv67yJ8qGlE= OSS_DIRECTORY  LogX                 2023-02-03
# vCa+wBp0799NJ8j9L6UgKxKmqiLT95Zk/aQX/hXty7c= OP_ATLAS       Mint Club            2023-11-15
# OZc8hUTVvRXzEXAMJ6IqHeYqiGCecD6pH396GAijm/Y= OSS_DIRECTORY  Decent               2022-02-02
#
#                                                                                first_transaction  \
# project_id                                   project_source display_name
# umRqPpvKJk46Da+E4636QAR+Wzwo/0FLMGDKg53GyF0= OSS_DIRECTORY  Eco Association           2023-06-12
# I7MpjYBji+f8RTU2z82rl+dA9zAIY7EBL1dAYG9eDGs= OSS_DIRECTORY  Copin.io                  2023-11-06
# Icdd7UA5WRMMx/E2sEdPICMoNAWk6RX6GOHUhBkTndc= OSS_DIRECTORY  JEFE TOKEN                2023-10-04
# pU+8a0LECe3IuQWgozjnrKWawkn70NE2gWtx16lge10= OSS_DIRECTORY  ZKP2P Fiat On Ramp        2023-09-22
# 7M4NI5CUzayK7YjK0VXLPGX0sxh3ashadfMP5586LII= OSS_DIRECTORY  Kiwi News                 2023-07-11
# ...                                                                                          ...
# dmXBoFu8JBive6XzLugqtI6hNxuT/oixb5nwteXZ5Y8= OSS_DIRECTORY  Agora                     2023-02-07
# 2l+DcexWOerkhRsKXiaWZam/soE6IQ5tVe7t4K202lo= OSS_DIRECTORY  Thales                    2021-11-30
# sZLQ7YXTrKyqwL630VpLPLJL8jAc0Pf2vv67yJ8qGlE= OSS_DIRECTORY  LogX                      2024-02-07
# vCa+wBp0799NJ8j9L6UgKxKmqiLT95Zk/aQX/hXty7c= OP_ATLAS       Mint Club                 2024-01-19
# OZc8hUTVvRXzEXAMJ6IqHeYqiGCecD6pH396GAijm/Y= OSS_DIRECTORY  Decent                    2022-10-06
#
#                                                                                 active_developers
# project_id                                   project_source display_name
# umRqPpvKJk46Da+E4636QAR+Wzwo/0FLMGDKg53GyF0= OSS_DIRECTORY  Eco Association                     5
# I7MpjYBji+f8RTU2z82rl+dA9zAIY7EBL1dAYG9eDGs= OSS_DIRECTORY  Copin.io                            2
# Icdd7UA5WRMMx/E2sEdPICMoNAWk6RX6GOHUhBkTndc= OSS_DIRECTORY  JEFE TOKEN                          1
# pU+8a0LECe3IuQWgozjnrKWawkn70NE2gWtx16lge10= OSS_DIRECTORY  ZKP2P Fiat On Ramp                  2
# 7M4NI5CUzayK7YjK0VXLPGX0sxh3ashadfMP5586LII= OSS_DIRECTORY  Kiwi News                           1
# ...                                                                                           ...
# dmXBoFu8JBive6XzLugqtI6hNxuT/oixb5nwteXZ5Y8= OSS_DIRECTORY  Agora                               9
# 2l+DcexWOerkhRsKXiaWZam/soE6IQ5tVe7t4K202lo= OSS_DIRECTORY  Thales                              6
# sZLQ7YXTrKyqwL630VpLPLJL8jAc0Pf2vv67yJ8qGlE= OSS_DIRECTORY  LogX                                1
# vCa+wBp0799NJ8j9L6UgKxKmqiLT95Zk/aQX/hXty7c= OP_ATLAS       Mint Club                           2
# OZc8hUTVvRXzEXAMJ6IqHeYqiGCecD6pH396GAijm/Y= OSS_DIRECTORY  Decent                              1
#
# [116 rows x 5 columns]

# %%
#df_metrics_filtered.to_csv("ProjectClassification.csv", index=False)
