# %%
# standard dependencies
import numpy as np
import os
import pandas as pd
import sys
import warnings
warnings.filterwarnings(action='ignore')

# %%
# local package dependencies
sys.path.append(os.path.abspath("../../scripts/"))
sys.path.append(os.path.abspath("../../visualizations/"))

# for making direct query requests to the data warehouse
from oso_db import execute_query

# %%
# create a mapping of projects to collections
result = execute_query("""
    SELECT p."slug", c."slug" 
    FROM project p 
    JOIN collection_projects_project cpp ON p."id" = cpp."projectId"
    JOIN collection c ON cpp."collectionId" = c."id"
    WHERE c."typeId" = 1
""", col_names=False)
projects_to_collections = {
    k: (
        sorted([
            v for v, key
            in result
            if key == k
        ]) 
    )
    for k in set(key for _, key in result)
}

# %%
# create a list of collections (ecosystems)
collection_slugs = list(projects_to_collections.keys())

# %%
# create a list of projects
project_slugs = set([
    p for c,ps 
    in projects_to_collections.items() 
    if c in collection_slugs 
    for p in ps
])
len(project_slugs)
# Out:
# 1214

# %%
# filter on the project slugs we're interested in
my_slugs = projects_to_collections['octant-02']

# %%
# create a string version of the projects list for use in querystrings
slugs_str = "','".join(my_slugs)
slugs_str
# Out:
# "brightid','clrfund','commonsbuild','dao-drops-dorgtech','drips-network','ethereum-cat-herders','ethstaker','gitcoin','givepraise','giveth','glo-foundation','hausdao','hypercerts','kernel-community','l2beat','metagame-metafam','onion-dao','opensource-observer','pairwise-general-magic','protocol-guild','revoke-cash','rotki','shutter-network','tor-project"

# %%
# get the names of those projects (up to 24 characters)
result = execute_query(f"""
    SELECT slug, name
    FROM project 
    WHERE slug IN ('{slugs_str}') 
""")
slugs_to_names = {x[0]: x[1][:25] for x in result}

# %%
# get data about active developers
query = execute_query(f"""
    SELECT
        p."slug",
        a."name" AS "repo",
        e."fromId",
        et."name",
        e."time",
        e."amount"
    FROM event e             
    JOIN project_artifacts_artifact paa ON e."toId" = paa."artifactId"            
    JOIN artifact a ON paa."artifactId" = a."id"
    JOIN project p ON paa."projectId" = p.id
    JOIN event_type et ON e."typeId" = et."id"
    WHERE
        e."typeId" IN (2,3,4,6,18,14,22)
        AND p.slug IN ('{slugs_str}')
""", col_names=True)

df = pd.DataFrame(query[1:], columns=query[0])
df.head()
# Out:
#           slug               repo    fromId         name  \
# 0  tor-project  torproject/webwml   33943.0  COMMIT_CODE
# 1  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 2  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 3  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 4  tor-project  torproject/webwml  150563.0  COMMIT_CODE
#
#                        time  amount
# 0 2007-12-31 20:38:23+00:00     1.0
# 1 2008-01-01 02:35:02+00:00     1.0
# 2 2008-01-01 03:09:22+00:00     1.0
# 3 2008-01-01 03:22:04+00:00     1.0
# 4 2008-01-01 04:17:09+00:00     1.0

# %%
df['month'] = df['time'].apply(lambda x: f"{x.year}-{str(x.month).zfill(2)}")
df['day'] = df['time'].apply(lambda x: f"{x.year}-{str(x.month).zfill(2)}-{str(x.day).zfill(2)}")
df['years_ago'] = (df['time'].max() - df['time']).apply(lambda x: x.days / 365.25)

# %%
date_thresh = '2023-07-01'

# %%
first_pr = (
    df.query("name == 'PULL_REQUEST_CREATED'")
    .groupby('slug')['years_ago']
    .max()
    .apply(lambda x: round(x,1))
    .rename('First PR Created - Years Ago')
)

# %%
active_repos = (
    df.query("name != 'FORK_AGGREGATE_STATS' and name != 'STAR_AGGREGATE_STATS'")
    .query("day >= @date_thresh")
    .groupby('slug')['repo']
    .nunique()
    .rename('Active Repos - Last 6 Months')
)

# %%
stars = (
    df.query("name == 'STAR_AGGREGATE_STATS'")
    .groupby('slug')['amount']
    .max()
    .rename('Max Stars - Any Repo')
    .astype(int)
)
forks = (
    df.query("name == 'FORK_AGGREGATE_STATS'")
    .groupby('slug')['amount']
    .max()
    .rename('Max Forks - Any Repo')
    .astype(int)
)

# %%
repo_activity = (
    df.query("name != 'FORK_AGGREGATE_STATS' and name != 'STAR_AGGREGATE_STATS'")
    .query("day >= @date_thresh")
    .groupby(['slug', 'name'])['amount']
    .sum()
    .sort_values()
    .reset_index()
    .pivot_table(index=['slug'], columns='name', values='amount', fill_value=0)
    .astype(int)
)
repo_activity.columns = [c.replace("_"," ").title() + " - All Repos, Last 6 Months" for c in repo_activity.columns]

# %%
contribs = (
    df.query("name == 'COMMIT_CODE' or name == 'PULL_REQUEST_CREATED'")
    .groupby(['slug', 'fromId'])
    .agg({'amount': 'sum', 'time': ['min', 'max']})
)
contribs.columns = ['amount', 'first', 'last']
new_contribs = (
    contribs[(contribs['amount'] > 1) & (contribs['first'] >= date_thresh)]
    .reset_index()
    .groupby('slug')['fromId']
    .nunique()
    .astype(int)
    .rename('New Contributors - Last 6 Months')
)
lifetime_contribs = (
    contribs[contribs['amount'] > 1]
    .reset_index()
    .groupby('slug')['fromId']
    .nunique()
    .astype(int)
    .rename('Total Contributors - All Time')
)

# %%
devs = (
    df.query("name == 'COMMIT_CODE' or name == 'PULL_REQUEST_CREATED'")
    .query("day >= @date_thresh")
    .groupby(['slug', 'fromId', 'month'])['day']
    .nunique()
    .rename('activeDays')
    .reset_index()
)
devs['devType'] = devs['activeDays'].apply(lambda x: "Full-time" if x >=10 else "Part-time")
dev_types = (
    (
        devs
        .groupby(['slug', 'devType'])['fromId']
        .count() / 6        
    )
    .reset_index()
    .pivot_table(
        index='slug', 
        columns='devType', 
        values='fromId', 
        fill_value=0
    )
    .rename(columns={
        'Full-time': 'Full-time Developers - Avg Last 6 Months',
        'Part-time': 'Part-time Developers - Avg Last 6 Months'
    })
    .join(
        (
            devs
            .groupby(['slug', 'month'])['fromId']
            .nunique()
        )
        .reset_index()
        .drop(columns='month')
        .groupby('slug')['fromId'].mean()
        .rename('Total Developers - Avg Last 6 Months')
    )
)

# %%
results = pd.concat([
    first_pr, 
    active_repos, 
    stars, forks, 
    repo_activity, 
    new_contribs, 
    lifetime_contribs, 
    dev_types
], axis=1).fillna(0).applymap(lambda x: round(x,1)).rename(index=slugs_to_names)
results.to_csv("octant-epoch-02-summary.csv")
results
# Out:
#                            First PR Created - Years Ago  \
# slug
# BrightID                                            5.7
# clr.fund                                            3.9
# Token Engineering Commons                           3.2
# DAO Drops                                           2.1
# Drips                                               2.5
# Ethereum Cat Herders                                8.2
# EthStaker                                           3.4
# Gitcoin                                             6.3
# Praise                                              2.1
# Giveth                                              7.3
# Glo Dollar                                          0.7
# Public HAUS                                         4.4
# Hypercerts                                          1.1
# Kernel                                              3.5
# L2BEAT                                              3.7
# MetaGame                                            4.0
# Onion DAO                                           1.8
# Open Source Observer                                0.5
# Pairwise                                            1.2
# Protocol Guild                                     10.1
# Revoke                                              3.9
# rotki                                               5.8
# Shutter Network                                     3.4
# The Tor Project                                    10.9
#
#                            Active Repos - Last 6 Months  Max Stars - Any Repo  \
# slug
# BrightID                                            6.0                 217.0
# clr.fund                                            2.0                 177.0
# Token Engineering Commons                           8.0                  10.0
# DAO Drops                                           0.0                  14.0
# Drips                                               8.0                  55.0
# Ethereum Cat Herders                                6.0               12264.0
# EthStaker                                           5.0                 382.0
# Gitcoin                                            43.0                1751.0
# Praise                                              6.0                  31.0
# Giveth                                             30.0                 652.0
# Glo Dollar                                          2.0                   3.0
# Public HAUS                                        18.0                 136.0
# Hypercerts                                          5.0                  70.0
# Kernel                                              3.0                  74.0
# L2BEAT                                              9.0                 417.0
# MetaGame                                            6.0                 124.0
# Onion DAO                                           1.0                   0.0
# Open Source Observer                                4.0                  25.0
# Pairwise                                            4.0                   6.0
# Protocol Guild                                    106.0               44606.0
# Revoke                                              5.0                 592.0
# rotki                                              16.0                2479.0
# Shutter Network                                    12.0                  51.0
# The Tor Project                                    15.0                4220.0
#
#                            Max Forks - Any Repo  \
# slug
# BrightID                                   63.0
# clr.fund                                   97.0
# Token Engineering Commons                  11.0
# DAO Drops                                   0.0
# Drips                                      15.0
# Ethereum Cat Herders                     5348.0
# EthStaker                                 160.0
# Gitcoin                                   881.0
# Praise                                     16.0
# Giveth                                    305.0
# Glo Dollar                                  1.0
# Public HAUS                                81.0
# Hypercerts                                 22.0
# Kernel                                     50.0
# L2BEAT                                    292.0
# MetaGame                                   79.0
# Onion DAO                                   2.0
# Open Source Observer                       14.0
# Pairwise                                    0.0
# Protocol Guild                          19781.0
# Revoke                                    213.0
# rotki                                     479.0
# Shutter Network                            14.0
# The Tor Project                           962.0
#
#                            Commit Code - All Repos, Last 6 Months  \
# slug
# BrightID                                                    193.0
# clr.fund                                                    148.0
# Token Engineering Commons                                    54.0
# DAO Drops                                                     0.0
# Drips                                                       688.0
# Ethereum Cat Herders                                        607.0
# EthStaker                                                   532.0
# Gitcoin                                                    2699.0
# Praise                                                      345.0
# Giveth                                                     3603.0
# Glo Dollar                                                  612.0
# Public HAUS                                                 902.0
# Hypercerts                                                  278.0
# Kernel                                                       75.0
# L2BEAT                                                     1274.0
# MetaGame                                                    606.0
# Onion DAO                                                     1.0
# Open Source Observer                                        605.0
# Pairwise                                                    708.0
# Protocol Guild                                            12495.0
# Revoke                                                      370.0
# rotki                                                      2161.0
# Shutter Network                                             393.0
# The Tor Project                                             520.0
#
#                            Issue Closed - All Repos, Last 6 Months  \
# slug
# BrightID                                                       5.0
# clr.fund                                                       1.0
# Token Engineering Commons                                      4.0
# DAO Drops                                                      0.0
# Drips                                                          1.0
# Ethereum Cat Herders                                         156.0
# EthStaker                                                     34.0
# Gitcoin                                                     1447.0
# Praise                                                        60.0
# Giveth                                                       841.0
# Glo Dollar                                                   121.0
# Public HAUS                                                   53.0
# Hypercerts                                                   173.0
# Kernel                                                         0.0
# L2BEAT                                                        40.0
# MetaGame                                                      87.0
# Onion DAO                                                      0.0
# Open Source Observer                                         309.0
# Pairwise                                                     115.0
# Protocol Guild                                              1752.0
# Revoke                                                        52.0
# rotki                                                        205.0
# Shutter Network                                                9.0
# The Tor Project                                               18.0
#
#                            Issue Created - All Repos, Last 6 Months  \
# slug
# BrightID                                                       13.0
# clr.fund                                                        1.0
# Token Engineering Commons                                      11.0
# DAO Drops                                                       0.0
# Drips                                                           0.0
# Ethereum Cat Herders                                          142.0
# EthStaker                                                      35.0
# Gitcoin                                                      1514.0
# Praise                                                         68.0
# Giveth                                                        801.0
# Glo Dollar                                                    101.0
# Public HAUS                                                    27.0
# Hypercerts                                                    207.0
# Kernel                                                          0.0
# L2BEAT                                                         51.0
# MetaGame                                                       48.0
# Onion DAO                                                       0.0
# Open Source Observer                                          427.0
# Pairwise                                                      169.0
# Protocol Guild                                               1783.0
# Revoke                                                        103.0
# rotki                                                         200.0
# Shutter Network                                                13.0
# The Tor Project                                                35.0
#
#                            Pull Request Created - All Repos, Last 6 Months  \
# slug
# BrightID                                                              23.0
# clr.fund                                                              29.0
# Token Engineering Commons                                              6.0
# DAO Drops                                                              0.0
# Drips                                                                  3.0
# Ethereum Cat Herders                                                 681.0
# EthStaker                                                            400.0
# Gitcoin                                                             1409.0
# Praise                                                                40.0
# Giveth                                                               632.0
# Glo Dollar                                                           135.0
# Public HAUS                                                          289.0
# Hypercerts                                                           158.0
# Kernel                                                                40.0
# L2BEAT                                                              1281.0
# MetaGame                                                              91.0
# Onion DAO                                                              0.0
# Open Source Observer                                                 437.0
# Pairwise                                                             130.0
# Protocol Guild                                                      5295.0
# Revoke                                                                21.0
# rotki                                                               1127.0
# Shutter Network                                                       67.0
# The Tor Project                                                       28.0
#
#                            Pull Request Merged - All Repos, Last 6 Months  \
# slug
# BrightID                                                             16.0
# clr.fund                                                             29.0
# Token Engineering Commons                                             6.0
# DAO Drops                                                             0.0
# Drips                                                                 3.0
# Ethereum Cat Herders                                                505.0
# EthStaker                                                           388.0
# Gitcoin                                                            1222.0
# Praise                                                               37.0
# Giveth                                                              578.0
# Glo Dollar                                                          129.0
# Public HAUS                                                         279.0
# Hypercerts                                                          150.0
# Kernel                                                               31.0
# L2BEAT                                                             1192.0
# MetaGame                                                             60.0
# Onion DAO                                                             0.0
# Open Source Observer                                                423.0
# Pairwise                                                            127.0
# Protocol Guild                                                     4132.0
# Revoke                                                               13.0
# rotki                                                              1088.0
# Shutter Network                                                      56.0
# The Tor Project                                                      10.0
#
#                            New Contributors - Last 6 Months  \
# slug
# BrightID                                                2.0
# clr.fund                                                0.0
# Token Engineering Commons                               3.0
# DAO Drops                                               0.0
# Drips                                                   2.0
# Ethereum Cat Herders                                   64.0
# EthStaker                                              15.0
# Gitcoin                                                27.0
# Praise                                                  2.0
# Giveth                                                  3.0
# Glo Dollar                                              0.0
# Public HAUS                                             3.0
# Hypercerts                                              2.0
# Kernel                                                  0.0
# L2BEAT                                                 46.0
# MetaGame                                                2.0
# Onion DAO                                               0.0
# Open Source Observer                                   14.0
# Pairwise                                                6.0
# Protocol Guild                                        321.0
# Revoke                                                  4.0
# rotki                                                  22.0
# Shutter Network                                         3.0
# The Tor Project                                        12.0
#
#                            Total Contributors - All Time  \
# slug
# BrightID                                              60
# clr.fund                                              31
# Token Engineering Commons                             53
# DAO Drops                                              3
# Drips                                                 22
# Ethereum Cat Herders                                 778
# EthStaker                                            115
# Gitcoin                                              555
# Praise                                                29
# Giveth                                               185
# Glo Dollar                                             8
# Public HAUS                                           69
# Hypercerts                                            10
# Kernel                                                98
# L2BEAT                                               129
# MetaGame                                             120
# Onion DAO                                              1
# Open Source Observer                                  14
# Pairwise                                               7
# Protocol Guild                                      4913
# Revoke                                                26
# rotki                                                137
# Shutter Network                                       17
# The Tor Project                                      485
#
#                            Full-time Developers - Avg Last 6 Months  \
# slug
# BrightID                                                        0.0
# clr.fund                                                        0.3
# Token Engineering Commons                                       0.2
# DAO Drops                                                       0.0
# Drips                                                           1.3
# Ethereum Cat Herders                                            0.0
# EthStaker                                                       1.2
# Gitcoin                                                        10.2
# Praise                                                          0.3
# Giveth                                                          5.0
# Glo Dollar                                                      1.0
# Public HAUS                                                     1.7
# Hypercerts                                                      0.7
# Kernel                                                          0.0
# L2BEAT                                                          7.8
# MetaGame                                                        0.7
# Onion DAO                                                       0.0
# Open Source Observer                                            1.8
# Pairwise                                                        1.2
# Protocol Guild                                                 21.7
# Revoke                                                          1.2
# rotki                                                           6.8
# Shutter Network                                                 0.5
# The Tor Project                                                 0.2
#
#                            Part-time Developers - Avg Last 6 Months  \
# slug
# BrightID                                                        3.8
# clr.fund                                                        1.7
# Token Engineering Commons                                       2.5
# DAO Drops                                                       0.0
# Drips                                                           5.7
# Ethereum Cat Herders                                           71.8
# EthStaker                                                      10.0
# Gitcoin                                                        26.7
# Praise                                                          2.5
# Giveth                                                         12.0
# Glo Dollar                                                      3.0
# Public HAUS                                                     7.2
# Hypercerts                                                      3.5
# Kernel                                                          3.3
# L2BEAT                                                         22.0
# MetaGame                                                        8.0
# Onion DAO                                                       0.2
# Open Source Observer                                            4.2
# Pairwise                                                        2.5
# Protocol Guild                                                334.0
# Revoke                                                          2.3
# rotki                                                          10.8
# Shutter Network                                                 6.3
# The Tor Project                                                20.3
#
#                            Total Developers - Avg Last 6 Months
# slug
# BrightID                                                    3.8
# clr.fund                                                    2.0
# Token Engineering Commons                                   2.3
# DAO Drops                                                   0.0
# Drips                                                       6.0
# Ethereum Cat Herders                                       61.6
# EthStaker                                                   9.6
# Gitcoin                                                    31.6
# Praise                                                      2.8
# Giveth                                                     14.6
# Glo Dollar                                                  3.4
# Public HAUS                                                 7.6
# Hypercerts                                                  3.6
# Kernel                                                      2.9
# L2BEAT                                                     25.6
# MetaGame                                                    7.4
# Onion DAO                                                   1.0
# Open Source Observer                                        5.1
# Pairwise                                                    3.1
# Protocol Guild                                            304.9
# Revoke                                                      3.0
# rotki                                                      15.1
# Shutter Network                                             5.9
# The Tor Project                                            17.6

# %%
results.to_csv("octant-epoch-02-summary.csv", sep="|")

# %%
(
    results[['First PR Created - Years Ago',
         'Total Contributors - All Time',
         'Max Forks - Any Repo',
         'Max Stars - Any Repo']]
    .sort_values(by='First PR Created - Years Ago', ascending=False)
)#.to_csv("octant-epoch-02-table1.csv", sep='|')

# %%
(
    results[[
        'New Contributors - Last 6 Months',
        'Full-time Developers - Avg Last 6 Months',
        'Part-time Developers - Avg Last 6 Months',
        'Total Developers - Avg Last 6 Months'
    ]]
    .sort_values(by='Total Developers - Avg Last 6 Months', ascending=False)
)#.to_csv("octant-epoch-02-table2.csv", sep='|')

# %%
(
    results[[
        'Issue Created - All Repos, Last 6 Months',
        'Issue Closed - All Repos, Last 6 Months',
        'Pull Request Created - All Repos, Last 6 Months',
        'Pull Request Merged - All Repos, Last 6 Months',
        'Commit Code - All Repos, Last 6 Months'        
    ]]
    .sort_values(by='Commit Code - All Repos, Last 6 Months', ascending=False)
    .applymap(int)
)#.to_csv("octant-epoch-02-table3.csv", sep='|')
