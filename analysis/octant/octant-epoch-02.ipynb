# %%
# standard dependencies
import numpy as np
import os
import pandas as pd
import sys
import warnings
warnings.filterwarnings(action='ignore')

# %%
# local package dependencies
sys.path.append(os.path.abspath("../../scripts/"))
sys.path.append(os.path.abspath("../../visualizations/"))

# for making direct query requests to the data warehouse
from oso_db import execute_query

# %%
# create a mapping of projects to collections
result = execute_query("""
    SELECT p."slug", c."slug" 
    FROM project p 
    JOIN collection_projects_project cpp ON p."id" = cpp."projectId"
    JOIN collection c ON cpp."collectionId" = c."id"
    WHERE c."typeId" = 1
""", col_names=False)
projects_to_collections = {
    k: (
        sorted([
            v for v, key
            in result
            if key == k
        ]) 
    )
    for k in set(key for _, key in result)
}

# %%
# create a list of collections (ecosystems)
collection_slugs = list(projects_to_collections.keys())

# %%
# create a list of projects
project_slugs = set([
    p for c,ps 
    in projects_to_collections.items() 
    if c in collection_slugs 
    for p in ps
])
len(project_slugs)
# Out:
# 1214

# %%
# filter on the project slugs we're interested in
my_slugs = projects_to_collections['octant-02']

# %%
# create a string version of the projects list for use in querystrings
slugs_str = "','".join(my_slugs).replace("'onion-dao',","")
slugs_str
# Out:
# "brightid','clrfund','commonsbuild','dao-drops-dorgtech','drips-network','ethereum-cat-herders','ethstaker','gitcoin','givepraise','giveth','glo-foundation','hausdao','hypercerts','kernel-community','l2beat','metagame-metafam','opensource-observer','pairwise-general-magic','protocol-guild','revoke-cash','rotki','shutter-network','tor-project"

# %%
# get the names of those projects (up to 24 characters)
result = execute_query(f"""
    SELECT slug, name
    FROM project 
    WHERE slug IN ('{slugs_str}') 
""")
slugs_to_names = {x[0]: x[1][:25] for x in result}

# %%
# get data about active developers
query = execute_query(f"""
    SELECT
        p."slug",
        a."name" AS "repo",
        e."fromId",
        et."name",
        e."time",
        e."amount"
    FROM event e             
    JOIN project_artifacts_artifact paa ON e."toId" = paa."artifactId"            
    JOIN artifact a ON paa."artifactId" = a."id"
    JOIN project p ON paa."projectId" = p.id
    JOIN event_type et ON e."typeId" = et."id"
    WHERE
        e."typeId" IN (2,3,4,6,18,14,22)
        AND p.slug IN ('{slugs_str}')
""", col_names=True)

df = pd.DataFrame(query[1:], columns=query[0])
df.head()
# Out:
#           slug               repo    fromId         name  \
# 0  tor-project  torproject/webwml   33943.0  COMMIT_CODE
# 1  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 2  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 3  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 4  tor-project  torproject/webwml  150563.0  COMMIT_CODE
#
#                        time  amount
# 0 2007-12-31 20:38:23+00:00     1.0
# 1 2008-01-01 02:35:02+00:00     1.0
# 2 2008-01-01 03:09:22+00:00     1.0
# 3 2008-01-01 03:22:04+00:00     1.0
# 4 2008-01-01 04:17:09+00:00     1.0

# %%
df['month'] = df['time'].apply(lambda x: f"{x.year}-{str(x.month).zfill(2)}")
df['day'] = df['time'].apply(lambda x: f"{x.year}-{str(x.month).zfill(2)}-{str(x.day).zfill(2)}")
df['years_ago'] = (df['time'].max() - df['time']).apply(lambda x: x.days / 365.25)

# %%
date_thresh = '2023-07-01'

# %%
first_pr = (
    df.query("name == 'PULL_REQUEST_CREATED'")
    .groupby('slug')['years_ago']
    .max()
    .apply(lambda x: round(x,1))
    .rename('First PR Created - Years Ago')
)

# %%
active_repos = (
    df.query("name != 'FORK_AGGREGATE_STATS' and name != 'STAR_AGGREGATE_STATS'")
    .query("day >= @date_thresh")
    .groupby('slug')['repo']
    .nunique()
    .rename('Active Repos - Last 6 Months')
)

# %%
stars = (
    df.query("name == 'STAR_AGGREGATE_STATS'")
    .groupby('slug')['amount']
    .max()
    .rename('Max Stars - Any Repo')
    .astype(int)
)
forks = (
    df.query("name == 'FORK_AGGREGATE_STATS'")
    .groupby('slug')['amount']
    .max()
    .rename('Max Forks - Any Repo')
    .astype(int)
)

# %%
repo_activity = (
    df.query("name != 'FORK_AGGREGATE_STATS' and name != 'STAR_AGGREGATE_STATS'")
    .query("day >= @date_thresh")
    .groupby(['slug', 'name'])['amount']
    .sum()
    .sort_values()
    .reset_index()
    .pivot_table(index=['slug'], columns='name', values='amount', fill_value=0)
    .astype(int)
)
repo_activity.columns = [c.replace("_"," ").title() + " - All Repos, Last 6 Months" for c in repo_activity.columns]

# %%
repo_activity
# Out:
#                         Commit Code - All Repos, Last 6 Months  \
# slug
# brightid                                                   193
# clrfund                                                    148
# commonsbuild                                                54
# drips-network                                              690
# ethereum-cat-herders                                       610
# ethstaker                                                  535
# gitcoin                                                   2715
# givepraise                                                 345
# giveth                                                    3611
# glo-foundation                                             612
# hausdao                                                    907
# hypercerts                                                 278
# kernel-community                                            82
# l2beat                                                    1285
# metagame-metafam                                           619
# opensource-observer                                        616
# pairwise-general-magic                                     708
# protocol-guild                                           12581
# revoke-cash                                                370
# rotki                                                     2182
# shutter-network                                            397
# tor-project                                                522
#
#                         Issue Closed - All Repos, Last 6 Months  \
# slug
# brightid                                                      5
# clrfund                                                       1
# commonsbuild                                                  4
# drips-network                                                26
# ethereum-cat-herders                                        156
# ethstaker                                                    34
# gitcoin                                                    1471
# givepraise                                                   60
# giveth                                                      848
# glo-foundation                                              121
# hausdao                                                      53
# hypercerts                                                  173
# kernel-community                                              0
# l2beat                                                       41
# metagame-metafam                                             87
# opensource-observer                                         312
# pairwise-general-magic                                      115
# protocol-guild                                             1759
# revoke-cash                                                  52
# rotki                                                       205
# shutter-network                                              10
# tor-project                                                  18
#
#                         Issue Created - All Repos, Last 6 Months  \
# slug
# brightid                                                      13
# clrfund                                                        1
# commonsbuild                                                  12
# drips-network                                                 23
# ethereum-cat-herders                                         142
# ethstaker                                                     35
# gitcoin                                                     1521
# givepraise                                                    68
# giveth                                                       807
# glo-foundation                                               101
# hausdao                                                       27
# hypercerts                                                   207
# kernel-community                                               0
# l2beat                                                        51
# metagame-metafam                                              48
# opensource-observer                                          435
# pairwise-general-magic                                       169
# protocol-guild                                              1804
# revoke-cash                                                  103
# rotki                                                        202
# shutter-network                                               14
# tor-project                                                   35
#
#                         Pull Request Created - All Repos, Last 6 Months  \
# slug
# brightid                                                             23
# clrfund                                                              29
# commonsbuild                                                          6
# drips-network                                                        40
# ethereum-cat-herders                                                684
# ethstaker                                                           401
# gitcoin                                                            1422
# givepraise                                                           40
# giveth                                                              635
# glo-foundation                                                      135
# hausdao                                                             290
# hypercerts                                                          158
# kernel-community                                                     42
# l2beat                                                             1290
# metagame-metafam                                                     92
# opensource-observer                                                 446
# pairwise-general-magic                                              130
# protocol-guild                                                     5325
# revoke-cash                                                          21
# rotki                                                              1135
# shutter-network                                                      71
# tor-project                                                          28
#
#                         Pull Request Merged - All Repos, Last 6 Months
# slug
# brightid                                                            16
# clrfund                                                             29
# commonsbuild                                                         6
# drips-network                                                       54
# ethereum-cat-herders                                               507
# ethstaker                                                          390
# gitcoin                                                           1234
# givepraise                                                          37
# giveth                                                             583
# glo-foundation                                                     129
# hausdao                                                            281
# hypercerts                                                         150
# kernel-community                                                    36
# l2beat                                                            1204
# metagame-metafam                                                    63
# opensource-observer                                                432
# pairwise-general-magic                                             127
# protocol-guild                                                    4183
# revoke-cash                                                         13
# rotki                                                             1097
# shutter-network                                                     63
# tor-project                                                         10

# %%
repo_activity.at['drips-network','Pull Request Created - All Repos, Last 6 Month'] = 262
repo_activity.at['drips-network','Pull Request Merged - All Repos, Last 6 Months'] = 227

repo_activity.at['drips-network','Issue Created - All Repos, Last 6 Months'] = 167
repo_activity.at['drips-network','Issue Closed - All Repos, Last 6 Months'] = 83

# %%
contribs = (
    df.query("name == 'COMMIT_CODE' or name == 'PULL_REQUEST_CREATED'")
    .groupby(['slug', 'fromId'])
    .agg({'amount': 'sum', 'time': ['min', 'max']})
)
contribs.columns = ['amount', 'first', 'last']
new_contribs = (
    contribs[(contribs['amount'] > 1) & (contribs['first'] >= date_thresh)]
    .reset_index()
    .groupby('slug')['fromId']
    .nunique()
    .astype(int)
    .rename('New Contributors - Last 6 Months')
)
lifetime_contribs = (
    contribs[contribs['amount'] > 1]
    .reset_index()
    .groupby('slug')['fromId']
    .nunique()
    .astype(int)
    .rename('Total Contributors - All Time')
)

# %%
devs = (
    df.query("name == 'COMMIT_CODE' or name == 'PULL_REQUEST_CREATED'")
    .query("day >= @date_thresh")
    .groupby(['slug', 'fromId', 'month'])['day']
    .nunique()
    .rename('activeDays')
    .reset_index()
)
devs['devType'] = devs['activeDays'].apply(lambda x: "Full-time" if x >=10 else "Part-time")
dev_types = (
    (
        devs
        .groupby(['slug', 'devType'])['fromId']
        .count() / 6        
    )
    .reset_index()
    .pivot_table(
        index='slug', 
        columns='devType', 
        values='fromId', 
        fill_value=0
    )
    .rename(columns={
        'Full-time': 'Full-time Developers - Avg Last 6 Months',
        'Part-time': 'Part-time Developers - Avg Last 6 Months'
    })
    .join(
        (
            devs
            .groupby(['slug', 'month'])['fromId']
            .nunique()
        )
        .reset_index()
        .drop(columns='month')
        .groupby('slug')['fromId'].mean()
        .rename('Total Developers - Avg Last 6 Months')
    )
)

# %%
results = pd.concat([
    first_pr, 
    active_repos, 
    stars, forks, 
    repo_activity, 
    new_contribs, 
    lifetime_contribs, 
    dev_types
], axis=1).fillna(0).applymap(lambda x: round(x,1)).rename(index=slugs_to_names)
results.to_csv("octant-epoch-02-summary.csv")
results
# Out:
#                            First PR Created - Years Ago  \
# slug
# BrightID                                            5.7
# clr.fund                                            3.9
# Token Engineering Commons                           3.2
# DAO Drops                                           2.2
# Drips                                               2.5
# Ethereum Cat Herders                                8.2
# EthStaker                                           3.4
# Gitcoin                                             6.3
# Praise                                              2.1
# Giveth                                              7.3
# Glo Dollar                                          0.7
# Public HAUS                                         4.4
# Hypercerts                                          1.1
# Kernel                                              3.5
# L2BEAT                                              3.7
# MetaGame                                            4.0
# Open Source Observer                                0.5
# Pairwise                                            1.2
# Protocol Guild                                     10.1
# Revoke                                              4.0
# rotki                                               5.9
# Shutter Network                                     3.4
# The Tor Project                                    10.9
#
#                            Active Repos - Last 6 Months  Max Stars - Any Repo  \
# slug
# BrightID                                            6.0                   217
# clr.fund                                            2.0                   177
# Token Engineering Commons                           8.0                    10
# DAO Drops                                           0.0                    14
# Drips                                               8.0                    55
# Ethereum Cat Herders                                6.0                 12268
# EthStaker                                           5.0                   384
# Gitcoin                                            44.0                  1751
# Praise                                              6.0                    31
# Giveth                                             30.0                   652
# Glo Dollar                                          2.0                     3
# Public HAUS                                        18.0                   136
# Hypercerts                                          5.0                    70
# Kernel                                              3.0                    74
# L2BEAT                                              9.0                   420
# MetaGame                                            6.0                   124
# Open Source Observer                                4.0                    25
# Pairwise                                            4.0                     6
# Protocol Guild                                    106.0                 44626
# Revoke                                              5.0                   593
# rotki                                              16.0                  2481
# Shutter Network                                    14.0                    51
# The Tor Project                                    15.0                  4224
#
#                            Max Forks - Any Repo  \
# slug
# BrightID                                   63.0
# clr.fund                                   99.0
# Token Engineering Commons                  11.0
# DAO Drops                                   0.0
# Drips                                      15.0
# Ethereum Cat Herders                     5354.0
# EthStaker                                 160.0
# Gitcoin                                   881.0
# Praise                                     17.0
# Giveth                                    305.0
# Glo Dollar                                  1.0
# Public HAUS                                81.0
# Hypercerts                                 23.0
# Kernel                                     51.0
# L2BEAT                                    295.0
# MetaGame                                   79.0
# Open Source Observer                       14.0
# Pairwise                                    0.0
# Protocol Guild                          19811.0
# Revoke                                    214.0
# rotki                                     479.0
# Shutter Network                            14.0
# The Tor Project                           962.0
#
#                            Commit Code - All Repos, Last 6 Months  \
# slug
# BrightID                                                    193.0
# clr.fund                                                    148.0
# Token Engineering Commons                                    54.0
# DAO Drops                                                     0.0
# Drips                                                       690.0
# Ethereum Cat Herders                                        610.0
# EthStaker                                                   535.0
# Gitcoin                                                    2715.0
# Praise                                                      345.0
# Giveth                                                     3611.0
# Glo Dollar                                                  612.0
# Public HAUS                                                 907.0
# Hypercerts                                                  278.0
# Kernel                                                       82.0
# L2BEAT                                                     1285.0
# MetaGame                                                    619.0
# Open Source Observer                                        616.0
# Pairwise                                                    708.0
# Protocol Guild                                            12581.0
# Revoke                                                      370.0
# rotki                                                      2182.0
# Shutter Network                                             397.0
# The Tor Project                                             522.0
#
#                            Issue Closed - All Repos, Last 6 Months  \
# slug
# BrightID                                                       5.0
# clr.fund                                                       1.0
# Token Engineering Commons                                      4.0
# DAO Drops                                                      0.0
# Drips                                                         83.0
# Ethereum Cat Herders                                         156.0
# EthStaker                                                     34.0
# Gitcoin                                                     1471.0
# Praise                                                        60.0
# Giveth                                                       848.0
# Glo Dollar                                                   121.0
# Public HAUS                                                   53.0
# Hypercerts                                                   173.0
# Kernel                                                         0.0
# L2BEAT                                                        41.0
# MetaGame                                                      87.0
# Open Source Observer                                         312.0
# Pairwise                                                     115.0
# Protocol Guild                                              1759.0
# Revoke                                                        52.0
# rotki                                                        205.0
# Shutter Network                                               10.0
# The Tor Project                                               18.0
#
#                            Issue Created - All Repos, Last 6 Months  \
# slug
# BrightID                                                       13.0
# clr.fund                                                        1.0
# Token Engineering Commons                                      12.0
# DAO Drops                                                       0.0
# Drips                                                         167.0
# Ethereum Cat Herders                                          142.0
# EthStaker                                                      35.0
# Gitcoin                                                      1521.0
# Praise                                                         68.0
# Giveth                                                        807.0
# Glo Dollar                                                    101.0
# Public HAUS                                                    27.0
# Hypercerts                                                    207.0
# Kernel                                                          0.0
# L2BEAT                                                         51.0
# MetaGame                                                       48.0
# Open Source Observer                                          435.0
# Pairwise                                                      169.0
# Protocol Guild                                               1804.0
# Revoke                                                        103.0
# rotki                                                         202.0
# Shutter Network                                                14.0
# The Tor Project                                                35.0
#
#                            Pull Request Created - All Repos, Last 6 Months  \
# slug
# BrightID                                                              23.0
# clr.fund                                                              29.0
# Token Engineering Commons                                              6.0
# DAO Drops                                                              0.0
# Drips                                                                 40.0
# Ethereum Cat Herders                                                 684.0
# EthStaker                                                            401.0
# Gitcoin                                                             1422.0
# Praise                                                                40.0
# Giveth                                                               635.0
# Glo Dollar                                                           135.0
# Public HAUS                                                          290.0
# Hypercerts                                                           158.0
# Kernel                                                                42.0
# L2BEAT                                                              1290.0
# MetaGame                                                              92.0
# Open Source Observer                                                 446.0
# Pairwise                                                             130.0
# Protocol Guild                                                      5325.0
# Revoke                                                                21.0
# rotki                                                               1135.0
# Shutter Network                                                       71.0
# The Tor Project                                                       28.0
#
#                            Pull Request Merged - All Repos, Last 6 Months  \
# slug
# BrightID                                                             16.0
# clr.fund                                                             29.0
# Token Engineering Commons                                             6.0
# DAO Drops                                                             0.0
# Drips                                                               227.0
# Ethereum Cat Herders                                                507.0
# EthStaker                                                           390.0
# Gitcoin                                                            1234.0
# Praise                                                               37.0
# Giveth                                                              583.0
# Glo Dollar                                                          129.0
# Public HAUS                                                         281.0
# Hypercerts                                                          150.0
# Kernel                                                               36.0
# L2BEAT                                                             1204.0
# MetaGame                                                             63.0
# Open Source Observer                                                432.0
# Pairwise                                                            127.0
# Protocol Guild                                                     4183.0
# Revoke                                                               13.0
# rotki                                                              1097.0
# Shutter Network                                                      63.0
# The Tor Project                                                      10.0
#
#                            Pull Request Created - All Repos, Last 6 Month  \
# slug
# BrightID                                                              0.0
# clr.fund                                                              0.0
# Token Engineering Commons                                             0.0
# DAO Drops                                                             0.0
# Drips                                                               262.0
# Ethereum Cat Herders                                                  0.0
# EthStaker                                                             0.0
# Gitcoin                                                               0.0
# Praise                                                                0.0
# Giveth                                                                0.0
# Glo Dollar                                                            0.0
# Public HAUS                                                           0.0
# Hypercerts                                                            0.0
# Kernel                                                                0.0
# L2BEAT                                                                0.0
# MetaGame                                                              0.0
# Open Source Observer                                                  0.0
# Pairwise                                                              0.0
# Protocol Guild                                                        0.0
# Revoke                                                                0.0
# rotki                                                                 0.0
# Shutter Network                                                       0.0
# The Tor Project                                                       0.0
#
#                            New Contributors - Last 6 Months  \
# slug
# BrightID                                                2.0
# clr.fund                                                0.0
# Token Engineering Commons                               3.0
# DAO Drops                                               0.0
# Drips                                                   4.0
# Ethereum Cat Herders                                   64.0
# EthStaker                                              15.0
# Gitcoin                                                27.0
# Praise                                                  2.0
# Giveth                                                  3.0
# Glo Dollar                                              0.0
# Public HAUS                                             3.0
# Hypercerts                                              2.0
# Kernel                                                  0.0
# L2BEAT                                                 47.0
# MetaGame                                                2.0
# Open Source Observer                                   14.0
# Pairwise                                                6.0
# Protocol Guild                                        321.0
# Revoke                                                  4.0
# rotki                                                  22.0
# Shutter Network                                         3.0
# The Tor Project                                        12.0
#
#                            Total Contributors - All Time  \
# slug
# BrightID                                              60
# clr.fund                                              31
# Token Engineering Commons                             53
# DAO Drops                                              3
# Drips                                                 24
# Ethereum Cat Herders                                 778
# EthStaker                                            115
# Gitcoin                                              556
# Praise                                                29
# Giveth                                               185
# Glo Dollar                                             8
# Public HAUS                                           69
# Hypercerts                                            10
# Kernel                                                98
# L2BEAT                                               130
# MetaGame                                             120
# Open Source Observer                                  14
# Pairwise                                               7
# Protocol Guild                                      4913
# Revoke                                                26
# rotki                                                137
# Shutter Network                                       17
# The Tor Project                                      485
#
#                            Full-time Developers - Avg Last 6 Months  \
# slug
# BrightID                                                        0.0
# clr.fund                                                        0.3
# Token Engineering Commons                                       0.2
# DAO Drops                                                       0.0
# Drips                                                           1.3
# Ethereum Cat Herders                                            0.0
# EthStaker                                                       1.3
# Gitcoin                                                        10.3
# Praise                                                          0.3
# Giveth                                                          5.2
# Glo Dollar                                                      1.0
# Public HAUS                                                     1.7
# Hypercerts                                                      0.7
# Kernel                                                          0.0
# L2BEAT                                                          8.0
# MetaGame                                                        0.7
# Open Source Observer                                            1.8
# Pairwise                                                        1.2
# Protocol Guild                                                 22.2
# Revoke                                                          1.2
# rotki                                                           7.0
# Shutter Network                                                 0.5
# The Tor Project                                                 0.2
#
#                            Part-time Developers - Avg Last 6 Months  \
# slug
# BrightID                                                        3.8
# clr.fund                                                        1.7
# Token Engineering Commons                                       2.5
# DAO Drops                                                       0.0
# Drips                                                           6.0
# Ethereum Cat Herders                                           72.2
# EthStaker                                                      10.0
# Gitcoin                                                        26.8
# Praise                                                          2.5
# Giveth                                                         11.8
# Glo Dollar                                                      3.0
# Public HAUS                                                     7.2
# Hypercerts                                                      3.5
# Kernel                                                          3.5
# L2BEAT                                                         22.0
# MetaGame                                                        8.0
# Open Source Observer                                            4.2
# Pairwise                                                        2.5
# Protocol Guild                                                334.7
# Revoke                                                          2.3
# rotki                                                          10.7
# Shutter Network                                                 6.5
# The Tor Project                                                20.3
#
#                            Total Developers - Avg Last 6 Months
# slug
# BrightID                                                    3.8
# clr.fund                                                    2.0
# Token Engineering Commons                                   2.3
# DAO Drops                                                   0.0
# Drips                                                       6.3
# Ethereum Cat Herders                                       61.9
# EthStaker                                                   9.7
# Gitcoin                                                    31.9
# Praise                                                      2.8
# Giveth                                                     14.6
# Glo Dollar                                                  3.4
# Public HAUS                                                 7.6
# Hypercerts                                                  3.6
# Kernel                                                      3.0
# L2BEAT                                                     25.7
# MetaGame                                                    7.4
# Open Source Observer                                        5.1
# Pairwise                                                    3.1
# Protocol Guild                                            305.9
# Revoke                                                      3.0
# rotki                                                      15.1
# Shutter Network                                             6.0
# The Tor Project                                            17.6

# %%
results.to_csv("octant-epoch-02-summary.csv", sep="|")

# %%
(
    results[['First PR Created - Years Ago',
         'Total Contributors - All Time',
         'Max Forks - Any Repo',
         'Max Stars - Any Repo']]
    .sort_values(by='First PR Created - Years Ago', ascending=False)
)#.to_csv("octant-epoch-02-table1.csv", sep='|')
# Out:
#                            First PR Created - Years Ago  \
# slug
# The Tor Project                                    10.9
# Protocol Guild                                     10.1
# Ethereum Cat Herders                                8.2
# Giveth                                              7.3
# Gitcoin                                             6.3
# rotki                                               5.9
# BrightID                                            5.7
# Public HAUS                                         4.4
# MetaGame                                            4.0
# Revoke                                              4.0
# clr.fund                                            3.9
# L2BEAT                                              3.7
# Kernel                                              3.5
# EthStaker                                           3.4
# Shutter Network                                     3.4
# Token Engineering Commons                           3.2
# Drips                                               2.5
# DAO Drops                                           2.2
# Praise                                              2.1
# Pairwise                                            1.2
# Hypercerts                                          1.1
# Glo Dollar                                          0.7
# Open Source Observer                                0.5
#
#                            Total Contributors - All Time  \
# slug
# The Tor Project                                      485
# Protocol Guild                                      4913
# Ethereum Cat Herders                                 778
# Giveth                                               185
# Gitcoin                                              556
# rotki                                                137
# BrightID                                              60
# Public HAUS                                           69
# MetaGame                                             120
# Revoke                                                26
# clr.fund                                              31
# L2BEAT                                               130
# Kernel                                                98
# EthStaker                                            115
# Shutter Network                                       17
# Token Engineering Commons                             53
# Drips                                                 24
# DAO Drops                                              3
# Praise                                                29
# Pairwise                                               7
# Hypercerts                                            10
# Glo Dollar                                             8
# Open Source Observer                                  14
#
#                            Max Forks - Any Repo  Max Stars - Any Repo
# slug
# The Tor Project                           962.0                  4224
# Protocol Guild                          19811.0                 44626
# Ethereum Cat Herders                     5354.0                 12268
# Giveth                                    305.0                   652
# Gitcoin                                   881.0                  1751
# rotki                                     479.0                  2481
# BrightID                                   63.0                   217
# Public HAUS                                81.0                   136
# MetaGame                                   79.0                   124
# Revoke                                    214.0                   593
# clr.fund                                   99.0                   177
# L2BEAT                                    295.0                   420
# Kernel                                     51.0                    74
# EthStaker                                 160.0                   384
# Shutter Network                            14.0                    51
# Token Engineering Commons                  11.0                    10
# Drips                                      15.0                    55
# DAO Drops                                   0.0                    14
# Praise                                     17.0                    31
# Pairwise                                    0.0                     6
# Hypercerts                                 23.0                    70
# Glo Dollar                                  1.0                     3
# Open Source Observer                       14.0                    25

# %%
(
    results[[
        'New Contributors - Last 6 Months',
        'Full-time Developers - Avg Last 6 Months',
        'Part-time Developers - Avg Last 6 Months',
        'Total Developers - Avg Last 6 Months'
    ]]
    .sort_values(by='Total Developers - Avg Last 6 Months', ascending=False)
)#.to_csv("octant-epoch-02-table2.csv", sep='|')

# %%
(
    results[[
        'Issue Created - All Repos, Last 6 Months',
        'Issue Closed - All Repos, Last 6 Months',
        'Pull Request Created - All Repos, Last 6 Months',
        'Pull Request Merged - All Repos, Last 6 Months',
        'Commit Code - All Repos, Last 6 Months'        
    ]]
    .sort_values(by='Commit Code - All Repos, Last 6 Months', ascending=False)
    .applymap(int)
)#.to_csv("octant-epoch-02-table3.csv", sep='|')

# %%
results.sum(axis=0)
# Out:
# First PR Created - Years Ago                          98.2
# Active Repos - Last 6 Months                         322.0
# Max Stars - Any Repo                               68392.0
# Max Forks - Any Repo                               28929.0
# Commit Code - All Repos, Last 6 Months             30060.0
# Issue Closed - All Repos, Last 6 Months             5608.0
# Issue Created - All Repos, Last 6 Months            5962.0
# Pull Request Created - All Repos, Last 6 Months    12443.0
# Pull Request Merged - All Repos, Last 6 Months     10817.0
# Pull Request Created - All Repos, Last 6 Month       262.0
# New Contributors - Last 6 Months                     556.0
# Total Contributors - All Time                       7868.0
# Full-time Developers - Avg Last 6 Months              65.1
# Part-time Developers - Avg Last 6 Months             565.7
# Total Developers - Avg Last 6 Months                 541.8
# dtype: float64
