# %%
# standard dependencies
import numpy as np
import os
import pandas as pd
import sys
import warnings
warnings.filterwarnings(action='ignore')

# %%
# local package dependencies
sys.path.append(os.path.abspath("../../scripts/"))
sys.path.append(os.path.abspath("../../visualizations/"))

# for making direct query requests to the data warehouse
from oso_db import execute_query

# %%
# create a mapping of projects to collections
result = execute_query("""
    SELECT p."slug", c."slug" 
    FROM project p 
    JOIN collection_projects_project cpp ON p."id" = cpp."projectId"
    JOIN collection c ON cpp."collectionId" = c."id"
    WHERE c."typeId" = 1
""", col_names=False)
projects_to_collections = {
    k: (
        sorted([
            v for v, key
            in result
            if key == k
        ]) 
    )
    for k in set(key for _, key in result)
}

# %%
# create a list of collections (ecosystems)
collection_slugs = list(projects_to_collections.keys())

# %%
# create a list of projects
project_slugs = set([
    p for c,ps 
    in projects_to_collections.items() 
    if c in collection_slugs 
    for p in ps
])
len(project_slugs)
# Out:
# 1215

# %%
# filter on the project slugs we're interested in
my_slugs = [
    p for p in
    projects_to_collections['octant-02']
    if p != 'protocol-guild'
]
len(my_slugs)
# Out:
# 23

# %%
# create a string version of the projects list for use in querystrings
slugs_str = "','".join(my_slugs)

# %%
# get the names of those projects (up to 24 characters)
result = execute_query(f"""
    SELECT slug, name
    FROM project 
    WHERE slug IN ('{slugs_str}') 
""")
slugs_to_names = {x[0]: x[1][:24] for x in result}

# %%
# get data about active developers
query = execute_query(f"""
    SELECT
        p."slug",
        a."name" AS "repo",
        e."fromId",
        et."name",
        e."time",
        e."amount"
    FROM event e             
    JOIN project_artifacts_artifact paa ON e."toId" = paa."artifactId"            
    JOIN artifact a ON paa."artifactId" = a."id"
    JOIN project p ON paa."projectId" = p.id
    JOIN event_type et ON e."typeId" = et."id"
    WHERE
        e."typeId" IN (2,3,4,6,18,14,22)
        AND p.slug IN ('{slugs_str}')
""", col_names=True)

df = pd.DataFrame(query[1:], columns=query[0])
df.to_csv("octant-epoch-02.csv")
df.head()
# Out:
#           slug               repo    fromId         name  \
# 0  tor-project  torproject/webwml   33943.0  COMMIT_CODE
# 1  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 2  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 3  tor-project  torproject/webwml  150563.0  COMMIT_CODE
# 4  tor-project  torproject/webwml  150563.0  COMMIT_CODE
#
#                        time  amount
# 0 2007-12-31 20:38:23+00:00     1.0
# 1 2008-01-01 02:35:02+00:00     1.0
# 2 2008-01-01 03:09:22+00:00     1.0
# 3 2008-01-01 03:22:04+00:00     1.0
# 4 2008-01-01 04:17:09+00:00     1.0

# %%
date_thresh = '2023-07-01'

# %%
df['month'] = df['time'].apply(lambda x: f"{x.year}-{str(x.month).zfill(2)}")
df['day'] = df['time'].apply(lambda x: f"{x.year}-{str(x.month).zfill(2)}-{str(x.day).zfill(2)}")
df['years_ago'] = (df['time'].max() - df['time']).apply(lambda x: x.days / 365.25)

# %%
first_pr = (
    df.query("name == 'PULL_REQUEST_CREATED'")
    .groupby('slug')['years_ago']
    .max()
    .rename('First PR Created - Years Ago')
)

# %%
active_repos = (
    df.query("name != 'FORK_AGGREGATE_STATS' and name != 'STAR_AGGREGATE_STATS'")
    .query("day >= @date_thresh")
    .groupby('slug')['repo']
    .nunique()
    .rename('Active Repos - Last 6 Months')
)

# %%
stars = (
    df.query("name == 'STAR_AGGREGATE_STATS'")
    .groupby('slug')['amount']
    .max()
    .rename('Max Stars - Any Repo')
)
forks = (
    df.query("name == 'FORK_AGGREGATE_STATS'")
    .groupby('slug')['amount']
    .max()
    .rename('Max Forks - Any Repo')
)

# %%
repo_activity = (
    df.query("name != 'FORK_AGGREGATE_STATS' and name != 'STAR_AGGREGATE_STATS'")
    .query("day >= @date_thresh")
    .groupby(['slug', 'name'])['amount']
    .sum()
    .sort_values()
    .reset_index()
    .pivot_table(index=['slug'], columns='name', values='amount', fill_value=0)
)
repo_activity.columns = [c.replace("_"," ").title() + " - All Repos, Last 6 Months" for c in repo_activity.columns]

# %%
contribs = (
    df.query("name == 'COMMIT_CODE' or name == 'PULL_REQUEST_CREATED'")
    .groupby(['slug', 'fromId'])
    .agg({'amount': 'sum', 'time': ['min', 'max']})
)
contribs.columns = ['amount', 'first', 'last']
new_contribs = (
    contribs[(contribs['amount'] > 1) & (contribs['first'] >= date_thresh)]
    .reset_index()
    .groupby('slug')['fromId']
    .nunique()
    .rename('New Contributors - Last 6 Months')
)
lifetime_contribs = (
    contribs[contribs['amount'] > 1]
    .reset_index()
    .groupby('slug')['fromId']
    .nunique()
    .rename('Total Contributors - All Time')
)

# %%
devs = (
    df.query("name == 'COMMIT_CODE' or name == 'PULL_REQUEST_CREATED'")
    .query("day >= @date_thresh")
    .groupby(['slug', 'fromId', 'month'])['day']
    .nunique()
    .rename('activeDays')
    .reset_index()
)
devs['devType'] = devs['activeDays'].apply(lambda x: "Full-time" if x >=10 else "Part-time")
dev_types = (
    (
        devs
        .groupby(['slug', 'devType'])['fromId']
        .count() / 6        
    )
    .reset_index()
    .pivot_table(
        index='slug', 
        columns='devType', 
        values='fromId', 
        fill_value=0
    )
    .rename(columns={
        'Full-time': 'Full-time Developers - Avg Last 6 Months',
        'Part-time': 'Part-time Developers - Avg Last 6 Months'
    })
    .join(
        (
            devs
            .groupby(['slug', 'month'])['fromId']
            .nunique()
        )
        .reset_index()
        .drop(columns='month')
        .groupby('slug')['fromId'].mean()
        .rename('Total Developers - Avg Last 6 Months')
    )
)

# %%
results = pd.concat([
    first_pr, 
    active_repos, 
    stars, forks, 
    repo_activity, 
    new_contribs, 
    lifetime_contribs, 
    dev_types
], axis=1).fillna(0)

# %%
results
# Out:
#                         First PR Created - Years Ago  \
# slug
# brightid                                    5.724846
# clrfund                                     3.937029
# commonsbuild                                3.189596
# dao-drops-dorgtech                          1.248460
# drips-network                               2.042437
# ethereum-cat-herders                        8.240931
# ethstaker                                   3.353867
# gitcoin                                     6.324435
# givepraise                                  2.088980
# giveth                                      7.252567
# glo-foundation                              0.720055
# hausdao                                     4.416153
# hypercerts                                  1.130732
# kernel-community                            3.523614
# l2beat                                      3.718001
# metagame-metafam                            3.958932
# onion-dao                                   1.804244
# opensource-observer                         0.490075
# pairwise-general-magic                      1.171800
# revoke-cash                                 3.942505
# rotki                                       5.842574
# shutter-network                             3.367556
# tor-project                                10.899384
#
#                         Active Repos - Last 6 Months  Max Stars - Any Repo  \
# slug
# brightid                                         6.0                 216.0
# clrfund                                          1.0                 177.0
# commonsbuild                                     7.0                  10.0
# dao-drops-dorgtech                               0.0                  14.0
# drips-network                                    4.0                  55.0
# ethereum-cat-herders                             6.0               12264.0
# ethstaker                                        5.0                 381.0
# gitcoin                                         43.0                1751.0
# givepraise                                       6.0                  30.0
# giveth                                          30.0                 652.0
# glo-foundation                                   2.0                   3.0
# hausdao                                         18.0                 136.0
# hypercerts                                       5.0                  69.0
# kernel-community                                 3.0                  74.0
# l2beat                                           8.0                 416.0
# metagame-metafam                                 6.0                 124.0
# onion-dao                                        0.0                   0.0
# opensource-observer                              4.0                  22.0
# pairwise-general-magic                           4.0                   6.0
# revoke-cash                                      5.0                 591.0
# rotki                                           16.0                2477.0
# shutter-network                                 12.0                  51.0
# tor-project                                     15.0                4220.0
#
#                         Max Forks - Any Repo  \
# slug
# brightid                                63.0
# clrfund                                 97.0
# commonsbuild                            11.0
# dao-drops-dorgtech                       0.0
# drips-network                           14.0
# ethereum-cat-herders                  5337.0
# ethstaker                              160.0
# gitcoin                                881.0
# givepraise                              16.0
# giveth                                 305.0
# glo-foundation                           1.0
# hausdao                                 81.0
# hypercerts                              22.0
# kernel-community                        50.0
# l2beat                                 290.0
# metagame-metafam                        79.0
# onion-dao                                2.0
# opensource-observer                     14.0
# pairwise-general-magic                   0.0
# revoke-cash                            211.0
# rotki                                  479.0
# shutter-network                         14.0
# tor-project                            962.0
#
#                         Commit Code - All Repos, Last 6 Months  \
# slug
# brightid                                                 193.0
# clrfund                                                  124.0
# commonsbuild                                              22.0
# dao-drops-dorgtech                                         0.0
# drips-network                                              3.0
# ethereum-cat-herders                                     607.0
# ethstaker                                                532.0
# gitcoin                                                 2601.0
# givepraise                                               345.0
# giveth                                                  3603.0
# glo-foundation                                           612.0
# hausdao                                                  902.0
# hypercerts                                               278.0
# kernel-community                                          75.0
# l2beat                                                  1270.0
# metagame-metafam                                         606.0
# onion-dao                                                  0.0
# opensource-observer                                      605.0
# pairwise-general-magic                                   708.0
# revoke-cash                                              370.0
# rotki                                                   2161.0
# shutter-network                                          303.0
# tor-project                                              520.0
#
#                         Issue Closed - All Repos, Last 6 Months  \
# slug
# brightid                                                    5.0
# clrfund                                                     1.0
# commonsbuild                                                4.0
# dao-drops-dorgtech                                          0.0
# drips-network                                               1.0
# ethereum-cat-herders                                      156.0
# ethstaker                                                  34.0
# gitcoin                                                  1447.0
# givepraise                                                 60.0
# giveth                                                    841.0
# glo-foundation                                            121.0
# hausdao                                                    53.0
# hypercerts                                                173.0
# kernel-community                                            0.0
# l2beat                                                     40.0
# metagame-metafam                                           87.0
# onion-dao                                                   0.0
# opensource-observer                                       309.0
# pairwise-general-magic                                    115.0
# revoke-cash                                                52.0
# rotki                                                     205.0
# shutter-network                                             9.0
# tor-project                                                16.0
#
#                         Issue Created - All Repos, Last 6 Months  \
# slug
# brightid                                                    13.0
# clrfund                                                      1.0
# commonsbuild                                                11.0
# dao-drops-dorgtech                                           0.0
# drips-network                                                0.0
# ethereum-cat-herders                                       142.0
# ethstaker                                                   35.0
# gitcoin                                                   1514.0
# givepraise                                                  68.0
# giveth                                                     801.0
# glo-foundation                                             101.0
# hausdao                                                     27.0
# hypercerts                                                 207.0
# kernel-community                                             0.0
# l2beat                                                      51.0
# metagame-metafam                                            48.0
# onion-dao                                                    0.0
# opensource-observer                                        427.0
# pairwise-general-magic                                     169.0
# revoke-cash                                                103.0
# rotki                                                      200.0
# shutter-network                                             13.0
# tor-project                                                 35.0
#
#                         Pull Request Created - All Repos, Last 6 Months  \
# slug
# brightid                                                           23.0
# clrfund                                                            29.0
# commonsbuild                                                        6.0
# dao-drops-dorgtech                                                  0.0
# drips-network                                                       3.0
# ethereum-cat-herders                                              681.0
# ethstaker                                                         400.0
# gitcoin                                                          1409.0
# givepraise                                                         40.0
# giveth                                                            632.0
# glo-foundation                                                    135.0
# hausdao                                                           289.0
# hypercerts                                                        158.0
# kernel-community                                                   40.0
# l2beat                                                           1281.0
# metagame-metafam                                                   91.0
# onion-dao                                                           0.0
# opensource-observer                                               437.0
# pairwise-general-magic                                            130.0
# revoke-cash                                                        21.0
# rotki                                                            1127.0
# shutter-network                                                    67.0
# tor-project                                                        28.0
#
#                         Pull Request Merged - All Repos, Last 6 Months  \
# slug
# brightid                                                          16.0
# clrfund                                                           29.0
# commonsbuild                                                       6.0
# dao-drops-dorgtech                                                 0.0
# drips-network                                                      3.0
# ethereum-cat-herders                                             505.0
# ethstaker                                                        388.0
# gitcoin                                                         1222.0
# givepraise                                                        37.0
# giveth                                                           578.0
# glo-foundation                                                   129.0
# hausdao                                                          279.0
# hypercerts                                                       150.0
# kernel-community                                                  31.0
# l2beat                                                          1192.0
# metagame-metafam                                                  60.0
# onion-dao                                                          0.0
# opensource-observer                                              423.0
# pairwise-general-magic                                           127.0
# revoke-cash                                                       13.0
# rotki                                                           1088.0
# shutter-network                                                   55.0
# tor-project                                                       10.0
#
#                         New Contributors - Last 6 Months  \
# slug
# brightid                                             2.0
# clrfund                                              0.0
# commonsbuild                                         2.0
# dao-drops-dorgtech                                   0.0
# drips-network                                        0.0
# ethereum-cat-herders                                64.0
# ethstaker                                           15.0
# gitcoin                                             27.0
# givepraise                                           2.0
# giveth                                               3.0
# glo-foundation                                       0.0
# hausdao                                              3.0
# hypercerts                                           2.0
# kernel-community                                     0.0
# l2beat                                              46.0
# metagame-metafam                                     2.0
# onion-dao                                            0.0
# opensource-observer                                 14.0
# pairwise-general-magic                               6.0
# revoke-cash                                          4.0
# rotki                                               22.0
# shutter-network                                      2.0
# tor-project                                         12.0
#
#                         Total Contributors - All Time  \
# slug
# brightid                                           60
# clrfund                                            31
# commonsbuild                                       52
# dao-drops-dorgtech                                  1
# drips-network                                       9
# ethereum-cat-herders                              778
# ethstaker                                         115
# gitcoin                                           508
# givepraise                                         29
# giveth                                            185
# glo-foundation                                      8
# hausdao                                            69
# hypercerts                                         10
# kernel-community                                   98
# l2beat                                            129
# metagame-metafam                                  120
# onion-dao                                           1
# opensource-observer                                14
# pairwise-general-magic                              7
# revoke-cash                                        26
# rotki                                             137
# shutter-network                                    16
# tor-project                                       485
#
#                         Full-time Developers - Avg Last 6 Months  \
# slug
# brightid                                                0.000000
# clrfund                                                 0.333333
# commonsbuild                                            0.000000
# dao-drops-dorgtech                                      0.000000
# drips-network                                           0.000000
# ethereum-cat-herders                                    0.000000
# ethstaker                                               1.166667
# gitcoin                                                10.000000
# givepraise                                              0.333333
# giveth                                                  5.000000
# glo-foundation                                          1.000000
# hausdao                                                 1.666667
# hypercerts                                              0.666667
# kernel-community                                        0.000000
# l2beat                                                  7.833333
# metagame-metafam                                        0.666667
# onion-dao                                               0.000000
# opensource-observer                                     1.833333
# pairwise-general-magic                                  1.166667
# revoke-cash                                             1.166667
# rotki                                                   6.833333
# shutter-network                                         0.333333
# tor-project                                             0.166667
#
#                         Part-time Developers - Avg Last 6 Months  \
# slug
# brightid                                                3.833333
# clrfund                                                 1.666667
# commonsbuild                                            2.166667
# dao-drops-dorgtech                                      0.000000
# drips-network                                           0.833333
# ethereum-cat-herders                                   71.833333
# ethstaker                                              10.000000
# gitcoin                                                26.666667
# givepraise                                              2.500000
# giveth                                                 12.000000
# glo-foundation                                          3.000000
# hausdao                                                 7.166667
# hypercerts                                              3.500000
# kernel-community                                        3.333333
# l2beat                                                 22.000000
# metagame-metafam                                        8.000000
# onion-dao                                               0.000000
# opensource-observer                                     4.166667
# pairwise-general-magic                                  2.500000
# revoke-cash                                             2.333333
# rotki                                                  10.833333
# shutter-network                                         5.666667
# tor-project                                            20.333333
#
#                         Total Developers - Avg Last 6 Months
# slug
# brightid                                            3.833333
# clrfund                                             2.000000
# commonsbuild                                        1.857143
# dao-drops-dorgtech                                  0.000000
# drips-network                                       2.500000
# ethereum-cat-herders                               61.571429
# ethstaker                                           9.571429
# gitcoin                                            31.428571
# givepraise                                          2.833333
# giveth                                             14.571429
# glo-foundation                                      3.428571
# hausdao                                             7.571429
# hypercerts                                          3.571429
# kernel-community                                    2.857143
# l2beat                                             25.571429
# metagame-metafam                                    7.428571
# onion-dao                                           0.000000
# opensource-observer                                 5.142857
# pairwise-general-magic                              3.142857
# revoke-cash                                         3.000000
# rotki                                              15.142857
# shutter-network                                     5.142857
# tor-project                                        17.571429

# %%
results.sum(axis=0)
# Out:
# First PR Created - Years Ago                          88.388775
# Active Repos - Last 6 Months                         206.000000
# Max Stars - Any Repo                               23739.000000
# Max Forks - Any Repo                                9089.000000
# Commit Code - All Repos, Last 6 Months             16440.000000
# Issue Closed - All Repos, Last 6 Months             3729.000000
# Issue Created - All Repos, Last 6 Months            3966.000000
# Pull Request Created - All Repos, Last 6 Months     7027.000000
# Pull Request Merged - All Repos, Last 6 Months      6341.000000
# New Contributors - Last 6 Months                     228.000000
# Total Contributors - All Time                       2888.000000
# Full-time Developers - Avg Last 6 Months              40.166667
# Part-time Developers - Avg Last 6 Months             224.333333
# Total Developers - Avg Last 6 Months                 229.738095
# dtype: float64
