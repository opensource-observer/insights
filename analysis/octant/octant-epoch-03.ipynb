# %%
from datetime import datetime, timedelta
from google.cloud import bigquery
import os
import pandas as pd

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../gcp_credentials.json'
client = bigquery.Client()

# %% [markdown]
# # Get active projects / repos

# %%
query = """
SELECT
    r.*
FROM `opensource-observer.oso.repos_by_project` r
JOIN `opensource-observer.oso.projects_by_collection` pc 
    ON r.project_id = pc.project_id
WHERE
    collection_slug = 'octant-03'
    AND last_commit_date >= '2023-10-01'
"""
result = client.query(query)
repos = result.to_dataframe()
repos.tail(3)
# Out:
#                                        project_id         project_slug  \
# 367  iilyWmaoJCXv0vPfyPQnIGYXoWyTZDlP0oQLMNIVj54=     metagame-metafam
# 368  iilyWmaoJCXv0vPfyPQnIGYXoWyTZDlP0oQLMNIVj54=     metagame-metafam
# 369  Erx9J64anc8oSeN-wDKm0sojJf8ONrFVYbQ7GFnqSyc=  opensource-observer
#
#              project_name repository_source  \
# 367              MetaGame            GITHUB
# 368              MetaGame            GITHUB
# 369  Open Source Observer            GITHUB
#
#                                       artifact_id  repo_is_fork  \
# 367  dMDefE9C6JLEDLpTwA9Ppsf8cvgYXvLRHqWCloKEC-U=          True
# 368  8YzrsNvfD4s9NpSgEMYr64deqY9n6jREE5_SJ3Mos1U=          True
# 369  tPgwwzg8t0YIYr5h3bv2TV5WKNVnKvBw19F-qEkxz-4=          True
#
#      repo_fork_count  repo_star_count         first_commit_date  \
# 367                1                0 2024-03-28 00:00:00+00:00
# 368                0                0 2024-01-23 00:00:00+00:00
# 369                0                0 2024-04-17 00:00:00+00:00
#
#              last_commit_date                     repo_name_with_owner
# 367 2024-03-28 00:00:00+00:00                    metafam/profile-frame
# 368 2024-01-23 00:00:00+00:00                   metafam/op-chievemints
# 369 2024-04-19 00:00:00+00:00  opensource-observer/tap-airbyte-wrapper

# %%
repos['repo_name_with_owner'].nunique()
# Out:
# 343

# %%
dups = repos.groupby('repo_name_with_owner')['project_slug'].nunique()
dups[dups>1]
# Out:
# repo_name_with_owner
# ethereum/eips       2
# ethereum/web3.py    2
# Name: project_slug, dtype: int64

# %%
project_ids = list(repos['project_id'].unique())
len(project_ids)
# Out:
# 26

# %%
# no activity: 0x-boring-security and dao-drops-dorgtech
# not oss: ethdaily, refidao
sorted(list(repos['project_slug'].unique()))
# Out:
# ['1hive',
#  'drips-network',
#  'etheralpha',
#  'ethereum-attestation-service',
#  'ethereum-cat-herders',
#  'ethstaker',
#  'fundingthecommons',
#  'gitcoin',
#  'givepraise',
#  'giveth',
#  'glo-foundation',
#  'growthepie',
#  'hypercerts',
#  'l2beat',
#  'metagame-metafam',
#  'metagov',
#  'nicenode',
#  'opensource-observer',
#  'pairwise-general-magic',
#  'protocol-guild',
#  'revoke-cash',
#  'rotki',
#  'shutter-network',
#  'tor-project',
#  'web3',
#  'web3py-ethereum']

# %% [markdown]
# # Overall developer / contributor metrics

# %%
query = """
SELECT
    d.*
FROM `opensource-observer.oso.int_devs` d
JOIN `opensource-observer.oso.projects_by_collection` pc 
    ON d.project_id = pc.project_id
WHERE
    collection_slug = 'octant-03'
    AND date_last_contribution >= '2023-10-01'
    AND count_events > 1
"""
result = client.query(query)
devs = result.to_dataframe()
devs.tail(3)
# Out:
#                                            from_id repository_source  \
# 2124  eeKlGvhYoE3HepHrWb3u2ncUqnRfvx7JAF1h0oQJIH4=            GITHUB
# 2125  0RdvBAabiLVkYv822oxvZ1AmoXu_SEfFbYt61i67Gtc=            GITHUB
# 2126  g-d8ktMh7fjuFiHiJxb-b8WrfVovswGIuL77e-Mqtks=            GITHUB
#
#                                         project_id   date_first_contribution  \
# 2124  _rSUGbgCLjCC0SxFrS6u6299eSa8Vde7C1ftbaFzBuo= 2022-06-13 00:00:00+00:00
# 2125  _rSUGbgCLjCC0SxFrS6u6299eSa8Vde7C1ftbaFzBuo= 2023-12-13 00:00:00+00:00
# 2126  -lP_Uvqt9rP8pWZQDW4VejaqpQDfLuc7mG5D59wRfbs= 2023-05-15 00:00:00+00:00
#
#         date_last_contribution  count_events
# 2124 2023-10-26 00:00:00+00:00           5.0
# 2125 2023-12-14 00:00:00+00:00           7.0
# 2126 2024-04-09 00:00:00+00:00         708.0

# %%
regular_devs = devs[devs['count_events'] >= 10]
print(regular_devs['from_id'].nunique())

new_devs = devs[devs['date_first_contribution'] >= '2023-10-01']
print(new_devs['from_id'].nunique())
# Out:
# 651
# 881

# %% [markdown]
# # Fetch code metrics by project and create a master dataframe

# %%
query = """

SELECT
    c.project_name,

    c.commits_6_months,
    c.issues_closed_6_months,
    c.issues_opened_6_months,
    c.pull_requests_opened_6_months,
    c.pull_requests_merged_6_months,
    
    c.contributors,
    c.new_contributors_6_months,
    c.avg_fulltime_devs_6_months,
    c.avg_active_devs_6_months
    
FROM `opensource-observer.oso.code_metrics_by_project` c
JOIN `opensource-observer.oso.projects_by_collection` pc 
    ON c.project_id = pc.project_id
WHERE collection_slug = 'octant-03'

"""
result = client.query(query)
metrics = result.to_dataframe()
metrics.tail(3)
# Out:
#    project_name  commits_6_months  issues_closed_6_months  \
# 26   Hypercerts             362.0                   197.0
# 27     NiceNode             255.0                    18.0
# 28        Drips             382.0                   137.0
#
#     issues_opened_6_months  pull_requests_opened_6_months  \
# 26                   132.0                          192.0
# 27                    35.0                          161.0
# 28                   148.0                          173.0
#
#     pull_requests_merged_6_months  contributors  new_contributors_6_months  \
# 26                          175.0            25                          9
# 27                          121.0            23                         11
# 28                          160.0            38                         13
#
#     avg_fulltime_devs_6_months  avg_active_devs_6_months
# 26                    0.333333                  2.666667
# 27                    0.833333                  1.333333
# 28                    1.000000                  3.833333

# %%
df = metrics.drop_duplicates().set_index('project_name')  

col_names = [
    'Commit Code - All Repos, Last 6 Months',
    'Issue Closed - All Repos, Last 6 Months',
    'Issue Created - All Repos, Last 6 Months',
    'Pull Request Created - All Repos, Last 6 Months',
    'Pull Request Merged - All Repos, Last 6 Months',
    
    'Total Contributors - All Time',
    'New Contributors - Last 6 Months', 
    'Full-time Developers - Avg Last 6 Months',
    'Total Developers - Avg Last 6 Months'
]
df.columns = col_names
df.loc['Protocol Guild'] = df.loc['Protocol Guild'] - df.loc['Ethereum Cat Herders'] - df.loc['web3.py']
df = df[df['Commit Code - All Repos, Last 6 Months'].isna() == False]

df = (
    repos
    .groupby('project_name')
    .agg({
        'repo_name_with_owner': 'nunique',
        'repo_fork_count': 'max',
        'repo_star_count': 'max'
    })
    .rename(
        columns={
            'repo_name_with_owner': 'Active Repos - Last 6 Months',
            'repo_fork_count': 'Fork Count - Max of Active Repos',
            'repo_star_count': 'Star Count - Max of Active Repos'
        }
    ).
    join(df)
)

df.index.name = 'Project'
df.rename(index={
    'The Metagovernance Project': 'MetaGov',
    'Ether Alpha': 'StateOfEth (by Ether Alpha)',
    'Shutter Network': 'Shielded Voting (by Shutter Network)'
}, inplace=True)

df['name'] = df.index.str.lower()
df.sort_values(by='name', inplace=True)
df.drop(columns='name', inplace=True)

df.fillna(0, inplace=True)

for col in col_names:
    if col in ['Full-time Developers - Avg Last 6 Months', 'Total Developers - Avg Last 6 Months']:
        df[col] = df[col].apply(lambda x: round(x,1))
    else:
        df[col] = df[col].astype(int)

df
# Out:
#                                       Active Repos - Last 6 Months  \
# Project
# 1Hive Gardens                                                    9
# Drips                                                            9
# Ethereum Attestation Service                                     8
# Ethereum Cat Herders                                             1
# EthStaker                                                        6
# fundingthecommons                                                2
# Gitcoin                                                         47
# Giveth                                                          22
# Glo Dollar                                                       2
# growthepie                                                       4
# Hypercerts                                                      10
# L2BEAT                                                           8
# MetaGame                                                         8
# MetaGov                                                         21
# NiceNode                                                        11
# Open Source Observer                                             5
# Pairwise                                                         5
# Praise                                                           5
# Protocol Guild                                                  92
# Revoke                                                           6
# rotki                                                           17
# Shielded Voting (by Shutter Network)                            15
# StateOfEth (by Ether Alpha)                                     13
# The Tor Project                                                 13
# web3.js                                                          5
# web3.py                                                          1
#
#                                       Fork Count - Max of Active Repos  \
# Project
# 1Hive Gardens                                                       37
# Drips                                                               17
# Ethereum Attestation Service                                        55
# Ethereum Cat Herders                                              5040
# EthStaker                                                          187
# fundingthecommons                                                    0
# Gitcoin                                                            422
# Giveth                                                              31
# Glo Dollar                                                           1
# growthepie                                                           5
# Hypercerts                                                          24
# L2BEAT                                                             329
# MetaGame                                                            76
# MetaGov                                                             20
# NiceNode                                                            26
# Open Source Observer                                                22
# Pairwise                                                             0
# Praise                                                              19
# Protocol Guild                                                   19417
# Revoke                                                             208
# rotki                                                              475
# Shielded Voting (by Shutter Network)                                14
# StateOfEth (by Ether Alpha)                                         21
# The Tor Project                                                    926
# web3.js                                                           4831
# web3.py                                                           1620
#
#                                       Star Count - Max of Active Repos  \
# Project
# 1Hive Gardens                                                       28
# Drips                                                               58
# Ethereum Attestation Service                                       213
# Ethereum Cat Herders                                             12523
# EthStaker                                                          426
# fundingthecommons                                                    0
# Gitcoin                                                            886
# Giveth                                                              30
# Glo Dollar                                                           3
# growthepie                                                          13
# Hypercerts                                                          81
# L2BEAT                                                             457
# MetaGame                                                           127
# MetaGov                                                             72
# NiceNode                                                           168
# Open Source Observer                                                37
# Pairwise                                                             7
# Praise                                                              32
# Protocol Guild                                                   46063
# Revoke                                                             620
# rotki                                                             2609
# Shielded Voting (by Shutter Network)                                57
# StateOfEth (by Ether Alpha)                                         22
# The Tor Project                                                   4304
# web3.js                                                          18764
# web3.py                                                           4790
#
#                                       Commit Code - All Repos, Last 6 Months  \
# Project
# 1Hive Gardens                                                            139
# Drips                                                                    382
# Ethereum Attestation Service                                             275
# Ethereum Cat Herders                                                     270
# EthStaker                                                                430
# fundingthecommons                                                          3
# Gitcoin                                                                 2877
# Giveth                                                                  2708
# Glo Dollar                                                                62
# growthepie                                                              1025
# Hypercerts                                                               362
# L2BEAT                                                                   754
# MetaGame                                                                 255
# MetaGov                                                                  417
# NiceNode                                                                 255
# Open Source Observer                                                     678
# Pairwise                                                                 330
# Praise                                                                    24
# Protocol Guild                                                         11167
# Revoke                                                                   312
# rotki                                                                   1937
# Shielded Voting (by Shutter Network)                                     251
# StateOfEth (by Ether Alpha)                                            16217
# The Tor Project                                                          428
# web3.js                                                                  184
# web3.py                                                                  243
#
#                                       Issue Closed - All Repos, Last 6 Months  \
# Project
# 1Hive Gardens                                                              42
# Drips                                                                     137
# Ethereum Attestation Service                                               20
# Ethereum Cat Herders                                                       31
# EthStaker                                                                  46
# fundingthecommons                                                           0
# Gitcoin                                                                   925
# Giveth                                                                    710
# Glo Dollar                                                                  0
# growthepie                                                                  1
# Hypercerts                                                                197
# L2BEAT                                                                     39
# MetaGame                                                                   58
# MetaGov                                                                    20
# NiceNode                                                                   18
# Open Source Observer                                                      332
# Pairwise                                                                   89
# Praise                                                                      0
# Protocol Guild                                                           1390
# Revoke                                                                     69
# rotki                                                                     168
# Shielded Voting (by Shutter Network)                                        6
# StateOfEth (by Ether Alpha)                                                 1
# The Tor Project                                                             7
# web3.js                                                                   203
# web3.py                                                                   137
#
#                                       Issue Created - All Repos, Last 6 Months  \
# Project
# 1Hive Gardens                                                               65
# Drips                                                                      148
# Ethereum Attestation Service                                                24
# Ethereum Cat Herders                                                        59
# EthStaker                                                                   54
# fundingthecommons                                                            0
# Gitcoin                                                                   1007
# Giveth                                                                     563
# Glo Dollar                                                                   2
# growthepie                                                                   0
# Hypercerts                                                                 132
# L2BEAT                                                                      34
# MetaGame                                                                    35
# MetaGov                                                                     31
# NiceNode                                                                    35
# Open Source Observer                                                       437
# Pairwise                                                                   128
# Praise                                                                       0
# Protocol Guild                                                            1528
# Revoke                                                                      67
# rotki                                                                      188
# Shielded Voting (by Shutter Network)                                        16
# StateOfEth (by Ether Alpha)                                                  1
# The Tor Project                                                             15
# web3.js                                                                    222
# web3.py                                                                     65
#
#                                       Pull Request Created - All Repos, Last 6 Months  \
# Project
# 1Hive Gardens                                                                      88
# Drips                                                                             173
# Ethereum Attestation Service                                                       75
# Ethereum Cat Herders                                                              393
# EthStaker                                                                         277
# fundingthecommons                                                                  21
# Gitcoin                                                                          1102
# Giveth                                                                            612
# Glo Dollar                                                                          6
# growthepie                                                                         56
# Hypercerts                                                                        192
# L2BEAT                                                                           1390
# MetaGame                                                                           80
# MetaGov                                                                            45
# NiceNode                                                                          161
# Open Source Observer                                                              505
# Pairwise                                                                           76
# Praise                                                                              3
# Protocol Guild                                                                   4684
# Revoke                                                                             44
# rotki                                                                            1111
# Shielded Voting (by Shutter Network)                                               52
# StateOfEth (by Ether Alpha)                                                        12
# The Tor Project                                                                    11
# web3.js                                                                           217
# web3.py                                                                           148
#
#                                       Pull Request Merged - All Repos, Last 6 Months  \
# Project
# 1Hive Gardens                                                                     67
# Drips                                                                            160
# Ethereum Attestation Service                                                      42
# Ethereum Cat Herders                                                             252
# EthStaker                                                                        276
# fundingthecommons                                                                  0
# Gitcoin                                                                          977
# Giveth                                                                           566
# Glo Dollar                                                                         4
# growthepie                                                                        54
# Hypercerts                                                                       175
# L2BEAT                                                                          1255
# MetaGame                                                                          61
# MetaGov                                                                           43
# NiceNode                                                                         121
# Open Source Observer                                                             482
# Pairwise                                                                          73
# Praise                                                                             4
# Protocol Guild                                                                  3688
# Revoke                                                                            43
# rotki                                                                           1073
# Shielded Voting (by Shutter Network)                                              42
# StateOfEth (by Ether Alpha)                                                        8
# The Tor Project                                                                    2
# web3.js                                                                          156
# web3.py                                                                          121
#
#                                       Total Contributors - All Time  \
# Project
# 1Hive Gardens                                                   326
# Drips                                                            38
# Ethereum Attestation Service                                     82
# Ethereum Cat Herders                                           1515
# EthStaker                                                       228
# fundingthecommons                                                 9
# Gitcoin                                                        1807
# Giveth                                                          314
# Glo Dollar                                                        8
# growthepie                                                        8
# Hypercerts                                                       25
# L2BEAT                                                          276
# MetaGame                                                        145
# MetaGov                                                          65
# NiceNode                                                         23
# Open Source Observer                                             30
# Pairwise                                                         15
# Praise                                                           29
# Protocol Guild                                                14721
# Revoke                                                          162
# rotki                                                           493
# Shielded Voting (by Shutter Network)                             22
# StateOfEth (by Ether Alpha)                                      35
# The Tor Project                                                 741
# web3.js                                                        2308
# web3.py                                                         949
#
#                                       New Contributors - Last 6 Months  \
# Project
# 1Hive Gardens                                                        2
# Drips                                                               13
# Ethereum Attestation Service                                        43
# Ethereum Cat Herders                                               129
# EthStaker                                                           40
# fundingthecommons                                                    3
# Gitcoin                                                             67
# Giveth                                                               9
# Glo Dollar                                                           0
# growthepie                                                           2
# Hypercerts                                                           9
# L2BEAT                                                              95
# MetaGame                                                             2
# MetaGov                                                              3
# NiceNode                                                            11
# Open Source Observer                                                25
# Pairwise                                                             6
# Praise                                                               0
# Protocol Guild                                                     890
# Revoke                                                              66
# rotki                                                               62
# Shielded Voting (by Shutter Network)                                 6
# StateOfEth (by Ether Alpha)                                          3
# The Tor Project                                                     26
# web3.js                                                            112
# web3.py                                                             56
#
#                                       Full-time Developers - Avg Last 6 Months  \
# Project
# 1Hive Gardens                                                              0.0
# Drips                                                                      1.0
# Ethereum Attestation Service                                               0.0
# Ethereum Cat Herders                                                       1.0
# EthStaker                                                                  1.0
# fundingthecommons                                                          0.0
# Gitcoin                                                                    5.0
# Giveth                                                                     1.7
# Glo Dollar                                                                 0.0
# growthepie                                                                 1.2
# Hypercerts                                                                 0.3
# L2BEAT                                                                     1.5
# MetaGame                                                                   0.3
# MetaGov                                                                    0.0
# NiceNode                                                                   0.8
# Open Source Observer                                                       1.8
# Pairwise                                                                   0.2
# Praise                                                                     0.0
# Protocol Guild                                                            11.3
# Revoke                                                                     0.8
# rotki                                                                      3.3
# Shielded Voting (by Shutter Network)                                       0.0
# StateOfEth (by Ether Alpha)                                                1.3
# The Tor Project                                                            0.8
# web3.js                                                                    0.2
# web3.py                                                                    0.0
#
#                                       Total Developers - Avg Last 6 Months
# Project
# 1Hive Gardens                                                          2.2
# Drips                                                                  3.8
# Ethereum Attestation Service                                           2.0
# Ethereum Cat Herders                                                   2.8
# EthStaker                                                              4.7
# fundingthecommons                                                      0.2
# Gitcoin                                                               17.0
# Giveth                                                                 9.7
# Glo Dollar                                                             1.0
# growthepie                                                             4.0
# Hypercerts                                                             2.7
# L2BEAT                                                                12.5
# MetaGame                                                               3.2
# MetaGov                                                                5.2
# NiceNode                                                               1.3
# Open Source Observer                                                   4.3
# Pairwise                                                               2.2
# Praise                                                                 0.3
# Protocol Guild                                                        60.7
# Revoke                                                                 1.0
# rotki                                                                  5.3
# Shielded Voting (by Shutter Network)                                   3.5
# StateOfEth (by Ether Alpha)                                            2.2
# The Tor Project                                                        1.8
# web3.js                                                                5.2
# web3.py                                                                4.2

# %%
df.sum()
# Out:
# Active Repos - Last 6 Months                         345.0
# Fork Count - Max of Active Repos                   33823.0
# Star Count - Max of Active Repos                   92390.0
# Commit Code - All Repos, Last 6 Months             41985.0
# Issue Closed - All Repos, Last 6 Months             4646.0
# Issue Created - All Repos, Last 6 Months            4856.0
# Pull Request Created - All Repos, Last 6 Months    11534.0
# Pull Request Merged - All Repos, Last 6 Months      9745.0
# Total Contributors - All Time                      24374.0
# New Contributors - Last 6 Months                    1680.0
# Full-time Developers - Avg Last 6 Months              33.5
# Total Developers - Avg Last 6 Months                 163.0
# dtype: float64

# %% [markdown]
# # Export markdown tables

# %%
tabs = {
    'summary': [0,1,2],
    'activity': [3,4,5,6,7],
    'contribs': [8,9,10,11]
}
new_projects = [
    '1Hive Gardens', 'StateOfEth (by Ether Alpha)', 'Ethereum Attestation Service',
    'growthepie', 'MetaGov', 'web3.js', 'web3.py'
]
returning_projects = [
    p for p in df.index
    if p not in new_projects and p != 'fundingthecommons'
]
groups = {'new': new_projects, 'returning': returning_projects}

# %%
for group_name, list_of_projects in groups.items():
    for tab_name, list_of_colnums in tabs.items():
        dff = df.loc[list_of_projects].iloc[:,list_of_colnums]
        dff.to_markdown(f'data/octant-03-{group_name}-{tab_name}.md')
