# %%
from google.cloud import bigquery
import os
import pandas as pd

# %%
GCP_PROJECT = 'opensource-observer'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../../oso_gcp_credentials.json'
client = bigquery.Client(GCP_PROJECT)

# %%
query = """
    select
        p.project_name,
        m.*
    from `oso.int_repo_metrics_by_project` as m
    join `oso.projects_v1` as p
        on m.project_id = p.project_id
"""

# result = client.query(query)
# df_repos = result.to_dataframe()
# df_repos.to_parquet('data/repo_metrics.parquet')

df_repos = pd.read_parquet('data/repo_metrics.parquet')
df_repos['artifact_name_owner'] = df_repos.apply(lambda x: "/".join([x['artifact_namespace'], x['artifact_name']]), axis=1)
df_repos.tail(1)
# Out:
#                        project_name  \
# 53390  privacy-scaling-explorations
#
#                                          project_id  \
# 53390  die2X_l4rJ6uZTU4L-inhU4RJ1P8vs0bTvw85Bzal_8=
#
#                                         artifact_id  \
# 53390  TNCOf8mKsvIlJApGxNaLN1MTFi8871edWlhWp-IRurk=
#
#                  artifact_namespace artifact_name artifact_source  is_fork  \
# 53390  privacy-scaling-explorations         halo2          GITHUB     True
#
#        fork_count  star_count  watcher_count language license_spdx_id  \
# 53390         129         206            206     Rust     NOASSERTION
#
#               first_commit_time          last_commit_time  \
# 53390 2021-11-29 09:31:38+00:00 2024-10-24 06:32:33+00:00
#
#        days_with_commits_count  contributors_to_repo_count  commit_count  \
# 53390                       89                           9         312.0
#
#                       artifact_name_owner
# 53390  privacy-scaling-explorations/halo2

# %%
df_projects = pd.read_csv('data/projects_oso_with_git.csv')
df_projects['githubProjectLink'] = df_projects['githubProjectLink'].str.lower()

df_projects['artifact_name_owner'] = df_projects['githubProjectLink'].apply(
    lambda x: x.replace('https://github.com/','').strip('/')
)
df_projects['artifact_namespace'] = df_projects['artifact_name_owner'].apply(
    lambda x: x.split('/')[0] if '/' in x else x
)
df_projects['artifact_name'] = df_projects['artifact_name_owner'].apply(
    lambda x: x.split('/')[1] if '/' in x else None
)
df_projects.head()
# Out:
#                                    name  \
# 0                        Filecoin Spark
# 1  The CalibrationNet Stability Project
# 2                           Rust-Libp2p
# 3                  Open Source Observer
# 4                       DeFinomics Labs
#
#                             githubProjectLink OSOName  categoryHasOsoName  \
# 0   https://github.com/filecoin-station/spark     NaN               False
# 1   https://github.com/filecoin-project/curio     NaN                True
# 2       https://github.com/libp2p/rust-libp2p  libp2p                True
# 3  https://github.com/opensource-observer/oso     NaN               False
# 4          https://github.com/definomics-labs     NaN               False
#
#        artifact_name_owner   artifact_namespace artifact_name
# 0   filecoin-station/spark     filecoin-station         spark
# 1   filecoin-project/curio     filecoin-project         curio
# 2       libp2p/rust-libp2p               libp2p   rust-libp2p
# 3  opensource-observer/oso  opensource-observer           oso
# 4          definomics-labs      definomics-labs          None

# %%
df_projects_repos = (
    df_projects[df_projects['artifact_name'].isna()==False]
    .set_index('artifact_name_owner').join(
        df_repos.groupby('artifact_name_owner')[['fork_count', 'star_count', 'commit_count']].sum()
    ).join(
        df_repos.groupby('artifact_name_owner')['project_name'].agg(set)
    )
)
df_projects_repos.to_csv('data/oso_repos.csv')
df_projects_repos.head()
# Out:
#                                                                                    name  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...             Network Health Dashboard
# ancients-research/retropgf                                            Ancients Research
# aschmahmann/filexp                                                               filexp
# asia-spwg/retropgf                                  Asia Storage Provider Working Group
# auralgenius/agcore                                                          AuralGenius
#
#                                                                                     githubProjectLink  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...    https://github.com/starboard-ventures/fileco...
# ancients-research/retropgf                              https://github.com/ancients-research/retropgf
# aschmahmann/filexp                                              https://github.com/aschmahmann/filexp
# asia-spwg/retropgf                                              https://github.com/asia-spwg/retropgf
# auralgenius/agcore                                              https://github.com/auralgenius/agcore
#
#                                                    OSOName  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...     NaN
# ancients-research/retropgf                             NaN
# aschmahmann/filexp                                     NaN
# asia-spwg/retropgf                                     NaN
# auralgenius/agcore                                     NaN
#
#                                                     categoryHasOsoName  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...               False
# ancients-research/retropgf                                       False
# aschmahmann/filexp                                                True
# asia-spwg/retropgf                                               False
# auralgenius/agcore                                               False
#
#                                                       artifact_namespace  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...    starboard-ventures
# ancients-research/retropgf                             ancients-research
# aschmahmann/filexp                                           aschmahmann
# asia-spwg/retropgf                                             asia-spwg
# auralgenius/agcore                                           auralgenius
#
#                                                                         artifact_name  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...  filecoin-network-health-dashboard
# ancients-research/retropgf                                                   retropgf
# aschmahmann/filexp                                                             filexp
# asia-spwg/retropgf                                                           retropgf
# auralgenius/agcore                                                             agcore
#
#                                                     fork_count  star_count  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...        <NA>        <NA>
# ancients-research/retropgf                                <NA>        <NA>
# aschmahmann/filexp                                           1          11
# asia-spwg/retropgf                                        <NA>        <NA>
# auralgenius/agcore                                        <NA>        <NA>
#
#                                                     commit_count  \
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...           NaN
# ancients-research/retropgf                                   NaN
# aschmahmann/filexp                                          33.0
# asia-spwg/retropgf                                           NaN
# auralgenius/agcore                                           NaN
#
#                                                             project_name
# artifact_name_owner
#   starboard-ventures/filecoin-network-health-da...                   NaN
# ancients-research/retropgf                                           NaN
# aschmahmann/filexp                                  {filexp-aschmahmann}
# asia-spwg/retropgf                                                   NaN
# auralgenius/agcore                                                   NaN

# %%
df_projects_orgs = (
    df_projects[df_projects['artifact_name'].isna()==True]
    .set_index('artifact_namespace').join(
        df_repos.groupby('artifact_namespace')[['fork_count', 'star_count', 'commit_count']].sum()
    ).join(
        df_repos.groupby('artifact_namespace')['project_name'].agg(set)
    )
)

df_projects_orgs.to_csv('data/oso_orgs.csv')
df_projects_orgs.head()
# Out:
#                                                                  name  \
# artifact_namespace
# definomics-labs                                       DeFinomics Labs
# chainupcloud        Chainup Cloud (Filecoin Public RPC) - Updated ...
# filecoin-station                                     Filecoin Station
# fill-lab                                                    FILLiquid
# storswiftlabs            Data123 (Full Archival History Node Service)
#
#                                       githubProjectLink       OSOName  \
# artifact_namespace
# definomics-labs      https://github.com/definomics-labs           NaN
# chainupcloud            https://github.com/chainupcloud  chainupcloud
# filecoin-station    https://github.com/filecoin-station           NaN
# fill-lab                    https://github.com/fill-lab      FILL-Lab
# storswiftlabs          https://github.com/storswiftlabs           NaN
#
#                     categoryHasOsoName artifact_name_owner artifact_name  \
# artifact_namespace
# definomics-labs                  False     definomics-labs          None
# chainupcloud                      True        chainupcloud          None
# filecoin-station                 False    filecoin-station          None
# fill-lab                          True            fill-lab          None
# storswiftlabs                     True       storswiftlabs          None
#
#                     fork_count  star_count  commit_count        project_name
# artifact_namespace
# definomics-labs              0           0          25.0   {definomics-labs}
# chainupcloud              <NA>        <NA>           NaN                 NaN
# filecoin-station            32         146        4628.0  {filecoin-station}
# fill-lab                     3           9         124.0          {fill-lab}
# storswiftlabs               15          37         559.0     {storswiftlabs}

# %%
df = pd.concat([df_projects_orgs.reset_index(), df_projects_repos.reset_index()], axis=0)
df['project_name'] = df['project_name'].apply(lambda x: list(x)[0] if isinstance(x, set) and len(x) == 1 else x)
df
# Out:
#     artifact_namespace                                               name  \
# 0      definomics-labs                                    DeFinomics Labs
# 1         chainupcloud  Chainup Cloud (Filecoin Public RPC) - Updated ...
# 2     filecoin-station                                   Filecoin Station
# 3             fill-lab                                          FILLiquid
# 4        storswiftlabs       Data123 (Full Archival History Node Service)
# ..                 ...                                                ...
# 126               yhio                                               Rbot
# 127         zenground0                             Cross Chain Onramp POC
# 128             zondax                                 Beryx Filecoin API
# 129             zondax                                     Beryx Explorer
# 130             zondax             Filecoin Ledger App & Installation Hub
#
#                                   githubProjectLink       OSOName  \
# 0                https://github.com/definomics-labs           NaN
# 1                   https://github.com/chainupcloud  chainupcloud
# 2               https://github.com/filecoin-station           NaN
# 3                       https://github.com/fill-lab      FILL-Lab
# 4                  https://github.com/storswiftlabs           NaN
# ..                                              ...           ...
# 126                    https://github.com/yhio/rbot           NaN
# 127  https://github.com/zenground0/onramp-contracts           NaN
# 128        https://github.com/zondax/rfpg-beryx-api           NaN
# 129    https://github.com/zondax/web-beryx-explorer           NaN
# 130               https://github.com/zondax/web-hub           NaN
#
#      categoryHasOsoName          artifact_name_owner       artifact_name  \
# 0                 False              definomics-labs                None
# 1                  True                 chainupcloud                None
# 2                 False             filecoin-station                None
# 3                  True                     fill-lab                None
# 4                  True                storswiftlabs                None
# ..                  ...                          ...                 ...
# 126                True                    yhio/rbot                rbot
# 127               False  zenground0/onramp-contracts    onramp-contracts
# 128                True        zondax/rfpg-beryx-api      rfpg-beryx-api
# 129                True    zondax/web-beryx-explorer  web-beryx-explorer
# 130                True               zondax/web-hub             web-hub
#
#      fork_count  star_count  commit_count      project_name
# 0             0           0          25.0   definomics-labs
# 1          <NA>        <NA>           NaN               NaN
# 2            32         146        4628.0  filecoin-station
# 3             3           9         124.0          fill-lab
# 4            15          37         559.0     storswiftlabs
# ..          ...         ...           ...               ...
# 126        <NA>        <NA>           NaN               NaN
# 127        <NA>        <NA>           NaN               NaN
# 128        <NA>        <NA>           NaN               NaN
# 129           1           4           5.0            zondax
# 130        <NA>        <NA>           NaN               NaN
#
# [152 rows x 11 columns]

# %%
def match_repo(a):
    if '/' in a:
        owner = a.split('/')[0]
        repo = a.split('/')[1]
    else:
        owner = a
        repo = None
        
    dff = df_repos[df_repos['artifact_namespace'] == owner]
    if dff.empty:
        return None
    
    projects = dff['project_name'].unique()

    if len(projects) == 1:
        return projects[0]
    elif len(projects) > 1:
        if not repo:
            return "multiple"
        else:
            dff = dff[dff['artifact_name'] == repo]
            if len(dff):
                projects = dff['project_name'].unique()
                return projects[0]

df_projects['oso_name'] = df_projects['artifact_name_owner'].apply(match_repo)
