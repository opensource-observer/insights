# %%
import json
import networkx as nx
import os
import pandas as pd

# %% [markdown]
# # Settings

# %%
REFRESH_DATA = True
LOCAL_CSV_PATH = 'graphs/filecoin_unweighted_graph.csv'
LOCAL_JSON_PATH = 'graphs/filecoin_unweighted_graph.json'

# %%
SEED_REPOS = [
    'https://github.com/filecoin-project/curio',
    'https://github.com/lighthouse-web3/',
    'https://github.com/glifio/filecoin-iac',
    'https://github.com/filecoin-station/spark',
    'https://github.com/ipni/storetheindex',
    'https://github.com/filecoin-project/lotus',
    'https://github.com/CIDgravity/nextcloud-cidgravity-gateway-app',
    'https://github.com/Zondax/web-hub',
    'https://github.com/filecoin-project/ref-fvm',
    'https://github.com/davidgasquez/filecoin-data-portal',
    'https://github.com/probe-lab/hermes',
    'https://github.com/starboard-ventures/filecoin-network-health-dashboard',
    'https://github.com/filecoin-project/venus',
    'https://github.com/strahe/curio-dashboard',
    'https://github.com/chainsafe/forest',
    'https://github.com/filecoin-station',
    'https://github.com/randa-mu',
    'https://github.com/orgs/FIL-Builders',
    'https://github.com/filecoin-project/fildevsummit',
    'https://github.com/rpcpool/yellowstone-faithful',
    'https://github.com/Asia-SPWG/retroPGF',
    'https://github.com/filecoin-project/ref-fvm',
    'https://github.com/ucan-wg',
    'https://github.com/kenada88/destor',
    'https://github.com/filecoin-project/FIPs/',
    'https://github.com/libp2p/go-libp2p',
    'https://github.com/filecoin-project/rust-fil-proofs',
    'https://github.com/ipfs/boxo',
    'https://github.com/Zondax/web-beryx-explorer',
    'https://github.com/nftstorage/NFT.Storage-Flagship-Preservation-Public-Good',
    'https://github.com/NDLABS-Leo/RPGF2---NDLabs',
    'https://github.com/filecoin-project/filsnap',
    'https://github.com/filecoin-project/lotus',
    'https://github.com/FILL-Lab',
    'https://github.com/ipfs-force-community/filscan-backend',
    'https://github.com/filecoin-project/curio',
    'https://github.com/dannyob/orbit-fil-retropgf-2',
    'https://github.com/filecoin-project/go-f3',
    'https://github.com/FILCAT/ribs',
    'https://github.com/Hill168/filecoinhill',
    'https://github.com/Titannet-dao',
    'https://github.com/rpcpool/yellowstone-faithful',
    'https://github.com/celtd/voting_mechanism_design',
    'https://github.com/filecoin-project/FIPs',
    'https://github.com/FilOzone',
    'https://github.com/ipfs/helia',
    'https://github.com/libp2p/rust-libp2p',
    'https://github.com/Zondax/rfpg-beryx-api',
    'https://github.com/orgs/FIL-Builders',
    'https://github.com/fundingthecommons',
    'https://github.com/opensource-observer/oso',
    'https://github.com/MsquareHub/RetroPGF-Design',
    'https://github.com/kencloud-tech',
    'https://github.com/s0nik42/lotus-farcaster',
    'https://github.com/chainsafe/forest',
    'https://github.com/crossfidao',
    'https://github.com/libp2p/libp2p',
    'https://github.com/CELtd/builtin-actors/tree/fip0081',
    'https://github.com/ZenGround0/onramp-contracts',
    'https://github.com/xutianyi1999/commp_worker',
    'https://github.com/fidlabs/filplus-dashboard-webapp',
    'https://github.com/irmago/OrbitChinaRPGF',
    'https://github.com/ethglobal',
    'https://github.com/gh-efforts/lotus-monitor',
    'https://github.com/filecoin-project/on-chain-voting',
    'https://github.com/webtransitions/initiatives/',
    'https://github.com/CELtd/mechafil-jax-web-levers, https://github.com/CELtd/sp_cost_web',
    'https://github.com/Eastore-project/fildeal',
    'https://github.com/ChainSafe/filecoin-community-services',
    'https://github.com/hugomrdias/filecoin',
    'https://github.com/FilOzone/DDO',
    'https://github.com/cryptowhizzard/curio-oldfaithful',
    'https://github.com/DataseekCN/ipfs-vscode-extension',
    'https://github.com/ipfs-force-community/droplet',
    'https://github.com/retriev-protocol/core',
    'https://github.com/aschmahmann/filexp',
    'https://github.com/filecoin-project/community/discussions/74',
    'https://github.com/Filecoin-Nigeria/Education-Outreach',
    'https://github.com/Filecoin-South-Africa-Community/Impact',
    'https://github.com/storswiftlabs/drand-rs',
    'https://github.com/ipfs/ipfs-desktop',
    'https://github.com/cryptowhizzard',
    'https://github.com/FilOzone/FIL-Implemeter-WG/tree/main',
    'https://github.com/filecoin-project/filplus-registry',
    'https://github.com/nftstorage/NFT.Storage-Flagship-Preservation-Public-Good',
    'https://github.com/Wengi-web',
    'https://github.com/yhio/LtoY',
    'https://github.com/FilPunks/retroPGF',
    'https://github.com/strahe/extend',
    'https://github.com/freedomhz/RPGF-filminerfnfo',
    'https://github.com/chainupcloud',
    'https://github.com/OpenGateLab/FNS',
    'https://github.com/NDLABS-Leo/RPGF2---NDLabs-storagestats',
    'https://github.com/protofire/genesis-ark-ansible',
    'https://github.com/oif-admin',
    'https://github.com/usdfil',
    'https://github.com/nijoe1/QUADB',
    'https://github.com/Ancients-Research/retroPGF',
    'https://github.com/auralgenius/agcore',
    'https://github.com/ipfs-force-community/damocles',
    'https://github.com/herrehesse/datahorizon',
    'https://github.com/storswiftlabs',
    'https://github.com/DecentraSchool/decentraclasses',
    'https://github.com/Definomics-Labs',
    'https://github.com/gh-efforts/distribution',
    'https://github.com/dspytdao/dspyt-homepage',
    'https://github.com/GrayAreaorg/dweb-curriculum',
    'https://github.com/NovaEnergyAI',
    'https://github.com/dspytdao/EVM-Explorer',
    'https://github.com/VxBlocks/boost',
    'https://github.com/Filecoin-Africa/Education-Outreach-Repository',
    'https://github.com/Cryptoblarabi/FilecoinArabic',
    'https://github.com/hipiyushhere',
    'https://github.com/FiveToken',
    'https://github.com/filedag-project/filedag-storage',
    'https://github.com/filedrive-team/filejoy',
    'https://github.com/beck-8/filplus',
    'https://github.com/Filscriptions1/Filscriptions',
    'https://github.com/ipfs-force-community/gevulot-fil',
    'https://github.com/filedrive-team/go-ds-cluster',
    'https://github.com/ipfs-force-community/go-fvm-sdk',
    'https://github.com/filedrive-team/go-graphsplit',
    'https://github.com/filedrive-team/go-parallel-graphsync',
    'https://github.com/GovXS/Evaluating-Voting-Design-Tradeoffs-for-Retro-Funding',
    'https://github.com/ipfs-force-community/gpuproxy',
    'https://github.com/NodeDAO/HashKing-FIL',
    'https://github.com/GitDataAI/jzfs',
    'https://github.com/kernelogic/kfda-ts',
    'https://github.com/yhio/lotus-pilot',
    'https://github.com/ipfs-force-community/metrics',
    'https://github.com/OpenGate01/OpenGate-NFT-Marketplace',
    'https://github.com/Yaadyindia/Yaadyindia.git',
    'https://github.com/KenCloud-Tech/prolly-tree-oracle',
    'https://github.com/FilForge/pylotus-rpc',
    'https://github.com/yhio/rbot',
    'https://github.com/ipfs-force-community/sophon-auth',
    'https://github.com/ipfs-force-community/sophon-co',
    'https://github.com/ipfs-force-community/Sophon-gateway',
    'https://github.com/ipfs-force-community/sophon-messager',
    'https://github.com/ipfs-force-community/sophon-miner',
    'https://github.com/dukesoft/filecoin-spade-client',
    'https://github.com/ttsszzyy/tdrive.git',
    'https://github.com/twinquasar/green',
    'https://github.com/xutianyi1999/treed_gpu',
    'https://github.com/ipfs-force-community/venus-common-utils',
    'https://github.com/ipfs-force-community/venus-hub',
    'https://github.com/ipfs-force-community/venus-tool',
    'https://github.com/filecoin-project/venus-wallet',
    'https://github.com/VxBlocks/filecoin-utils',
    'https://github.com/pp1314car/Wanjia-Storage.git',
    'https://github.com/samflan875/Web3ForGood',
    'https://github.com/womenbiz/Filecoin'
]
SEED_REPOS = [x.replace('https://github.com/','').lower() for x in SEED_REPOS]
PACKAGE_SERVERS = ['NPM', 'RUST', 'GO', 'PIP']

# %% [markdown]
# # Get SBOMs for repos we care about
#
# - Subscribe to the OSO Production dataset on BigQuery (see docs [here](https://docs.opensource.observer/docs/get-started/bigquery))
# - Enter the following query into your [console](https://console.cloud.google.com/bigquery) to get a fresh copy of the graph
# - Save it as a CSV file to `graph/unweighted_graph.csv`

# %%
def stringify_array(arr):
    return "'" + "','".join(arr) + "'"

query = f"""
  -- COPY THIS INTO YOUR BIGQUERY CONSOLE
  
  select distinct
    sboms.from_artifact_namespace as seed_repo_owner,
    sboms.from_artifact_name as seed_repo_name,
    sboms.to_package_artifact_name as package_name,
    package_owners.package_owner_artifact_namespace as package_repo_owner,
    package_owners.package_owner_artifact_name as package_repo_name,
    sboms.to_package_artifact_source as package_source
  from `oso_production.sboms_v0` sboms
  join `oso_production.package_owners_v0` package_owners
    on
      sboms.to_package_artifact_name = package_owners.package_artifact_name
      and sboms.to_package_artifact_source = package_owners.package_artifact_source
  where
    sboms.to_package_artifact_source in ({stringify_array(PACKAGE_SERVERS)})
    and package_owners.package_owner_artifact_namespace is not null
    and concat(sboms.from_artifact_namespace, '/', sboms.from_artifact_name)
      in ({stringify_array(SEED_REPOS)})
"""

if REFRESH_DATA:

    from google.cloud import bigquery

    # replace with your path to credentials
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../oso_gcp_credentials.json'

    # replace with your project name
    client = bigquery.Client(project='opensource-observer')
    
    # execute the query and save it
    results = client.query(query)
    df = results.to_dataframe()
    df.to_csv(LOCAL_CSV_PATH)
    print("Query saved to local CSV file.")

else:    
    print(query)
# Out:
# Query saved to local CSV file.

# %% [markdown]
# # Load the graph as a CSV

# %%
df = pd.read_csv(LOCAL_CSV_PATH)

gh = 'https://github.com/'
df['seed_repo_url'] = df.apply(lambda x: f"{gh}{x['seed_repo_owner']}/{x['seed_repo_name']}", axis=1)
df['package_repo_url'] = df.apply(lambda x: f"{gh}{x['package_repo_owner']}/{x['package_repo_name']}", axis=1)

df.tail()
# Out:
#        Unnamed: 0 seed_repo_owner  \
# 35226       35226      nftstorage
# 35227       35227      nftstorage
# 35228       35228      nftstorage
# 35229       35229      nftstorage
# 35230       35230      nftstorage
#
#                                       seed_repo_name  \
# 35226  nft.storage-flagship-preservation-public-good
# 35227  nft.storage-flagship-preservation-public-good
# 35228  nft.storage-flagship-preservation-public-good
# 35229  nft.storage-flagship-preservation-public-good
# 35230  nft.storage-flagship-preservation-public-good
#
#                      package_name package_repo_owner  \
# 35226                         eta            eta-dev
# 35227             es-object-atoms             ljharb
# 35228       postcss-normalize-url            cssnano
# 35229            encoding-sniffer               fb55
# 35230  unist-util-remove-position        syntax-tree
#
#                 package_repo_name package_source  \
# 35226                         eta            NPM
# ...

# %%
df.groupby('package_source')['package_name'].nunique()
# Out:
# package_source
# GO       813
# NPM     5727
# PIP      288
# RUST    1154
# Name: package_name, dtype: int64

# %%
for pkg in PACKAGE_SERVERS:
    print(f"\n### Most Popular {pkg} Packages ###")
    pkg_lst = df[(df['package_source']==pkg) & (df['package_repo_owner'] != '')]['package_repo_name'].value_counts()
    nth = int(len(pkg_lst) * (0.025 if pkg == 'NPM' else 0.1))
    pkg_lst_top = list(pkg_lst.head(nth).index)
    print(pkg_lst_top)
# Out:
# ### Most Popular NPM Packages ###
# ...

# %%
owners = list(df['package_repo_owner'].unique())
len(owners)
# Out:
# 2193

# %% [markdown]
# # Create a network graph

# %%
G = nx.DiGraph()

for seed_repo in SEED_REPOS:
    G.add_node(f"{gh}{seed_repo}", level=1)
    
for repo_url in df['package_repo_url'].unique():
    if repo_url not in G.nodes:
        G.add_node(repo_url, level=2)
        
for _, row in df.iterrows():
    G.add_edge(
        row['seed_repo_url'],
        row['package_repo_url'],
        relation=row['package_source']
    )
    
total_edges = G.number_of_edges()
print(total_edges)

global_weight = 0
for u, v in G.edges:
    G[u][v]['weight'] = global_weight
    
graph_json = nx.node_link_data(G)
with open(LOCAL_JSON_PATH, "w") as f:
    json.dump(graph_json, f, indent=2)
# Out:
# 26516
