# %%
from google.cloud import bigquery
import os
import pandas as pd

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../gcp_credentials.json'
client = bigquery.Client()

# %% [markdown]
# # Get projects code metrics

# %%
query = """
SELECT *
FROM `opensource-observer.oso.code_metrics_by_project`
"""
result = client.query(query)
metrics = result.to_dataframe()

# %%
metrics.drop(columns=['project_id', 'project_name', 'repository_source'], inplace=True)
metrics.tail(3)
# Out:
#       project_slug         first_commit_date          last_commit_date  \
# 1729       uniswap 2018-03-07 00:00:00+00:00 2024-04-29 00:00:00+00:00
# 1730   safe-global 2017-07-06 00:00:00+00:00 2024-04-30 00:00:00+00:00
# 1731  offchainlabs 2019-06-04 00:00:00+00:00 2024-04-29 00:00:00+00:00
#
#       repositories  stars  forks  contributors  new_contributors_6_months  \
# 1729            59  27432  25468          5863                        495
# 1730           118   4925   3621          1453                        249
# 1731            94   4871   3333           821                        249
#
#       contributors_6_months  avg_fulltime_devs_6_months  \
# 1729                   5863                    1.000000
# 1730                   1453                    6.166667
# 1731                    821                    2.500000
#
#       avg_active_devs_6_months  commits_6_months  issues_opened_6_months  \
# 1729                 18.666667             708.0                   492.0
# 1730                 20.333333            5166.0                  1096.0
# 1731                 25.166667            4069.0                   360.0
#
#       issues_closed_6_months  pull_requests_opened_6_months  \
# 1729                   152.0                         1054.0
# 1730                  1093.0                         2952.0
# 1731                   323.0                         1504.0
#
#       pull_requests_merged_6_months
# 1729                          699.0
# 1730                         2567.0
# 1731                         1187.0

# %% [markdown]
# # Get all repos on OSO

# %%
query = """
SELECT *
FROM `opensource-observer.oso.repos_by_project`
"""
result = client.query(query)
repos = result.to_dataframe()
repos['repo_owner'] = repos['repo_name_with_owner'].apply(lambda x: x.split('/')[0])
repos.tail(3)
# Out:
#                                          project_id  \
# 37711  wXDIn1ZhRNdQ682uvEAtHNxdN_fzvxGWSbcWWIA96s0=
# 37712  wXDIn1ZhRNdQ682uvEAtHNxdN_fzvxGWSbcWWIA96s0=
# 37713  wXDIn1ZhRNdQ682uvEAtHNxdN_fzvxGWSbcWWIA96s0=
#
#                           project_slug                     project_name  \
# 37711  freedom-of-the-press-foundation  Freedom of the Press Foundation
# 37712  freedom-of-the-press-foundation  Freedom of the Press Foundation
# 37713  freedom-of-the-press-foundation  Freedom of the Press Foundation
#
#       repository_source                                   artifact_id  \
# 37711            GITHUB  z93BPXSRK2_85cW3JMH6_wi-0gB8px17w7PkyXRi8BE=
# 37712            GITHUB  0Exq3E25Iq02_ZssKk7_dlnMidJZT71e2Of9dQSWUIY=
# 37713            GITHUB  mokXx9BoxOv7TGcCwgPpMS-ZQaopi6EURml8ALwaj8U=
#
#        repo_is_fork  repo_fork_count  repo_star_count first_commit_date  \
# 37711          True                1                1               NaT
# 37712          True                0                1               NaT
# 37713          True                0                0               NaT
#
#       last_commit_date                repo_name_with_owner      repo_owner
# 37711              NaT    freedomofpress/due_date_reminder  freedomofpress
# 37712              NaT     freedomofpress/pdf-redact-tools  freedomofpress
# 37713              NaT  freedomofpress/ansible-letsencrypt  freedomofpress

# %%
repo_to_slug = dict(zip(repos['repo_name_with_owner'], repos['project_slug']))

repo_owners = repos[['repo_owner', 'project_slug']].drop_duplicates()
owner_to_slug_counts = repo_owners['repo_owner'].value_counts()
oso_unique_owners = list(owner_to_slug_counts[owner_to_slug_counts==1].index)
oso_dup_owners = list(owner_to_slug_counts[owner_to_slug_counts>1].index)

owner_to_slug = (
    repo_owners[repo_owners['repo_owner']
                .isin(oso_unique_owners)]
    .set_index('repo_owner')
    ['project_slug']
    .to_dict()
)

# %% [markdown]
# # Get GG projects from Metabase

# %%
projects = pd.read_csv('data/csv/gg20_projects_2024-05-01T12_20_52.794267Z.csv')

oso_slugs = []
for _,row in projects.iterrows():
    project = row['project_github']
    name = row['project_name']
    if isinstance(project, str):
        project = project.lower().strip().strip('/')
        if project in repo_to_slug:
            slug = repo_to_slug[project]
            oso_slugs.append(slug)
            continue
        if project in owner_to_slug:
            slug = owner_to_slug[project]
            oso_slugs.append(slug)
            continue        
        if project in oso_dup_owners:
            print(project, name)
    oso_slugs.append(None)

    
projects['oso_slug'] = oso_slugs
projects.tail()
# Out:
# chainsafe Lodestar
# scopelift Umbra
# scopelift Flexible Voting
# synthetixio Synpress
# ethereum web3.py
# openzeppelin OpenZeppelin Contracts
#      chain_id  round_id        round_name                    project_name  \
# 565     42161        23  Hackathon Alumni  $CODEX: Photosynthetic Finance
# 566     42161        23  Hackathon Alumni                            Ecco
# 567     42161        23  Hackathon Alumni                     AndiLending
# 568     42161        23  Hackathon Alumni                          FundIt
# 569     42161        23  Hackathon Alumni                          AdLand
#
#      project_github                              payout_address    status  \
# 565  cascadiacarbon  0xF1Ec938a362138ff0CC5268EC32690d9a137e83A  APPROVED
# 566       ecco-web3  0x57adDe4d31F44fa86FB553979FC52EDE13364129  APPROVED
# 567        AndiLend  0xBF457f26F1e8e7788654C228eda8B8660cC9eFd4  APPROVED
# 568   ecoland-world  0xc8f0bae52D42f42d1Aed7b4af00CA3EF6C516c23  APPROVED
# 569       adcommune  0x26bBec292e5080ecFD36F38FF1619FF35826b113  APPROVED
#
#            oso_slug
# 565  cascadiacarbon
# 566            None
# 567            None
# 568   ecoland-world
# 569       adcommune

# %% [markdown]
# # Create a master dataframe of all projects on OSO w/ metrics

# %%
df = pd.merge(
    projects,
    metrics,
    left_on='oso_slug',
    right_on='project_slug',
    how='left'
).drop(columns=['chain_id', 'round_id', 'project_slug'])
df
# Out:
#            round_name                    project_name   project_github  \
# 0       dApps & Apps         Tape (formerly Lenstube)          tapexyz
# 1       dApps & Apps       Hey.xyz (formerly Lenster)           heyxyz
# 2       dApps & Apps                  Toaster Finance  toaster-finance
# 3       dApps & Apps              ENS Wayback Machine      BlossomLabs
# 4       dApps & Apps                    Bloom Network     BloomNetwork
# ..                ...                             ...              ...
# 565  Hackathon Alumni  $CODEX: Photosynthetic Finance   cascadiacarbon
# 566  Hackathon Alumni                            Ecco        ecco-web3
# 567  Hackathon Alumni                     AndiLending         AndiLend
# 568  Hackathon Alumni                          FundIt    ecoland-world
# 569  Hackathon Alumni                          AdLand        adcommune
#
#                                  payout_address    status  \
# 0    0x01d79BcEaEaaDfb8fD2F2f53005289CFcF483464  APPROVED
# 1    0x03Ba34f6Ea1496fa316873CF8350A3f7eaD317EF  APPROVED
# 2    0x30CAEb399186E087668e85F4424ea39Baf4981aD  APPROVED
# 3    0x6ea869B6870dd98552B0C7e47dA90702a436358b  APPROVED
# 4    0x5219ffb88175588510e9752A1ecaA3cd217ca783  APPROVED
# ..                                          ...       ...
# 565  0xF1Ec938a362138ff0CC5268EC32690d9a137e83A  APPROVED
# 566  0x57adDe4d31F44fa86FB553979FC52EDE13364129  APPROVED
# 567  0xBF457f26F1e8e7788654C228eda8B8660cC9eFd4  APPROVED
# 568  0xc8f0bae52D42f42d1Aed7b4af00CA3EF6C516c23  APPROVED
# 569  0x26bBec292e5080ecFD36F38FF1619FF35826b113  APPROVED
#
#                             oso_slug         first_commit_date  \
# 0                            tapexyz 2022-08-27 00:00:00+00:00
# 1                             heyxyz 2022-03-19 00:00:00+00:00
# 2                    toaster-finance 2023-09-28 00:00:00+00:00
# 3    ens-wayback-machine-blossomlabs 2023-04-02 00:00:00+00:00
# 4                       bloomnetwork 2023-04-19 00:00:00+00:00
# ..                               ...                       ...
# 565                   cascadiacarbon 2019-07-26 00:00:00+00:00
# 566                             None                       NaT
# 567                             None                       NaT
# 568                    ecoland-world 2022-08-27 00:00:00+00:00
# 569                        adcommune 2024-04-29 00:00:00+00:00
#
#              last_commit_date  repositories  stars  ...  contributors  \
# 0   2024-04-29 00:00:00+00:00             4   4395  ...            38
# 1   2024-04-29 00:00:00+00:00             2  22408  ...           444
# 2   2024-04-26 00:00:00+00:00             4      1  ...             2
# 3   2024-04-25 00:00:00+00:00             1      0  ...             2
# 4   2023-08-11 00:00:00+00:00             1      1  ...             1
# ..                        ...           ...    ...  ...           ...
# 565 2024-04-08 00:00:00+00:00            13      4  ...             4
# 566                       NaT          <NA>   <NA>  ...          <NA>
# 567                       NaT          <NA>   <NA>  ...          <NA>
# 568 2024-04-26 00:00:00+00:00             5      0  ...             5
# 569 2024-04-29 00:00:00+00:00             1      2  ...             1
#
#      new_contributors_6_months  contributors_6_months  \
# 0                            8                     38
# 1                           76                    444
# 2                            1                      2
# 3                            1                      2
# 4                            0                      1
# ..                         ...                    ...
# 565                          2                      4
# 566                       <NA>                   <NA>
# 567                       <NA>                   <NA>
# 568                          1                      5
# 569                          1                      1
#
#      avg_fulltime_devs_6_months  avg_active_devs_6_months  commits_6_months  \
# 0                           1.0                  1.000000             719.0
# 1                           1.0                  1.166667            3101.0
# 2                           0.0                  0.333333               3.0
# 3                           0.0                  0.333333               6.0
# 4                           NaN                       NaN               NaN
# ..                          ...                       ...               ...
# 565                         NaN                       NaN               5.0
# 566                         NaN                       NaN               NaN
# 567                         NaN                       NaN               NaN
# 568                         0.0                  0.166667               2.0
# 569                         NaN                       NaN               4.0
#
#      issues_opened_6_months  issues_closed_6_months  \
# 0                       9.0                    22.0
# 1                     202.0                   228.0
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ..                      ...                     ...
# 565                     NaN                     NaN
# 566                     NaN                     NaN
# 567                     NaN                     NaN
# 568                     NaN                     NaN
# 569                     NaN                     NaN
#
#      pull_requests_opened_6_months  pull_requests_merged_6_months
# 0                            271.0                          260.0
# 1                            657.0                          572.0
# 2                              1.0                            NaN
# 3                              1.0                            1.0
# 4                              NaN                            NaN
# ..                             ...                            ...
# 565                            3.0                            NaN
# 566                            NaN                            NaN
# 567                            NaN                            NaN
# 568                            NaN                            NaN
# 569                            2.0                            1.0
#
# [570 rows x 21 columns]

# %%
df.to_csv("/Users/cerv1-air/Downloads/gg20-projects-export.csv")

# %%
summary_stats = pd.concat([
    projects.groupby('round_name')['payout_address'].count(),
    projects.groupby('round_name')['project_github'].count(),
    df.groupby('round_name')['oso_slug'].count(),
    df[df['first_commit_date'].isna() == True].groupby('round_name')['oso_slug'].count()
], axis=1)
summary_stats.columns = ['Total Projects', 'Projects w GitHub', 'Projects on OSO', 'New Projects on OSO']
summary_stats['Collection Size'] = round(summary_stats['Total Projects'] * .2)
summary_stats = summary_stats.fillna(0).astype(int)

summary_stats
# Out:
#                                                 Total Projects  \
# round_name
# Climate Round                                              127
# Developer Tooling and Libraries                             46
# ENS Identity                                                38
# Hackathon Alumni                                            53
# Hypercerts Ecosystem Round                                  35
# OpenCivics Consortium Round 02                              16
# Token Engineering QF Grants Round: Spring 2024              32
# Web3 Infrastructure                                         75
# dApps & Apps                                               148
#
#                                                 Projects w GitHub  \
# round_name
# Climate Round                                                  41
# Developer Tooling and Libraries                                46
# ENS Identity                                                   27
# Hackathon Alumni                                               53
# Hypercerts Ecosystem Round                                     20
# OpenCivics Consortium Round 02                                  7
# Token Engineering QF Grants Round: Spring 2024                 21
# Web3 Infrastructure                                            75
# dApps & Apps                                                  148
#
#                                                 Projects on OSO  \
# round_name
# Climate Round                                                22
# Developer Tooling and Libraries                              34
# ENS Identity                                                 20
# Hackathon Alumni                                             31
# Hypercerts Ecosystem Round                                   16
# OpenCivics Consortium Round 02                                5
# Token Engineering QF Grants Round: Spring 2024               14
# Web3 Infrastructure                                          57
# dApps & Apps                                                115
#
#                                                 New Projects on OSO  \
# round_name
# Climate Round                                                     4
# Developer Tooling and Libraries                                   5
# ENS Identity                                                      3
# Hackathon Alumni                                                 13
# Hypercerts Ecosystem Round                                        4
# OpenCivics Consortium Round 02                                    0
# Token Engineering QF Grants Round: Spring 2024                    4
# Web3 Infrastructure                                              12
# dApps & Apps                                                     22
#
#                                                 Collection Size
# round_name
# Climate Round                                                25
# Developer Tooling and Libraries                               9
# ENS Identity                                                  8
# Hackathon Alumni                                             11
# Hypercerts Ecosystem Round                                    7
# OpenCivics Consortium Round 02                                3
# Token Engineering QF Grants Round: Spring 2024                6
# Web3 Infrastructure                                          15
# dApps & Apps                                                 30

# %% [markdown]
# # Specific metrics

# %%
criteria = {
    'dApps & Apps ': 'avg_fulltime_devs_6_months',
    'Web3 Infrastructure': 'first_commit_date',
    'Developer Tooling and Libraries': 'forks',
    'Hackathon Alumni': 'commits_6_months', # days active

    'ENS Identity': 'pull_requests_merged_6_months',
    'Token Engineering QF Grants Round: Spring 2024': 'issues_opened_6_months',
        
    'Hypercerts Ecosystem Round': 'stars',
    'Climate Round': 'avg_fulltime_devs_6_months',
    'OpenCivics Consortium Round 02': 'stars' 
}

# %%
summary_stats.loc['Web3 Infrastructure', 'Collection Size']
# Out:
# 15

# %%
for round_name, metric in criteria.items():
    dff = df[df['round_name'] == round_name]
    n = summary_stats.loc[round_name, 'Collection Size']
    top_projects = list(dff.sort_values(by=metric, ascending=False)['project_name'].head(n))
    print(round_name)
    print(top_projects)
    print()
# Out:
# dApps & Apps
# ['ShapeShift DAO', 'rotki', 'Vocdoni - Secure digital voting', 'Giveth', 'Mississippi', 'JobStash', 'growthepie.xyz 🥧📏 - Usage Data and Analytics for Ethereum Scaling Solutions', 'Liker Land - NFT eBook - Empower Content Ownership', 'WTF Academy', 'Kiwi News', 'Impact Markets', 'DexKit', 'Hey.xyz (formerly Lenster)', 'Tape (formerly Lenstube)', 'Bankless Academy', 'Eppie: Web3 native email', 'Citizen Wallet', 'ZKP2P Fiat On Ramp', 'Revoke.cash', 'JediSwap', 'Tally Zero', 'IDriss - A more usable web3 for everyone', 'Mirror', 'Social Layer', 'viaPrize', 'Carmine Finance', 'Denota Protocol', 'MetaGame', 'Spark | Deresy & Hyperminter', 'Geo Web']
#
# Web3 Infrastructure
# ['PORTERS', 'True Network', 'Ultimate Digits', 'nim-libp2p', 'quic-go', 'Zerokit', 'Ethscriptions', 'Lakat 📜', 'EIP-7265 Alliance - securing the future of ethereum', 'Rantom', 'Blockhead: portfolio tracker, block explorer and web3 browser', 'Bonding Curve Research Group (BCRG)', 'Opti.Domains | Scale ENS to OP', 'AuditDB', 'Epoch Protocol']
#
# Developer Tooling and Libraries
# ['Scaffold-ETH2', 'Web3.js', 'Blockscout Block Explorer - Decentralized, Open-Source, Transparent Block Explorer for All Chains', 'ethers.js', 'Viem', 'Wagmi', 'OrbitDB', 'Blocknative', 'Ape Framework']
#
# Hackathon Alumni
# ['NFC wallet', 'Breadchain Cooperative', 'Dspyt-CodeVerse', 'Dspyt- into CodeVerse', 'Mosaic: Earn rewards for using your favorite web3 apps and protocols', 'Astral', 'Bitsave Protocol', 'Safe2Link', 'Fluidpay', 'Perpetual Organization Architect', 'DeStealth']
#
# ENS Identity
# ['rotki', 'Eppie: Web3 native email', 'ENS Road Around Brazil – by blockful', 'beaconcha.in', 'MetaMail', 'Pin Save EVM', 'EAS Attestation Explorer', 'Huddle01']
#
# Token Engineering QF Grants Round: Spring 2024
# ['Pairwise: Simplifying Choices, Amplifying Voices', 'Breadchain Cooperative', '1Hive Gardens', 'The cadCAD Foundation', 'Commons Stack', 'Bonding Curve Research Group (BCRG)']
#
# Hypercerts Ecosystem Round
# ['LexDAO', 'Armitage', 'NERD DAO: Decentralized Science and Web3 Innovation', 'Sovereign Nature Initiative & Hypercerts – Catalysing Biodiversity Restoration through Proof of Ecological Contribution', 'Hyperstaker', 'RWA x Public Goods | BASIN', 'Hyperfiles']
#
# Climate Round
# ['GoodDollar', 'RWA x Public Goods | BASIN', 'Grassroots Economics', 'LexDAO', 'ReFi Medellín - First Colombian Node of ReFiDAO responsible for promoting ReFi projects in Medellín.', 'Sunrise Stake', 'Ekonavi', 'MesoReefDAO - Regenerating Reef Conservation with DeSci Web3 tools', 'Switch Electric', 'xParametric', 'dMeter', 'Astral', "Endangered Tokens: NRWA Tokenization - Invest in nature's scarcest resources", 'ECOTA Web3 Carbon Dashboard', 'Pollen Buzz Initiative', 'La Madriguera', 'Carbon Counting Club ', '♻️ #GigsGoGreen - a movement for Gig Workers (initially Uber / Lyft / rideshare app drivers)', 'Sovereign Nature Initiative — Triggering Nature-Positive Funding One Asset at a Time', 'gainforest', 'Tulum’s Tomorrow, Accelerating the Regenaissance with ReFi Tulum', 'EarthRevive | Sustainable Communities', 'Greenpill Kenya Climate Round.', 'ALTERNUN', 'Change Code']
#
# OpenCivics Consortium Round 02
# ['Metagov', "Urbánika's bus: Circular Economy + Urban Governance", 'VoiceDeck: A Marketplace for Journalism Impact Certificates']

# %%
metrics.columns
# Out:
# Index(['project_slug', 'first_commit_date', 'last_commit_date', 'repositories',
#        'stars', 'forks', 'contributors', 'new_contributors_6_months',
#        'contributors_6_months', 'avg_fulltime_devs_6_months',
#        'avg_active_devs_6_months', 'commits_6_months',
#        'issues_opened_6_months', 'issues_closed_6_months',
#        'pull_requests_opened_6_months', 'pull_requests_merged_6_months'],
#       dtype='object')

# %%
with open("data/gg20-github-checks.json", "w") as f:
    json.dump(not_found, f, indent=2)
# Out:
# 174

# %%
projects_to_add = []
for p in not_found:
    if p['outcome']['Approved']:
        projects_to_add.append(p)
        
artifacts_to_add = [x['artifact'] for x in projects_to_add]

# %%
csv_version = (
    projects[projects['project_github'].str.lower().isin(artifacts_to_add)]
    [['project_name', 'project_github']]
    .drop_duplicates()
)
csv_version.columns = ['Project', 'GitHub']

csv_version['GitHub'] = csv_version['GitHub'].apply(lambda x: f"https://github.com/{x.lower()}")
csv_version
# Out:
#                               Project  \
# 10                Metrics Garden Labs
# 12                           Armitage
# 20                      Index Wallets
# 36                       IPC Explorer
# 37                  Proof of passport
# ..                                ...
# 507              Agents With Benefits
# 513  Perpetual Organization Architect
# 519                 Coordination-Play
# 520                          AI Swarm
# 522                            AdLand
#
#                                                 GitHub
# 10              https://github.com/metrics-garden-labs
# 12                    https://github.com/armitage-labs
# 20                         https://github.com/optionhq
# 36                     https://github.com/cronian-tech
# 37                      https://github.com/zk-passport
# ..                                                 ...
# 507                 https://github.com/agentswbenefits
# 513  https://github.com/perpetualorganizationarchitect
# 519               https://github.com/coordination-play
# 520                         https://github.com/aiswarm
# 522                       https://github.com/adcommune
#
# [78 rows x 2 columns]

# %%
csv_version.to_csv("data/csv/gg20_new_projects.csv")
